# %%
# !nvidia-smi # 查看GPU信息
# Out:
# Fri Jun 12 17:12:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 进入需要训练项目的文件夹
# %cd /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate2
# Out:
# /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate2

# %%
# !pip install xlutils
# Out:
# Requirement already satisfied: xlutils in /usr/local/lib/python3.6/dist-packages (2.0.0)
# Requirement already satisfied: xlrd>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.1.0)
# Requirement already satisfied: xlwt>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.3.0)

# %%
from models_deepcrack_unet import SegmentNet, weights_init_normal
from dataset_deepcrack_unet import CFDDataset

import torch.nn as nn
import torch

from torchvision import datasets
from torchvision.utils import save_image
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

import os
import sys
import argparse
import time
import PIL.Image as Image

import numpy as np

import xlwt
import xlrd
from xlutils.copy import copy

# %%
# 在ipynb文件中，parse的创建用函数来创建
# 直接用parser=parser = argparse.ArgumentParser() 来创建之后调用会报错

def get_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--cuda", type=bool, default=True, help="number of gpu")
    parser.add_argument("--gpu_num", type=int, default=1, help="number of gpu")
    parser.add_argument("--worker_num", type=int, default=0, help="number of input workers") # 只有一个GPU,default=0表示单进程加载
    parser.add_argument("--batch_size", type=int, default=2, help="batch size of input")
    parser.add_argument("--lr", type=float, default=0.01, help="adam: learning rate")
    parser.add_argument("--b1", type=float, default=0.90, help="adam: decay of first order momentum of gradient")
    parser.add_argument("--b2", type=float, default=0.997, help="adam: decay of second order momentum of gradient")
    parser.add_argument("--weight_decay", type=float, default=0.0005, help="adam: weight decay coefficient")

    parser.add_argument("--begin_epoch", type=int, default=51, help="begin_epoch")
    parser.add_argument("--end_epoch", type=int, default=201, help="end_epoch")

    parser.add_argument("--need_test", type=bool, default=True, help="need to test")
    parser.add_argument("--test_interval", type=int, default=10, help="interval of test")
    parser.add_argument("--need_save", type=bool, default=True, help="need to save")
    parser.add_argument("--save_interval", type=int, default=10, help="interval of save weights")

    parser.add_argument("--img_width", type=int, default=480, help="size of image width")
    parser.add_argument("--img_height", type=int, default=320, help="size of image height")
    
    return parser.parse_args(args=[])

opt = get_arguments()

print(opt)
# Out:
# Namespace(b1=0.9, b2=0.997, batch_size=2, begin_epoch=51, cuda=True, end_epoch=201, gpu_num=1, img_height=320, img_width=480, lr=0.01, need_save=True, need_test=True, save_interval=10, test_interval=10, weight_decay=0.0005, worker_num=0)

# %%
dataSetRoot = "../Data_cleaned"

# %%
# 建立网络
segment_net = SegmentNet(init_weights=True)

# 选择二分类交叉熵损失函数
criterion_segment  = torch.nn.BCELoss()

# %%
# 选择Adam优化器
optimizer_seg = torch.optim.Adam(segment_net.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=opt.weight_decay)

# 指数方式调整学习率，每一个epoch之后学习率变为原来的0.98倍
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_seg, gamma=0.98)

# %%
# 选择训练环境和参数
if opt.cuda:
    segment_net = segment_net.cuda()
    criterion_segment.cuda()

if opt.gpu_num > 1:
    segment_net = torch.nn.DataParallel(segment_net, device_ids=list(range(opt.gpu_num)))

if opt.begin_epoch != 1:
    # 加载前期训练的模型
    segment_net.load_state_dict(torch.load("./saved_models/segment_net_%d.pth" % (opt.begin_epoch-1)))
else:
    # 初始化权重
    segment_net.apply(weights_init_normal)

# %%
# 对原始数据和真实值进行一定前期处理，方便后续训练
transforms_ = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width), Image.BICUBIC),
    transforms.ToTensor()
])

transforms_mask = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width)), 
    transforms.ToTensor()
])

# %%
# 加载训练集和测试集
trainCFDloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask, subFold="CFD", isTrain=True),
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.worker_num,
)

testloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask,  subFold="CFD/cfd_TEST", isTrain=True),
    batch_size=1,
    shuffle=False,
    num_workers=opt.worker_num
)

# %%
# 定义对输出结果进行阈值化处理的函数，将小于阈值的计算为0，大于阈值的计算为1，在图像中像素为1的点为白色，为0的点为黑色
def data_threshold(data, threshold):
    threshold = torch.Tensor([threshold]).cuda()
    data_target = torch.Tensor([i//threshold for i in data]).cuda()
    return data_target

# %%
# 获取训练之后的 accuracy, precision , recall ,F1评价指标
# mask是真实值，data是预测值
def evaluate_metric(mask, data):
    m = metrics.confusion_matrix(mask, data)
    count_TP = m[1, 1]
    count_TN = m[0, 0]
    count_FN = m[1, 0] 
    count_FP = m[0 ,1]
    
    count = count_TP + count_FN + count_FP +count_TN
    print("count:{0},TP:{1},TN:{2},FP:{3},FN:{4}".format(count, count_TP, count_TN, count_FP, count_FN))  
    
    # 准确率
    accuracy = (count_TP+count_TN)/count 
    # 精准率
    precision = count_TP / (count_TP + count_FP) 
    # 查全率
    recall = count_TP / (count_TP + count_FN)
    # F1分
    F1 = 2*count_TP/(2*count_TP + count_FP + count_FN)
    
    return accuracy, precision, recall, F1

# %%
if opt.begin_epoch == 1:
  # 将训练过程的需要保存的数据保存到xls文件中
  # 创建一个workbook，设置编码
  workbook = xlwt.Workbook(encoding = 'utf-8')

  #---------------------写入训练过程的epoch, loss, accuracy------------------
  # 创建一个worksheet
  worksheet = workbook.add_sheet('sheet1')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')

  #---------------------写入测试过程的epoch, loss, accuracy------------------
  worksheet = workbook.add_sheet('sheet2')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')
                  
  #---------------------写入测试过程的epoch, accuracy, precision, recall, F1------------------                
  worksheet = workbook.add_sheet('sheet3')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'accuracy')
  worksheet.write(0, 2, 'precision')
  worksheet.write(0, 3, 'recall')
  worksheet.write(0, 4, 'F1')

  # 保存
  workbook.save('evaluate_data.xls')

def write_excel_xls_append(path, value, sheet_num):
  index = len(value)  # 获取需要写入数据的行数
  workbook = xlrd.open_workbook(path)            # 打开工作簿
  sheets = workbook.sheet_names()                # 获取工作簿中的所有表格
  worksheet = workbook.sheet_by_name(sheets[sheet_num])  # 获取工作簿中所有表格中的的第一个表格
  rows_old = worksheet.nrows                 # 获取表格中已存在的数据的行数
  new_workbook = copy(workbook)                # 将xlrd对象拷贝转化为xlwt对象
  new_worksheet = new_workbook.get_sheet(sheet_num)      # 获取转化后工作簿中的第sheet_num个表格
  
  for i in range(0, index):
      new_worksheet.write(rows_old, i, value[i])  # 追加写入数据
  new_workbook.save(path)  # 保存工作簿
  print("xls格式表格[追加]写入数据成功！")

# %%
for epoch in range(opt.begin_epoch, opt.end_epoch):

  iterCFD = trainCFDloader.__iter__()

  lenNum = len(trainCFDloader)

  segment_net.train()

  # -----------------------------------------------------------------------------
  # 开始训练
  # 记录每一个epoch的总损失和总精度
  train_loss_sum, train_acc_sum, batch_count = 0.0, 0.0, 0.0

  for i in range(0, lenNum):
      
    batchData = iterCFD.__next__()

    if opt.cuda:
        img = batchData["img"].cuda()
        mask = batchData["mask"].cuda()
    else:
        img = batchData["img"]
        mask = batchData["mask"]

    optimizer_seg.zero_grad()

    rst = segment_net(img)
    seg = rst["seg"]

    # 计算训练过程的损失loss
    loss_seg = 0.45*criterion_segment(seg, mask)+0.25*criterion_segment(rst["scale4"], mask)+0.15*criterion_segment(rst["scale3"], mask)\
            +0.1*criterion_segment(rst["scale2"], mask)+0.05*criterion_segment(rst["scale1"], mask)
    loss_seg.backward()
    optimizer_seg.step()

    train_loss_sum += loss_seg.item() 
    
    # 计算训练过程的accuracy
    net_seg = data_threshold(seg.clone().flatten(), 0.5)    # 预测值
    mask_seg = mask.clone().flatten()              # 真实值
    
    # 对每个像素点的值进行比较，相同的点计入right_seg 
    right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
    total_num = float(mask.clone().flatten().size()[0])
    
    batch_acc = right_seg/total_num
    train_acc_sum += batch_acc
    
    batch_count += 1
    
    # 输出每个epoch之中每个batch的信息
    print("[Epocn:{0}],[batch_count:{1}],[loss:{2:.6f}],[accuracy:{3:.6f}]".format(epoch, batch_count, loss_seg.item(), batch_acc))
    

  
  # 输出训练过程每个epoch平均的loss和accuracy
  print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, train_loss_sum/batch_count, train_acc_sum/batch_count))
    
  # 将上述epoch, loss, accuracy数据写入xls文件
  print("------------------------------------------------------------------------------------------")
  print("开始写入训练过程的epoch, loss, accuracy")
  train_xls_value = [epoch, train_loss_sum/batch_count, train_acc_sum/batch_count]
  write_excel_xls_append("evaluate_data.xls", train_xls_value, 0)
  print("------------------------------------------------------------------------------------------")
  

  # -----------------------------------------------------------------------------
  # 以一定周期保存训练之后的模型
  if opt.need_save and epoch % opt.save_interval == 0 and epoch >= opt.save_interval:

    save_path_str = "./saved_models"
    if os.path.exists(save_path_str) == False:
        os.makedirs(save_path_str, exist_ok=True)

    torch.save(segment_net.state_dict(), "%s/segment_net_%d.pth" % (save_path_str, epoch))
    print("------------------------------------------------------------------------------------------")
    print("save weights ! epoch = %d" %epoch)
    print("------------------------------------------------------------------------------------------")
    pass
    

  # -----------------------------------------------------------------------------
  # 对模型进行测试，并保存结果
  if opt.need_test and epoch % opt.test_interval == 0 and epoch >= opt.test_interval:

    test_loss_sum, test_acc_sum, batch_count = 0.0, 0.0, 0.0
    result_evaluate_epoch = np.array([0.0, 0.0, 0.0, 0.0])

    for i, testBatch in enumerate(testloader):
      imgTest = testBatch["img"].cuda()
      t1 = time.time()
      rstTest = segment_net(imgTest)
      t2 = time.time()

      # 计算测试过程的损失loss
      mask = testBatch["mask"].cuda()
      loss_test = criterion_segment(rstTest["seg"], mask)

      test_loss_sum += loss_test.item()

      # 计算测试过程的accuracy
      net_seg = data_threshold(rstTest["seg"].clone().flatten(), 0.5)  # 预测值
      mask_seg = mask.clone().flatten()                  # 真实值
      
      # 对每个像素点的值进行比较，相同的点计入right_seg 
      right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
      total_num = float(mask.clone().flatten().size()[0])
      
      batch_acc = right_seg/total_num
      test_acc_sum += batch_acc
      
      batch_count += 1

      # 对一个batch测试结果进行综合评估，并进行累加，方便后续保存
      result_evaluate_batch = np.array(list(evaluate_metric(mask_seg, net_seg)))
      result_evaluate_epoch += result_evaluate_batch
      
      # 对保存的图片进行阈值化处理
      seg_shape = rstTest["seg"].data.shape
      segTest_flatten = data_threshold(rstTest["seg"].flatten(), 0.5)
      segTest = segTest_flatten.reshape(seg_shape[0], seg_shape[1], seg_shape[2], seg_shape[3])

      # 建立文件的保存路径
      save_path_str = "./testResultSeg/epoch_%d"%(epoch)
      if os.path.exists(save_path_str) == False:
          os.makedirs(save_path_str, exist_ok=True)

      # 输出文件的保存信息
      print("processing image NO %d, time comsuption %fs"%(i, t2 - t1))
      save_image(imgTest.data, "%s/img_%d.jpg"% (save_path_str, i))
      save_image(segTest.data, "%s/img_%d_seg.jpg"% (save_path_str, i))
      save_image(rstTest["seg"].data, "%s/img_%d_raw_seg.jpg"% (save_path_str, i))

    # 将上述测试过程的评估参数acc,precision,recall和F1分数进行保存
    print("------------------------------------------------------------------------------------------")
    print("开始写入评估参数")
    result_evaluate_epoch = result_evaluate_epoch/np.array([batch_count])
    test_xls_metric = [epoch] + list(result_evaluate_epoch)
    write_excel_xls_append("evaluate_data.xls", test_xls_metric, 2)
    print("------------------------------------------------------------------------------------------")
    
    # 输出测试过程每个epoch平均的loss和accuracy
    print("------------------------------------------------------------------------------------------")
    print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, test_loss_sum/batch_count, test_acc_sum/batch_count))
    print("------------------------------------------------------------------------------------------")
    
    # 将上述epoch, loss, accuracy数据写入xls文件
    print("------------------------------------------------------------------------------------------")
    print("开始写入测试过程的epoch, loss, accuracy")
    test_xls_value = [epoch, test_loss_sum/batch_count, test_acc_sum/batch_count]
    write_excel_xls_append("evaluate_data.xls", test_xls_value, 1)
    print("------------------------------------------------------------------------------------------")

  # 利用schedular对学习率进行调节
  scheduler.step()
# Out:
# [Epocn:51],[batch_count:1.0],[loss:0.115410],[accuracy:0.991344]
# [Epocn:51],[batch_count:2.0],[loss:0.148241],[accuracy:0.979017]
# [Epocn:51],[batch_count:3.0],[loss:0.122938],[accuracy:0.985924]
# [Epocn:51],[batch_count:4.0],[loss:0.136615],[accuracy:0.978623]
# [Epocn:51],[batch_count:5.0],[loss:0.131859],[accuracy:0.979980]
# [Epocn:51],[batch_count:6.0],[loss:0.149973],[accuracy:0.974603]
# [Epocn:51],[batch_count:7.0],[loss:0.135889],[accuracy:0.977747]
# [Epocn:51],[batch_count:8.0],[loss:0.114110],[accuracy:0.987943]
# [Epocn:51],[batch_count:9.0],[loss:0.110752],[accuracy:0.988464]
# [Epocn:51],[batch_count:10.0],[loss:0.108833],[accuracy:0.989248]
# [Epocn:51],[batch_count:11.0],[loss:0.112700],[accuracy:0.987035]
# [Epocn:51],[batch_count:12.0],[loss:0.128656],[accuracy:0.978418]
# [Epocn:51],[batch_count:13.0],[loss:0.111073],[accuracy:0.987747]
# [Epocn:51],[batch_count:14.0],[loss:0.105346],[accuracy:0.990026]
# [Epocn:51],[batch_count:15.0],[loss:0.116130],[accuracy:0.986458]
# [Epocn:51],[batch_count:16.0],[loss:0.104652],[accuracy:0.989756]
# [Epocn:51],[batch_count:17.0],[loss:0.103666],[accuracy:0.989515]
# [Epocn:51],[batch_count:18.0],[loss:0.119398],[accuracy:0.980518]
# [Epocn:51],[batch_count:19.0],[loss:0.106489],[accuracy:0.988493]
# [Epocn:51],[batch_count:20.0],[loss:0.103384],[accuracy:0.987656]
# [Epocn:51],[batch_count:21.0],[loss:0.101268],[accuracy:0.988434]
# [Epocn:51],[batch_count:22.0],[loss:0.103453],[accuracy:0.985788]
# [Epocn:51],[batch_count:23.0],[loss:0.101857],[accuracy:0.988675]
# [Epocn:51],[batch_count:24.0],[loss:0.147141],[accuracy:0.965820]
# [Epocn:51],[batch_count:25.0],[loss:0.095719],[accuracy:0.990456]
# [Epocn:51],[batch_count:26.0],[loss:0.114622],[accuracy:0.978027]
# [Epocn:51],[batch_count:27.0],[loss:0.098543],[accuracy:0.988942]
# [Epocn:51],[batch_count:28.0],[loss:0.106913],[accuracy:0.981634]
# [Epocn:51],[batch_count:29.0],[loss:0.132387],[accuracy:0.966914]
# [Epocn:51],[batch_count:30.0],[loss:0.166940],[accuracy:0.942832]
# [Epoch 51/201], [loss:0.118499], accuracy:0.982535]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:52],[batch_count:1.0],[loss:0.108647],[accuracy:0.982793]
# [Epocn:52],[batch_count:2.0],[loss:0.130815],[accuracy:0.965492]
# [Epocn:52],[batch_count:3.0],[loss:0.116389],[accuracy:0.978626]
# [Epocn:52],[batch_count:4.0],[loss:0.105277],[accuracy:0.983893]
# [Epocn:52],[batch_count:5.0],[loss:0.103158],[accuracy:0.984792]
# [Epocn:52],[batch_count:6.0],[loss:0.133336],[accuracy:0.962969]
# [Epocn:52],[batch_count:7.0],[loss:0.094625],[accuracy:0.989613]
# [Epocn:52],[batch_count:8.0],[loss:0.120049],[accuracy:0.976872]
# [Epocn:52],[batch_count:9.0],[loss:0.090111],[accuracy:0.990999]
# [Epocn:52],[batch_count:10.0],[loss:0.095781],[accuracy:0.984352]
# [Epocn:52],[batch_count:11.0],[loss:0.101075],[accuracy:0.982367]
# [Epocn:52],[batch_count:12.0],[loss:0.094142],[accuracy:0.987985]
# [Epocn:52],[batch_count:13.0],[loss:0.103554],[accuracy:0.979443]
# [Epocn:52],[batch_count:14.0],[loss:0.102890],[accuracy:0.982158]
# [Epocn:52],[batch_count:15.0],[loss:0.089697],[accuracy:0.987646]
# [Epocn:52],[batch_count:16.0],[loss:0.092857],[accuracy:0.984619]
# [Epocn:52],[batch_count:17.0],[loss:0.081672],[accuracy:0.991973]
# [Epocn:52],[batch_count:18.0],[loss:0.100450],[accuracy:0.980290]
# [Epocn:52],[batch_count:19.0],[loss:0.087655],[accuracy:0.988581]
# [Epocn:52],[batch_count:20.0],[loss:0.078747],[accuracy:0.992129]
# [Epocn:52],[batch_count:21.0],[loss:0.090033],[accuracy:0.984609]
# [Epocn:52],[batch_count:22.0],[loss:0.088192],[accuracy:0.987308]
# [Epocn:52],[batch_count:23.0],[loss:0.115185],[accuracy:0.973428]
# [Epocn:52],[batch_count:24.0],[loss:0.100848],[accuracy:0.980524]
# [Epocn:52],[batch_count:25.0],[loss:0.075994],[accuracy:0.992832]
# [Epocn:52],[batch_count:26.0],[loss:0.081835],[accuracy:0.988896]
# [Epocn:52],[batch_count:27.0],[loss:0.082732],[accuracy:0.989730]
# [Epocn:52],[batch_count:28.0],[loss:0.080629],[accuracy:0.990352]
# [Epocn:52],[batch_count:29.0],[loss:0.080344],[accuracy:0.991195]
# [Epocn:52],[batch_count:30.0],[loss:0.086398],[accuracy:0.987754]
# [Epoch 52/201], [loss:0.097104], accuracy:0.984141]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:53],[batch_count:1.0],[loss:0.087545],[accuracy:0.987168]
# [Epocn:53],[batch_count:2.0],[loss:0.086015],[accuracy:0.987129]
# [Epocn:53],[batch_count:3.0],[loss:0.083209],[accuracy:0.986800]
# [Epocn:53],[batch_count:4.0],[loss:0.096076],[accuracy:0.983451]
# [Epocn:53],[batch_count:5.0],[loss:0.073237],[accuracy:0.991618]
# [Epocn:53],[batch_count:6.0],[loss:0.077472],[accuracy:0.988809]
# [Epocn:53],[batch_count:7.0],[loss:0.086136],[accuracy:0.987692]
# [Epocn:53],[batch_count:8.0],[loss:0.086636],[accuracy:0.984772]
# [Epocn:53],[batch_count:9.0],[loss:0.090440],[accuracy:0.983538]
# [Epocn:53],[batch_count:10.0],[loss:0.082089],[accuracy:0.985169]
# [Epocn:53],[batch_count:11.0],[loss:0.068287],[accuracy:0.992298]
# [Epocn:53],[batch_count:12.0],[loss:0.089983],[accuracy:0.981123]
# [Epocn:53],[batch_count:13.0],[loss:0.081895],[accuracy:0.987246]
# [Epocn:53],[batch_count:14.0],[loss:0.081743],[accuracy:0.984554]
# [Epocn:53],[batch_count:15.0],[loss:0.119039],[accuracy:0.962513]
# [Epocn:53],[batch_count:16.0],[loss:0.069421],[accuracy:0.990583]
# [Epocn:53],[batch_count:17.0],[loss:0.068677],[accuracy:0.992399]
# [Epocn:53],[batch_count:18.0],[loss:0.077765],[accuracy:0.986624]
# [Epocn:53],[batch_count:19.0],[loss:0.076064],[accuracy:0.988802]
# [Epocn:53],[batch_count:20.0],[loss:0.083058],[accuracy:0.981917]
# [Epocn:53],[batch_count:21.0],[loss:0.067417],[accuracy:0.991221]
# [Epocn:53],[batch_count:22.0],[loss:0.106495],[accuracy:0.974909]
# [Epocn:53],[batch_count:23.0],[loss:0.119335],[accuracy:0.963451]
# [Epocn:53],[batch_count:24.0],[loss:0.079469],[accuracy:0.986117]
# [Epocn:53],[batch_count:25.0],[loss:0.085551],[accuracy:0.982894]
# [Epocn:53],[batch_count:26.0],[loss:0.070917],[accuracy:0.989395]
# [Epocn:53],[batch_count:27.0],[loss:0.086614],[accuracy:0.980817]
# [Epocn:53],[batch_count:28.0],[loss:0.070017],[accuracy:0.989740]
# [Epocn:53],[batch_count:29.0],[loss:0.064898],[accuracy:0.990833]
# [Epocn:53],[batch_count:30.0],[loss:0.098155],[accuracy:0.973965]
# [Epoch 53/201], [loss:0.083789], accuracy:0.984585]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:54],[batch_count:1.0],[loss:0.067743],[accuracy:0.988776]
# [Epocn:54],[batch_count:2.0],[loss:0.082146],[accuracy:0.984629]
# [Epocn:54],[batch_count:3.0],[loss:0.108313],[accuracy:0.968226]
# [Epocn:54],[batch_count:4.0],[loss:0.065393],[accuracy:0.989704]
# [Epocn:54],[batch_count:5.0],[loss:0.084517],[accuracy:0.977702]
# [Epocn:54],[batch_count:6.0],[loss:0.066540],[accuracy:0.991478]
# [Epocn:54],[batch_count:7.0],[loss:0.078560],[accuracy:0.984424]
# [Epocn:54],[batch_count:8.0],[loss:0.078559],[accuracy:0.984189]
# [Epocn:54],[batch_count:9.0],[loss:0.063716],[accuracy:0.991162]
# [Epocn:54],[batch_count:10.0],[loss:0.061129],[accuracy:0.992129]
# [Epocn:54],[batch_count:11.0],[loss:0.061438],[accuracy:0.992360]
# [Epocn:54],[batch_count:12.0],[loss:0.077209],[accuracy:0.981895]
# [Epocn:54],[batch_count:13.0],[loss:0.059736],[accuracy:0.991956]
# [Epocn:54],[batch_count:14.0],[loss:0.069652],[accuracy:0.986090]
# [Epocn:54],[batch_count:15.0],[loss:0.058604],[accuracy:0.992432]
# [Epocn:54],[batch_count:16.0],[loss:0.065542],[accuracy:0.988776]
# [Epocn:54],[batch_count:17.0],[loss:0.064222],[accuracy:0.989395]
# [Epocn:54],[batch_count:18.0],[loss:0.107676],[accuracy:0.967646]
# [Epocn:54],[batch_count:19.0],[loss:0.059026],[accuracy:0.990739]
# [Epocn:54],[batch_count:20.0],[loss:0.091908],[accuracy:0.975999]
# [Epocn:54],[batch_count:21.0],[loss:0.065973],[accuracy:0.989564]
# [Epocn:54],[batch_count:22.0],[loss:0.060101],[accuracy:0.990446]
# [Epocn:54],[batch_count:23.0],[loss:0.063767],[accuracy:0.987158]
# [Epocn:54],[batch_count:24.0],[loss:0.077777],[accuracy:0.984548]
# [Epocn:54],[batch_count:25.0],[loss:0.075650],[accuracy:0.983096]
# [Epocn:54],[batch_count:26.0],[loss:0.074620],[accuracy:0.984447]
# [Epocn:54],[batch_count:27.0],[loss:0.070869],[accuracy:0.986328]
# [Epocn:54],[batch_count:28.0],[loss:0.097047],[accuracy:0.973945]
# [Epocn:54],[batch_count:29.0],[loss:0.077675],[accuracy:0.983027]
# [Epocn:54],[batch_count:30.0],[loss:0.056618],[accuracy:0.993249]
# [Epoch 54/201], [loss:0.073058], accuracy:0.985517]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:55],[batch_count:1.0],[loss:0.080332],[accuracy:0.981755]
# [Epocn:55],[batch_count:2.0],[loss:0.068666],[accuracy:0.984284]
# [Epocn:55],[batch_count:3.0],[loss:0.069992],[accuracy:0.985420]
# [Epocn:55],[batch_count:4.0],[loss:0.062844],[accuracy:0.987191]
# [Epocn:55],[batch_count:5.0],[loss:0.061870],[accuracy:0.988125]
# [Epocn:55],[batch_count:6.0],[loss:0.068994],[accuracy:0.988486]
# [Epocn:55],[batch_count:7.0],[loss:0.065116],[accuracy:0.987568]
# [Epocn:55],[batch_count:8.0],[loss:0.066061],[accuracy:0.986559]
# [Epocn:55],[batch_count:9.0],[loss:0.050867],[accuracy:0.993180]
# [Epocn:55],[batch_count:10.0],[loss:0.051866],[accuracy:0.992689]
# [Epocn:55],[batch_count:11.0],[loss:0.054120],[accuracy:0.990990]
# [Epocn:55],[batch_count:12.0],[loss:0.051469],[accuracy:0.991686]
# [Epocn:55],[batch_count:13.0],[loss:0.070299],[accuracy:0.984427]
# [Epocn:55],[batch_count:14.0],[loss:0.128730],[accuracy:0.955290]
# [Epocn:55],[batch_count:15.0],[loss:0.066897],[accuracy:0.986592]
# [Epocn:55],[batch_count:16.0],[loss:0.058234],[accuracy:0.989043]
# [Epocn:55],[batch_count:17.0],[loss:0.051274],[accuracy:0.992601]
# [Epocn:55],[batch_count:18.0],[loss:0.059943],[accuracy:0.989629]
# [Epocn:55],[batch_count:19.0],[loss:0.071756],[accuracy:0.980674]
# [Epocn:55],[batch_count:20.0],[loss:0.101790],[accuracy:0.964863]
# [Epocn:55],[batch_count:21.0],[loss:0.052559],[accuracy:0.991950]
# [Epocn:55],[batch_count:22.0],[loss:0.054637],[accuracy:0.990335]
# [Epocn:55],[batch_count:23.0],[loss:0.073673],[accuracy:0.983369]
# [Epocn:55],[batch_count:24.0],[loss:0.059144],[accuracy:0.988021]
# [Epocn:55],[batch_count:25.0],[loss:0.085479],[accuracy:0.977829]
# [Epocn:55],[batch_count:26.0],[loss:0.058856],[accuracy:0.988574]
# [Epocn:55],[batch_count:27.0],[loss:0.063909],[accuracy:0.987077]
# [Epocn:55],[batch_count:28.0],[loss:0.063699],[accuracy:0.985247]
# [Epocn:55],[batch_count:29.0],[loss:0.052089],[accuracy:0.990742]
# [Epocn:55],[batch_count:30.0],[loss:0.054859],[accuracy:0.990352]
# [Epoch 55/201], [loss:0.066001], accuracy:0.985818]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:56],[batch_count:1.0],[loss:0.057381],[accuracy:0.987402]
# [Epocn:56],[batch_count:2.0],[loss:0.057317],[accuracy:0.988542]
# [Epocn:56],[batch_count:3.0],[loss:0.061869],[accuracy:0.987871]
# [Epocn:56],[batch_count:4.0],[loss:0.049477],[accuracy:0.991354]
# [Epocn:56],[batch_count:5.0],[loss:0.058252],[accuracy:0.987757]
# [Epocn:56],[batch_count:6.0],[loss:0.067054],[accuracy:0.984893]
# [Epocn:56],[batch_count:7.0],[loss:0.054667],[accuracy:0.989854]
# [Epocn:56],[batch_count:8.0],[loss:0.069624],[accuracy:0.981449]
# [Epocn:56],[batch_count:9.0],[loss:0.050560],[accuracy:0.991354]
# [Epocn:56],[batch_count:10.0],[loss:0.068840],[accuracy:0.980068]
# [Epocn:56],[batch_count:11.0],[loss:0.055661],[accuracy:0.988649]
# [Epocn:56],[batch_count:12.0],[loss:0.050819],[accuracy:0.990238]
# [Epocn:56],[batch_count:13.0],[loss:0.067632],[accuracy:0.987236]
# [Epocn:56],[batch_count:14.0],[loss:0.056573],[accuracy:0.986634]
# [Epocn:56],[batch_count:15.0],[loss:0.043524],[accuracy:0.993509]
# [Epocn:56],[batch_count:16.0],[loss:0.059043],[accuracy:0.987549]
# [Epocn:56],[batch_count:17.0],[loss:0.058406],[accuracy:0.986230]
# [Epocn:56],[batch_count:18.0],[loss:0.053305],[accuracy:0.990260]
# [Epocn:56],[batch_count:19.0],[loss:0.071313],[accuracy:0.983499]
# [Epocn:56],[batch_count:20.0],[loss:0.048849],[accuracy:0.992510]
# [Epocn:56],[batch_count:21.0],[loss:0.098149],[accuracy:0.964508]
# [Epocn:56],[batch_count:22.0],[loss:0.057585],[accuracy:0.985306]
# [Epocn:56],[batch_count:23.0],[loss:0.047367],[accuracy:0.992389]
# [Epocn:56],[batch_count:24.0],[loss:0.068396],[accuracy:0.981706]
# [Epocn:56],[batch_count:25.0],[loss:0.057651],[accuracy:0.985329]
# [Epocn:56],[batch_count:26.0],[loss:0.064421],[accuracy:0.983812]
# [Epocn:56],[batch_count:27.0],[loss:0.099130],[accuracy:0.965544]
# [Epocn:56],[batch_count:28.0],[loss:0.091115],[accuracy:0.972214]
# [Epocn:56],[batch_count:29.0],[loss:0.055607],[accuracy:0.987467]
# [Epocn:56],[batch_count:30.0],[loss:0.057296],[accuracy:0.987409]
# [Epoch 56/201], [loss:0.061896], accuracy:0.985418]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:57],[batch_count:1.0],[loss:0.065307],[accuracy:0.982884]
# [Epocn:57],[batch_count:2.0],[loss:0.045500],[accuracy:0.992777]
# [Epocn:57],[batch_count:3.0],[loss:0.048746],[accuracy:0.989893]
# [Epocn:57],[batch_count:4.0],[loss:0.044108],[accuracy:0.992721]
# [Epocn:57],[batch_count:5.0],[loss:0.086706],[accuracy:0.971501]
# [Epocn:57],[batch_count:6.0],[loss:0.048503],[accuracy:0.989906]
# [Epocn:57],[batch_count:7.0],[loss:0.053537],[accuracy:0.986592]
# [Epocn:57],[batch_count:8.0],[loss:0.056522],[accuracy:0.988760]
# [Epocn:57],[batch_count:9.0],[loss:0.061540],[accuracy:0.986823]
# [Epocn:57],[batch_count:10.0],[loss:0.052704],[accuracy:0.987467]
# [Epocn:57],[batch_count:11.0],[loss:0.096708],[accuracy:0.966253]
# [Epocn:57],[batch_count:12.0],[loss:0.051303],[accuracy:0.989574]
# [Epocn:57],[batch_count:13.0],[loss:0.058095],[accuracy:0.987301]
# [Epocn:57],[batch_count:14.0],[loss:0.057914],[accuracy:0.985003]
# [Epocn:57],[batch_count:15.0],[loss:0.048040],[accuracy:0.991488]
# [Epocn:57],[batch_count:16.0],[loss:0.056646],[accuracy:0.985023]
# [Epocn:57],[batch_count:17.0],[loss:0.059556],[accuracy:0.986426]
# [Epocn:57],[batch_count:18.0],[loss:0.057851],[accuracy:0.987702]
# [Epocn:57],[batch_count:19.0],[loss:0.055123],[accuracy:0.987197]
# [Epocn:57],[batch_count:20.0],[loss:0.055398],[accuracy:0.987799]
# [Epocn:57],[batch_count:21.0],[loss:0.053753],[accuracy:0.986761]
# [Epocn:57],[batch_count:22.0],[loss:0.066863],[accuracy:0.980306]
# [Epocn:57],[batch_count:23.0],[loss:0.045913],[accuracy:0.992191]
# [Epocn:57],[batch_count:24.0],[loss:0.043756],[accuracy:0.991878]
# [Epocn:57],[batch_count:25.0],[loss:0.046827],[accuracy:0.990264]
# [Epocn:57],[batch_count:26.0],[loss:0.099239],[accuracy:0.964980]
# [Epocn:57],[batch_count:27.0],[loss:0.044571],[accuracy:0.990609]
# [Epocn:57],[batch_count:28.0],[loss:0.053945],[accuracy:0.987998]
# [Epocn:57],[batch_count:29.0],[loss:0.051920],[accuracy:0.987204]
# [Epocn:57],[batch_count:30.0],[loss:0.038887],[accuracy:0.994284]
# [Epoch 57/201], [loss:0.056849], accuracy:0.986319]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:58],[batch_count:1.0],[loss:0.044783],[accuracy:0.991585]
# [Epocn:58],[batch_count:2.0],[loss:0.069569],[accuracy:0.980876]
# [Epocn:58],[batch_count:3.0],[loss:0.049548],[accuracy:0.987952]
# [Epocn:58],[batch_count:4.0],[loss:0.055877],[accuracy:0.984290]
# [Epocn:58],[batch_count:5.0],[loss:0.038865],[accuracy:0.993376]
# [Epocn:58],[batch_count:6.0],[loss:0.051041],[accuracy:0.987074]
# [Epocn:58],[batch_count:7.0],[loss:0.048298],[accuracy:0.989147]
# [Epocn:58],[batch_count:8.0],[loss:0.042965],[accuracy:0.990508]
# [Epocn:58],[batch_count:9.0],[loss:0.061795],[accuracy:0.982653]
# [Epocn:58],[batch_count:10.0],[loss:0.073124],[accuracy:0.978105]
# [Epocn:58],[batch_count:11.0],[loss:0.095784],[accuracy:0.965244]
# [Epocn:58],[batch_count:12.0],[loss:0.049446],[accuracy:0.988486]
# [Epocn:58],[batch_count:13.0],[loss:0.039092],[accuracy:0.993174]
# [Epocn:58],[batch_count:14.0],[loss:0.046675],[accuracy:0.990143]
# [Epocn:58],[batch_count:15.0],[loss:0.045246],[accuracy:0.989593]
# [Epocn:58],[batch_count:16.0],[loss:0.054001],[accuracy:0.984954]
# [Epocn:58],[batch_count:17.0],[loss:0.045268],[accuracy:0.989993]
# [Epocn:58],[batch_count:18.0],[loss:0.041201],[accuracy:0.991423]
# [Epocn:58],[batch_count:19.0],[loss:0.068780],[accuracy:0.979694]
# [Epocn:58],[batch_count:20.0],[loss:0.086697],[accuracy:0.968317]
# [Epocn:58],[batch_count:21.0],[loss:0.064988],[accuracy:0.984788]
# [Epocn:58],[batch_count:22.0],[loss:0.045094],[accuracy:0.990202]
# [Epocn:58],[batch_count:23.0],[loss:0.046940],[accuracy:0.990394]
# [Epocn:58],[batch_count:24.0],[loss:0.046738],[accuracy:0.988115]
# [Epocn:58],[batch_count:25.0],[loss:0.051933],[accuracy:0.986950]
# [Epocn:58],[batch_count:26.0],[loss:0.042437],[accuracy:0.991230]
# [Epocn:58],[batch_count:27.0],[loss:0.055551],[accuracy:0.988180]
# [Epocn:58],[batch_count:28.0],[loss:0.036965],[accuracy:0.992793]
# [Epocn:58],[batch_count:29.0],[loss:0.045048],[accuracy:0.990267]
# [Epocn:58],[batch_count:30.0],[loss:0.047331],[accuracy:0.989206]
# [Epoch 58/201], [loss:0.053036], accuracy:0.986624]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:59],[batch_count:1.0],[loss:0.082188],[accuracy:0.975094]
# [Epocn:59],[batch_count:2.0],[loss:0.075911],[accuracy:0.978721]
# [Epocn:59],[batch_count:3.0],[loss:0.043420],[accuracy:0.990365]
# [Epocn:59],[batch_count:4.0],[loss:0.055927],[accuracy:0.984167]
# [Epocn:59],[batch_count:5.0],[loss:0.094738],[accuracy:0.965120]
# [Epocn:59],[batch_count:6.0],[loss:0.042678],[accuracy:0.990462]
# [Epocn:59],[batch_count:7.0],[loss:0.057671],[accuracy:0.980990]
# [Epocn:59],[batch_count:8.0],[loss:0.039398],[accuracy:0.992764]
# [Epocn:59],[batch_count:9.0],[loss:0.045336],[accuracy:0.989580]
# [Epocn:59],[batch_count:10.0],[loss:0.056254],[accuracy:0.985872]
# [Epocn:59],[batch_count:11.0],[loss:0.055784],[accuracy:0.984030]
# [Epocn:59],[batch_count:12.0],[loss:0.038747],[accuracy:0.991891]
# [Epocn:59],[batch_count:13.0],[loss:0.042823],[accuracy:0.990247]
# [Epocn:59],[batch_count:14.0],[loss:0.039314],[accuracy:0.991357]
# [Epocn:59],[batch_count:15.0],[loss:0.038352],[accuracy:0.992275]
# [Epocn:59],[batch_count:16.0],[loss:0.046012],[accuracy:0.989782]
# [Epocn:59],[batch_count:17.0],[loss:0.058356],[accuracy:0.982314]
# [Epocn:59],[batch_count:18.0],[loss:0.116940],[accuracy:0.960944]
# [Epocn:59],[batch_count:19.0],[loss:0.042350],[accuracy:0.990036]
# [Epocn:59],[batch_count:20.0],[loss:0.058053],[accuracy:0.986019]
# [Epocn:59],[batch_count:21.0],[loss:0.042120],[accuracy:0.990085]
# [Epocn:59],[batch_count:22.0],[loss:0.038380],[accuracy:0.992419]
# [Epocn:59],[batch_count:23.0],[loss:0.043303],[accuracy:0.990928]
# [Epocn:59],[batch_count:24.0],[loss:0.043104],[accuracy:0.989626]
# [Epocn:59],[batch_count:25.0],[loss:0.055703],[accuracy:0.985612]
# [Epocn:59],[batch_count:26.0],[loss:0.038887],[accuracy:0.992201]
# [Epocn:59],[batch_count:27.0],[loss:0.045326],[accuracy:0.988669]
# [Epocn:59],[batch_count:28.0],[loss:0.037982],[accuracy:0.991608]
# [Epocn:59],[batch_count:29.0],[loss:0.046468],[accuracy:0.987767]
# [Epocn:59],[batch_count:30.0],[loss:0.052203],[accuracy:0.983997]
# [Epoch 59/201], [loss:0.052458], accuracy:0.986165]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:60],[batch_count:1.0],[loss:0.087902],[accuracy:0.968353]
# [Epocn:60],[batch_count:2.0],[loss:0.058215],[accuracy:0.983890]
# [Epocn:60],[batch_count:3.0],[loss:0.046218],[accuracy:0.987650]
# [Epocn:60],[batch_count:4.0],[loss:0.038428],[accuracy:0.992230]
# [Epocn:60],[batch_count:5.0],[loss:0.065923],[accuracy:0.978451]
# [Epocn:60],[batch_count:6.0],[loss:0.036881],[accuracy:0.991742]
# [Epocn:60],[batch_count:7.0],[loss:0.046164],[accuracy:0.987409]
# [Epocn:60],[batch_count:8.0],[loss:0.034452],[accuracy:0.992865]
# [Epocn:60],[batch_count:9.0],[loss:0.043857],[accuracy:0.989251]
# [Epocn:60],[batch_count:10.0],[loss:0.046257],[accuracy:0.989098]
# [Epocn:60],[batch_count:11.0],[loss:0.065719],[accuracy:0.983053]
# [Epocn:60],[batch_count:12.0],[loss:0.044529],[accuracy:0.987930]
# [Epocn:60],[batch_count:13.0],[loss:0.039394],[accuracy:0.991654]
# [Epocn:60],[batch_count:14.0],[loss:0.036410],[accuracy:0.992949]
# [Epocn:60],[batch_count:15.0],[loss:0.036616],[accuracy:0.992367]
# [Epocn:60],[batch_count:16.0],[loss:0.038379],[accuracy:0.991172]
# [Epocn:60],[batch_count:17.0],[loss:0.073804],[accuracy:0.977887]
# [Epocn:60],[batch_count:18.0],[loss:0.037016],[accuracy:0.991960]
# [Epocn:60],[batch_count:19.0],[loss:0.055034],[accuracy:0.983867]
# [Epocn:60],[batch_count:20.0],[loss:0.038324],[accuracy:0.991406]
# [Epocn:60],[batch_count:21.0],[loss:0.045258],[accuracy:0.988210]
# [Epocn:60],[batch_count:22.0],[loss:0.040973],[accuracy:0.989697]
# [Epocn:60],[batch_count:23.0],[loss:0.057085],[accuracy:0.981042]
# [Epocn:60],[batch_count:24.0],[loss:0.051026],[accuracy:0.985674]
# [Epocn:60],[batch_count:25.0],[loss:0.055811],[accuracy:0.983571]
# [Epocn:60],[batch_count:26.0],[loss:0.036330],[accuracy:0.991940]
# [Epocn:60],[batch_count:27.0],[loss:0.050791],[accuracy:0.986064]
# [Epocn:60],[batch_count:28.0],[loss:0.044966],[accuracy:0.987184]
# [Epocn:60],[batch_count:29.0],[loss:0.095549],[accuracy:0.967347]
# [Epocn:60],[batch_count:30.0],[loss:0.047499],[accuracy:0.987454]
# [Epoch 60/201], [loss:0.049827], accuracy:0.986446]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 60
# ------------------------------------------------------------------------------------------
# count:153600,TP:2046,TN:150598,FP:418,FN538
# processing image NO 0, time comsuption 0.029920s
# count:153600,TP:2102,TN:150364,FP:289,FN845
# processing image NO 1, time comsuption 0.025976s
# count:153600,TP:2546,TN:148613,FP:329,FN2112
# processing image NO 2, time comsuption 0.019992s
# count:153600,TP:1694,TN:150185,FP:360,FN1361
# processing image NO 3, time comsuption 0.016979s
# count:153600,TP:1822,TN:150963,FP:522,FN293
# processing image NO 4, time comsuption 0.018946s
# count:153600,TP:1856,TN:150934,FP:446,FN364
# processing image NO 5, time comsuption 0.015017s
# count:153600,TP:2028,TN:150189,FP:506,FN877
# processing image NO 6, time comsuption 0.026930s
# count:153600,TP:2141,TN:150462,FP:232,FN765
# processing image NO 7, time comsuption 0.030916s
# count:153600,TP:1833,TN:150834,FP:595,FN338
# processing image NO 8, time comsuption 0.023934s
# count:153600,TP:1606,TN:150826,FP:846,FN322
# processing image NO 9, time comsuption 0.022966s
# count:153600,TP:1949,TN:149574,FP:520,FN1557
# processing image NO 10, time comsuption 0.019972s
# count:153600,TP:1651,TN:150983,FP:553,FN413
# processing image NO 11, time comsuption 0.030956s
# count:153600,TP:1522,TN:150915,FP:687,FN476
# processing image NO 12, time comsuption 0.020943s
# count:153600,TP:1228,TN:151037,FP:609,FN726
# processing image NO 13, time comsuption 0.025965s
# count:153600,TP:1728,TN:150500,FP:586,FN786
# processing image NO 14, time comsuption 0.024935s
# count:153600,TP:1701,TN:150582,FP:523,FN794
# processing image NO 15, time comsuption 0.014961s
# count:153600,TP:2114,TN:150178,FP:343,FN965
# processing image NO 16, time comsuption 0.033909s
# count:153600,TP:1696,TN:151070,FP:609,FN225
# processing image NO 17, time comsuption 0.032875s
# count:153600,TP:1854,TN:150551,FP:651,FN544
# processing image NO 18, time comsuption 0.014960s
# count:153600,TP:1777,TN:150612,FP:569,FN642
# processing image NO 19, time comsuption 0.021932s
# count:153600,TP:1863,TN:150856,FP:423,FN458
# processing image NO 20, time comsuption 0.016989s
# count:153600,TP:2104,TN:149792,FP:543,FN1161
# processing image NO 21, time comsuption 0.022936s
# count:153600,TP:1582,TN:150831,FP:595,FN592
# processing image NO 22, time comsuption 0.015970s
# count:153600,TP:2117,TN:150182,FP:400,FN901
# processing image NO 23, time comsuption 0.020949s
# count:153600,TP:1468,TN:151122,FP:567,FN443
# processing image NO 24, time comsuption 0.033908s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 60/201], [loss:0.036660], accuracy:0.991870]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-db2a2cd662a2> in <module>
#      25     optimizer_seg.zero_grad()
#      26
# ---> 27     rst = segment_net(img)
#      28     seg = rst["seg"]
#      29
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# D:\Google chrome download\2020.06.13深度学习训练\DeepCrackU-net-dilate2\models_deepcrack_unet.py in forward(self, x)
#     204         x14 = self.layer14(torch.cat((x3, x13), 1))
#     205         x15 = self.layer15(x14)
# --> 206         x16 = self.layer16(torch.cat((x1, x15), 1))
#     207
#     208         x17 = self.layer17(torch.cat((x7, x10), 1))
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\modules\batchnorm.py in forward(self, input)
#      74             input, self.running_mean, self.running_var, self.weight, self.bias,
#      75             self.training or not self.track_running_stats,
# ---> 76             exponential_average_factor, self.eps)
#      77
#      78     def extra_repr(self):
#
# D:\Anaconda\envs\PyTorch\lib\site-packages\torch\nn\functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1621     return torch.batch_norm(
#    1622         input, weight, bias, running_mean, running_var,
# -> 1623         training, momentum, eps, torch.backends.cudnn.enabled
#    1624     )
#    1625
#
# RuntimeError: CUDA out of memory. Tried to allocate 75.00 MiB (GPU 0; 4.00 GiB total capacity; 2.79 GiB already allocated; 38.66 MiB free; 137.15 MiB cached)
