# %%
# !nvidia-smi # 查看GPU信息
# Out:
# Fri Jun 12 17:05:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 进入需要训练项目的文件夹
# %cd /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate1
# Out:
# /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate1

# %%
# !pip install xlutils
# Out:
# Collecting xlutils
#   Downloading https://files.pythonhosted.org/packages/c7/55/e22ac73dbb316cabb5db28bef6c87044a95914f713a6e81b593f8a0d2f79/xlutils-2.0.0-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 4.8MB/s
# Requirement already satisfied: xlrd>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.1.0)
# Requirement already satisfied: xlwt>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.3.0)
# Installing collected packages: xlutils
# Successfully installed xlutils-2.0.0

# %%
from models_deepcrack_unet import SegmentNet, weights_init_normal
from dataset_deepcrack_unet import CFDDataset

import torch.nn as nn
import torch

from torchvision import datasets
from torchvision.utils import save_image
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

import os
import sys
import argparse
import time
import PIL.Image as Image

import numpy as np

import xlwt
import xlrd
from xlutils.copy import copy

# %%
# 在ipynb文件中，parse的创建用函数来创建
# 直接用parser=parser = argparse.ArgumentParser() 来创建之后调用会报错

def get_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--cuda", type=bool, default=True, help="number of gpu")
    parser.add_argument("--gpu_num", type=int, default=1, help="number of gpu")
    parser.add_argument("--worker_num", type=int, default=0, help="number of input workers") # 只有一个GPU,default=0表示单进程加载
    parser.add_argument("--batch_size", type=int, default=6, help="batch size of input")
    parser.add_argument("--lr", type=float, default=0.01, help="adam: learning rate")
    parser.add_argument("--b1", type=float, default=0.90, help="adam: decay of first order momentum of gradient")
    parser.add_argument("--b2", type=float, default=0.997, help="adam: decay of second order momentum of gradient")
    parser.add_argument("--weight_decay", type=float, default=0.0005, help="adam: weight decay coefficient")

    parser.add_argument("--begin_epoch", type=int, default=1, help="begin_epoch")
    parser.add_argument("--end_epoch", type=int, default=201, help="end_epoch")

    parser.add_argument("--need_test", type=bool, default=True, help="need to test")
    parser.add_argument("--test_interval", type=int, default=10, help="interval of test")
    parser.add_argument("--need_save", type=bool, default=True, help="need to save")
    parser.add_argument("--save_interval", type=int, default=10, help="interval of save weights")

    parser.add_argument("--img_width", type=int, default=480, help="size of image width")
    parser.add_argument("--img_height", type=int, default=320, help="size of image height")
    
    return parser.parse_args(args=[])

opt = get_arguments()

print(opt)
# Out:
# Namespace(b1=0.9, b2=0.997, batch_size=6, begin_epoch=1, cuda=True, end_epoch=201, gpu_num=1, img_height=320, img_width=480, lr=0.01, need_save=True, need_test=True, save_interval=10, test_interval=10, weight_decay=0.0005, worker_num=0)

# %%
dataSetRoot = "../Data_cleaned"

# %%
# 建立网络
segment_net = SegmentNet(init_weights=True)

# 选择二分类交叉熵损失函数
criterion_segment  = torch.nn.BCELoss()

# %%
# 选择Adam优化器
optimizer_seg = torch.optim.Adam(segment_net.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=opt.weight_decay)

# 指数方式调整学习率，每一个epoch之后学习率变为原来的0.98倍
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_seg, gamma=0.98)

# %%
# 选择训练环境和参数
if opt.cuda:
    segment_net = segment_net.cuda()
    criterion_segment.cuda()

if opt.gpu_num > 1:
    segment_net = torch.nn.DataParallel(segment_net, device_ids=list(range(opt.gpu_num)))

if opt.begin_epoch != 1:
    # 加载前期训练的模型
    segment_net.load_state_dict(torch.load("./saved_models/segment_net_%d.pth" % (opt.begin_epoch-1)))
else:
    # 初始化权重
    segment_net.apply(weights_init_normal)

# %%
# 对原始数据和真实值进行一定前期处理，方便后续训练
transforms_ = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width), Image.BICUBIC),
    transforms.ToTensor()
])

transforms_mask = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width)), 
    transforms.ToTensor()
])

# %%
# 加载训练集和测试集
trainCFDloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask, subFold="CFD", isTrain=True),
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.worker_num,
)

testloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask,  subFold="CFD/cfd_TEST", isTrain=True),
    batch_size=1,
    shuffle=False,
    num_workers=opt.worker_num
)

# %%
# 定义对输出结果进行阈值化处理的函数，将小于阈值的计算为0，大于阈值的计算为1，在图像中像素为1的点为白色，为0的点为黑色
def data_threshold(data, threshold):
    threshold = torch.Tensor([threshold]).cuda()
    data_target = torch.Tensor([i//threshold for i in data]).cuda()
    return data_target

# %%
# 获取训练之后的 accuracy, precision , recall ,F1评价指标
# mask是真实值，data是预测值
def evaluate_metric(mask, data):
    m = metrics.confusion_matrix(mask, data)
    count_TP = m[1, 1]
    count_TN = m[0, 0]
    count_FN = m[1, 0] 
    count_FP = m[0 ,1]
    
    count = count_TP + count_FN + count_FP +count_TN
    print("count:{0},TP:{1},TN:{2},FP:{3},FN:{4}".format(count, count_TP, count_TN, count_FP, count_FN))  
    
    # 准确率
    accuracy = (count_TP+count_TN)/count 
    # 精准率
    precision = count_TP / (count_TP + count_FP) 
    # 查全率
    recall = count_TP / (count_TP + count_FN)
    # F1分
    F1 = 2*count_TP/(2*count_TP + count_FP + count_FN)
    
    return accuracy, precision, recall, F1

# %%
if opt.begin_epoch == 1:
  # 将训练过程的需要保存的数据保存到xls文件中
  # 创建一个workbook，设置编码
  workbook = xlwt.Workbook(encoding = 'utf-8')

  #---------------------写入训练过程的epoch, loss, accuracy------------------
  # 创建一个worksheet
  worksheet = workbook.add_sheet('sheet1')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')

  #---------------------写入测试过程的epoch, loss, accuracy------------------
  worksheet = workbook.add_sheet('sheet2')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')
                  
  #---------------------写入测试过程的epoch, accuracy, precision, recall, F1------------------                
  worksheet = workbook.add_sheet('sheet3')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'accuracy')
  worksheet.write(0, 2, 'precision')
  worksheet.write(0, 3, 'recall')
  worksheet.write(0, 4, 'F1')

  # 保存
  workbook.save('evaluate_data.xls')

def write_excel_xls_append(path, value, sheet_num):
  index = len(value)  # 获取需要写入数据的行数
  workbook = xlrd.open_workbook(path)            # 打开工作簿
  sheets = workbook.sheet_names()                # 获取工作簿中的所有表格
  worksheet = workbook.sheet_by_name(sheets[sheet_num])  # 获取工作簿中所有表格中的的第一个表格
  rows_old = worksheet.nrows                 # 获取表格中已存在的数据的行数
  new_workbook = copy(workbook)                # 将xlrd对象拷贝转化为xlwt对象
  new_worksheet = new_workbook.get_sheet(sheet_num)      # 获取转化后工作簿中的第sheet_num个表格
  
  for i in range(0, index):
      new_worksheet.write(rows_old, i, value[i])  # 追加写入数据
  new_workbook.save(path)  # 保存工作簿
  print("xls格式表格[追加]写入数据成功！")

# %%
for epoch in range(opt.begin_epoch, opt.end_epoch):

  iterCFD = trainCFDloader.__iter__()

  lenNum = len(trainCFDloader)

  segment_net.train()

  # -----------------------------------------------------------------------------
  # 开始训练
  # 记录每一个epoch的总损失和总精度
  train_loss_sum, train_acc_sum, batch_count = 0.0, 0.0, 0.0

  for i in range(0, lenNum):
      
    batchData = iterCFD.__next__()

    if opt.cuda:
        img = batchData["img"].cuda()
        mask = batchData["mask"].cuda()
    else:
        img = batchData["img"]
        mask = batchData["mask"]

    optimizer_seg.zero_grad()

    rst = segment_net(img)
    seg = rst["seg"]

    # 计算训练过程的损失loss
    loss_seg = 0.45*criterion_segment(seg, mask)+0.25*criterion_segment(rst["scale4"], mask)+0.15*criterion_segment(rst["scale3"], mask)\
            +0.1*criterion_segment(rst["scale2"], mask)+0.05*criterion_segment(rst["scale1"], mask)
    loss_seg.backward()
    optimizer_seg.step()

    train_loss_sum += loss_seg.item() 
    
    # 计算训练过程的accuracy
    net_seg = data_threshold(seg.clone().flatten(), 0.5)    # 预测值
    mask_seg = mask.clone().flatten()              # 真实值
    
    # 对每个像素点的值进行比较，相同的点计入right_seg 
    right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
    total_num = float(mask.clone().flatten().size()[0])
    
    batch_acc = right_seg/total_num
    train_acc_sum += batch_acc
    
    batch_count += 1
    
    # 输出每个epoch之中每个batch的信息
    print("[Epocn:{0}],[batch_count:{1}],[loss:{2:.6f}],[accuracy:{3:.6f}]".format(epoch, batch_count, loss_seg.item(), batch_acc))
    

  
  # 输出训练过程每个epoch平均的loss和accuracy
  print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, train_loss_sum/batch_count, train_acc_sum/batch_count))
    
  # 将上述epoch, loss, accuracy数据写入xls文件
  print("------------------------------------------------------------------------------------------")
  print("开始写入训练过程的epoch, loss, accuracy")
  train_xls_value = [epoch, train_loss_sum/batch_count, train_acc_sum/batch_count]
  write_excel_xls_append("evaluate_data.xls", train_xls_value, 0)
  print("------------------------------------------------------------------------------------------")
  

  # -----------------------------------------------------------------------------
  # 以一定周期保存训练之后的模型
  if opt.need_save and epoch % opt.save_interval == 0 and epoch >= opt.save_interval:

    save_path_str = "./saved_models"
    if os.path.exists(save_path_str) == False:
        os.makedirs(save_path_str, exist_ok=True)

    torch.save(segment_net.state_dict(), "%s/segment_net_%d.pth" % (save_path_str, epoch))
    print("------------------------------------------------------------------------------------------")
    print("save weights ! epoch = %d" %epoch)
    print("------------------------------------------------------------------------------------------")
    pass
    

  # -----------------------------------------------------------------------------
  # 对模型进行测试，并保存结果
  if opt.need_test and epoch % opt.test_interval == 0 and epoch >= opt.test_interval:

    test_loss_sum, test_acc_sum, batch_count = 0.0, 0.0, 0.0
    result_evaluate_epoch = np.array([0.0, 0.0, 0.0, 0.0])

    for i, testBatch in enumerate(testloader):
      imgTest = testBatch["img"].cuda()
      t1 = time.time()
      rstTest = segment_net(imgTest)
      t2 = time.time()

      # 计算测试过程的损失loss
      mask = testBatch["mask"].cuda()
      loss_test = criterion_segment(rstTest["seg"], mask)

      test_loss_sum += loss_test.item()

      # 计算测试过程的accuracy
      net_seg = data_threshold(rstTest["seg"].clone().flatten(), 0.5)  # 预测值
      mask_seg = mask.clone().flatten()                  # 真实值
      
      # 对每个像素点的值进行比较，相同的点计入right_seg 
      right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
      total_num = float(mask.clone().flatten().size()[0])
      
      batch_acc = right_seg/total_num
      test_acc_sum += batch_acc
      
      batch_count += 1

      # 对一个batch测试结果进行综合评估，并进行累加，方便后续保存
      result_evaluate_batch = np.array(list(evaluate_metric(mask_seg, net_seg)))
      result_evaluate_epoch += result_evaluate_batch
      
      # 对保存的图片进行阈值化处理
      seg_shape = rstTest["seg"].data.shape
      segTest_flatten = data_threshold(rstTest["seg"].flatten(), 0.5)
      segTest = segTest_flatten.reshape(seg_shape[0], seg_shape[1], seg_shape[2], seg_shape[3])

      # 建立文件的保存路径
      save_path_str = "./testResultSeg/epoch_%d"%(epoch)
      if os.path.exists(save_path_str) == False:
          os.makedirs(save_path_str, exist_ok=True)

      # 输出文件的保存信息
      print("processing image NO %d, time comsuption %fs"%(i, t2 - t1))
      save_image(imgTest.data, "%s/img_%d.jpg"% (save_path_str, i))
      save_image(segTest.data, "%s/img_%d_seg.jpg"% (save_path_str, i))
      save_image(rstTest["seg"].data, "%s/img_%d_raw_seg.jpg"% (save_path_str, i))

    # 将上述测试过程的评估参数acc,precision,recall和F1分数进行保存
    print("------------------------------------------------------------------------------------------")
    print("开始写入评估参数")
    result_evaluate_epoch = result_evaluate_epoch/np.array([batch_count])
    test_xls_metric = [epoch] + list(result_evaluate_epoch)
    write_excel_xls_append("evaluate_data.xls", test_xls_metric, 2)
    print("------------------------------------------------------------------------------------------")
    
    # 输出测试过程每个epoch平均的loss和accuracy
    print("------------------------------------------------------------------------------------------")
    print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, test_loss_sum/batch_count, test_acc_sum/batch_count))
    print("------------------------------------------------------------------------------------------")
    
    # 将上述epoch, loss, accuracy数据写入xls文件
    print("------------------------------------------------------------------------------------------")
    print("开始写入测试过程的epoch, loss, accuracy")
    test_xls_value = [epoch, test_loss_sum/batch_count, test_acc_sum/batch_count]
    write_excel_xls_append("evaluate_data.xls", test_xls_value, 1)
    print("------------------------------------------------------------------------------------------")

  # 利用schedular对学习率进行调节
  scheduler.step()
# Out:
# [Epocn:1],[batch_count:1.0],[loss:0.813175],[accuracy:0.450059]
# [Epocn:1],[batch_count:2.0],[loss:0.762522],[accuracy:0.563618]
# [Epocn:1],[batch_count:3.0],[loss:0.729865],[accuracy:0.705421]
# [Epocn:1],[batch_count:4.0],[loss:0.728550],[accuracy:0.733360]
# [Epocn:1],[batch_count:5.0],[loss:0.681430],[accuracy:0.818171]
# [Epocn:1],[batch_count:6.0],[loss:0.703733],[accuracy:0.842011]
# [Epocn:1],[batch_count:7.0],[loss:0.683224],[accuracy:0.884308]
# [Epocn:1],[batch_count:8.0],[loss:0.672380],[accuracy:0.780846]
# [Epocn:1],[batch_count:9.0],[loss:0.676773],[accuracy:0.896980]
# [Epocn:1],[batch_count:10.0],[loss:0.660320],[accuracy:0.846938]
# [Epoch 1/201], [loss:0.711197], accuracy:0.752171]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:2],[batch_count:1.0],[loss:0.646817],[accuracy:0.943814]
# [Epocn:2],[batch_count:2.0],[loss:0.640403],[accuracy:0.955010]
# [Epocn:2],[batch_count:3.0],[loss:0.644138],[accuracy:0.942757]
# [Epocn:2],[batch_count:4.0],[loss:0.619968],[accuracy:0.953559]
# [Epocn:2],[batch_count:5.0],[loss:0.623448],[accuracy:0.938996]
# [Epocn:2],[batch_count:6.0],[loss:0.613209],[accuracy:0.927748]
# [Epocn:2],[batch_count:7.0],[loss:0.637781],[accuracy:0.907547]
# [Epocn:2],[batch_count:8.0],[loss:0.596895],[accuracy:0.934768]
# [Epocn:2],[batch_count:9.0],[loss:0.583225],[accuracy:0.957964]
# [Epocn:2],[batch_count:10.0],[loss:0.582473],[accuracy:0.955811]
# [Epoch 2/201], [loss:0.618836], accuracy:0.941797]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:3],[batch_count:1.0],[loss:0.585494],[accuracy:0.959527]
# [Epocn:3],[batch_count:2.0],[loss:0.589617],[accuracy:0.949359]
# [Epocn:3],[batch_count:3.0],[loss:0.577252],[accuracy:0.960065]
# [Epocn:3],[batch_count:4.0],[loss:0.568407],[accuracy:0.966782]
# [Epocn:3],[batch_count:5.0],[loss:0.580773],[accuracy:0.969521]
# [Epocn:3],[batch_count:6.0],[loss:0.565169],[accuracy:0.970502]
# [Epocn:3],[batch_count:7.0],[loss:0.571727],[accuracy:0.954300]
# [Epocn:3],[batch_count:8.0],[loss:0.571718],[accuracy:0.938991]
# [Epocn:3],[batch_count:9.0],[loss:0.552980],[accuracy:0.969832]
# [Epocn:3],[batch_count:10.0],[loss:0.549450],[accuracy:0.969535]
# [Epoch 3/201], [loss:0.571259], accuracy:0.960841]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:4],[batch_count:1.0],[loss:0.546735],[accuracy:0.973646]
# [Epocn:4],[batch_count:2.0],[loss:0.553630],[accuracy:0.971748]
# [Epocn:4],[batch_count:3.0],[loss:0.543885],[accuracy:0.962477]
# [Epocn:4],[batch_count:4.0],[loss:0.553297],[accuracy:0.951151]
# [Epocn:4],[batch_count:5.0],[loss:0.531538],[accuracy:0.966199]
# [Epocn:4],[batch_count:6.0],[loss:0.528396],[accuracy:0.974180]
# [Epocn:4],[batch_count:7.0],[loss:0.522085],[accuracy:0.981973]
# [Epocn:4],[batch_count:8.0],[loss:0.523221],[accuracy:0.974461]
# [Epocn:4],[batch_count:9.0],[loss:0.522816],[accuracy:0.977072]
# [Epocn:4],[batch_count:10.0],[loss:0.506692],[accuracy:0.957990]
# [Epoch 4/201], [loss:0.533230], accuracy:0.969090]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:5],[batch_count:1.0],[loss:0.510749],[accuracy:0.954693]
# [Epocn:5],[batch_count:2.0],[loss:0.495368],[accuracy:0.967626]
# [Epocn:5],[batch_count:3.0],[loss:0.507299],[accuracy:0.974349]
# [Epocn:5],[batch_count:4.0],[loss:0.516214],[accuracy:0.968971]
# [Epocn:5],[batch_count:5.0],[loss:0.509939],[accuracy:0.979446]
# [Epocn:5],[batch_count:6.0],[loss:0.514134],[accuracy:0.981374]
# [Epocn:5],[batch_count:7.0],[loss:0.498698],[accuracy:0.977848]
# [Epocn:5],[batch_count:8.0],[loss:0.489685],[accuracy:0.974018]
# [Epocn:5],[batch_count:9.0],[loss:0.481184],[accuracy:0.969243]
# [Epocn:5],[batch_count:10.0],[loss:0.473665],[accuracy:0.976958]
# [Epoch 5/201], [loss:0.499694], accuracy:0.972453]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:6],[batch_count:1.0],[loss:0.469927],[accuracy:0.979605]
# [Epocn:6],[batch_count:2.0],[loss:0.466005],[accuracy:0.984167]
# [Epocn:6],[batch_count:3.0],[loss:0.474811],[accuracy:0.976536]
# [Epocn:6],[batch_count:4.0],[loss:0.478775],[accuracy:0.972719]
# [Epocn:6],[batch_count:5.0],[loss:0.476578],[accuracy:0.972752]
# [Epocn:6],[batch_count:6.0],[loss:0.460586],[accuracy:0.968478]
# [Epocn:6],[batch_count:7.0],[loss:0.482112],[accuracy:0.962501]
# [Epocn:6],[batch_count:8.0],[loss:0.458622],[accuracy:0.977352]
# [Epocn:6],[batch_count:9.0],[loss:0.457285],[accuracy:0.983567]
# [Epocn:6],[batch_count:10.0],[loss:0.452785],[accuracy:0.986335]
# [Epoch 6/201], [loss:0.467749], accuracy:0.976401]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:7],[batch_count:1.0],[loss:0.471237],[accuracy:0.967261]
# [Epocn:7],[batch_count:2.0],[loss:0.445477],[accuracy:0.979201]
# [Epocn:7],[batch_count:3.0],[loss:0.461912],[accuracy:0.958003]
# [Epocn:7],[batch_count:4.0],[loss:0.442908],[accuracy:0.982091]
# [Epocn:7],[batch_count:5.0],[loss:0.441017],[accuracy:0.984416]
# [Epocn:7],[batch_count:6.0],[loss:0.441222],[accuracy:0.983452]
# [Epocn:7],[batch_count:7.0],[loss:0.445274],[accuracy:0.987498]
# [Epocn:7],[batch_count:8.0],[loss:0.425459],[accuracy:0.986270]
# [Epocn:7],[batch_count:9.0],[loss:0.423111],[accuracy:0.983442]
# [Epocn:7],[batch_count:10.0],[loss:0.426128],[accuracy:0.971904]
# [Epoch 7/201], [loss:0.442375], accuracy:0.978354]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:8],[batch_count:1.0],[loss:0.429658],[accuracy:0.966548]
# [Epocn:8],[batch_count:2.0],[loss:0.430323],[accuracy:0.967895]
# [Epocn:8],[batch_count:3.0],[loss:0.419249],[accuracy:0.981624]
# [Epocn:8],[batch_count:4.0],[loss:0.414671],[accuracy:0.979793]
# [Epocn:8],[batch_count:5.0],[loss:0.408725],[accuracy:0.987689]
# [Epocn:8],[batch_count:6.0],[loss:0.402524],[accuracy:0.982631]
# [Epocn:8],[batch_count:7.0],[loss:0.417271],[accuracy:0.971806]
# [Epocn:8],[batch_count:8.0],[loss:0.414336],[accuracy:0.972137]
# [Epocn:8],[batch_count:9.0],[loss:0.414303],[accuracy:0.982895]
# [Epocn:8],[batch_count:10.0],[loss:0.425174],[accuracy:0.967228]
# [Epoch 8/201], [loss:0.417624], accuracy:0.976025]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:9],[batch_count:1.0],[loss:0.407168],[accuracy:0.979017]
# [Epocn:9],[batch_count:2.0],[loss:0.399220],[accuracy:0.981387]
# [Epocn:9],[batch_count:3.0],[loss:0.400632],[accuracy:0.985447]
# [Epocn:9],[batch_count:4.0],[loss:0.415492],[accuracy:0.973224]
# [Epocn:9],[batch_count:5.0],[loss:0.392309],[accuracy:0.987121]
# [Epocn:9],[batch_count:6.0],[loss:0.389133],[accuracy:0.980954]
# [Epocn:9],[batch_count:7.0],[loss:0.384798],[accuracy:0.986842]
# [Epocn:9],[batch_count:8.0],[loss:0.382414],[accuracy:0.984494]
# [Epocn:9],[batch_count:9.0],[loss:0.380401],[accuracy:0.981919]
# [Epocn:9],[batch_count:10.0],[loss:0.380265],[accuracy:0.982483]
# [Epoch 9/201], [loss:0.393183], accuracy:0.982289]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:10],[batch_count:1.0],[loss:0.390954],[accuracy:0.971198]
# [Epocn:10],[batch_count:2.0],[loss:0.385128],[accuracy:0.981045]
# [Epocn:10],[batch_count:3.0],[loss:0.376429],[accuracy:0.986978]
# [Epocn:10],[batch_count:4.0],[loss:0.380580],[accuracy:0.979626]
# [Epocn:10],[batch_count:5.0],[loss:0.368861],[accuracy:0.986750]
# [Epocn:10],[batch_count:6.0],[loss:0.365054],[accuracy:0.980972]
# [Epocn:10],[batch_count:7.0],[loss:0.361766],[accuracy:0.980449]
# [Epocn:10],[batch_count:8.0],[loss:0.371752],[accuracy:0.976483]
# [Epocn:10],[batch_count:9.0],[loss:0.363504],[accuracy:0.984347]
# [Epocn:10],[batch_count:10.0],[loss:0.364608],[accuracy:0.983740]
# [Epoch 10/201], [loss:0.372863], accuracy:0.981159]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 10
# ------------------------------------------------------------------------------------------
# count:153600,TP:1456,TN:151172,FP:597,FN375
# processing image NO 0, time comsuption 0.008437s
# count:153600,TP:1409,TN:150785,FP:578,FN828
# processing image NO 1, time comsuption 0.009942s
# count:153600,TP:2282,TN:149429,FP:943,FN946
# processing image NO 2, time comsuption 0.009083s
# count:153600,TP:1001,TN:150326,FP:1091,FN1182
# processing image NO 3, time comsuption 0.007830s
# count:153600,TP:1322,TN:151338,FP:824,FN116
# processing image NO 4, time comsuption 0.012547s
# count:153600,TP:1348,TN:151298,FP:759,FN195
# processing image NO 5, time comsuption 0.008705s
# count:153600,TP:1705,TN:150719,FP:860,FN316
# processing image NO 6, time comsuption 0.016781s
# count:153600,TP:1776,TN:150834,FP:602,FN388
# processing image NO 7, time comsuption 0.007663s
# count:153600,TP:1120,TN:151083,FP:1122,FN275
# processing image NO 8, time comsuption 0.007789s
# count:153600,TP:1061,TN:150025,FP:2319,FN195
# processing image NO 9, time comsuption 0.008033s
# count:153600,TP:1200,TN:150299,FP:1043,FN1058
# processing image NO 10, time comsuption 0.009251s
# count:153600,TP:1102,TN:150936,FP:1271,FN291
# processing image NO 11, time comsuption 0.008205s
# count:153600,TP:927,TN:150436,FP:1825,FN412
# processing image NO 12, time comsuption 0.007790s
# count:153600,TP:798,TN:149744,FP:2543,FN515
# processing image NO 13, time comsuption 0.007939s
# count:153600,TP:1040,TN:150723,FP:1259,FN578
# processing image NO 14, time comsuption 0.007617s
# count:153600,TP:1197,TN:150581,FP:1290,FN532
# processing image NO 15, time comsuption 0.007630s
# count:153600,TP:1411,TN:150368,FP:935,FN886
# processing image NO 16, time comsuption 0.009110s
# count:153600,TP:929,TN:151357,FP:1026,FN288
# processing image NO 17, time comsuption 0.007996s
# count:153600,TP:1084,TN:150762,FP:1189,FN565
# processing image NO 18, time comsuption 0.009474s
# count:153600,TP:1049,TN:150903,FP:1064,FN584
# processing image NO 19, time comsuption 0.007847s
# count:153600,TP:1223,TN:151300,FP:714,FN363
# processing image NO 20, time comsuption 0.009359s
# count:153600,TP:1370,TN:150243,FP:1194,FN793
# processing image NO 21, time comsuption 0.007777s
# count:153600,TP:1044,TN:150513,FP:1578,FN465
# processing image NO 22, time comsuption 0.008669s
# count:153600,TP:1491,TN:150684,FP:786,FN639
# processing image NO 23, time comsuption 0.009505s
# count:153600,TP:913,TN:151055,FP:1272,FN360
# processing image NO 24, time comsuption 0.007635s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 10/201], [loss:0.352679], accuracy:0.989093]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:11],[batch_count:1.0],[loss:0.363949],[accuracy:0.988054]
# [Epocn:11],[batch_count:2.0],[loss:0.367088],[accuracy:0.987856]
# [Epocn:11],[batch_count:3.0],[loss:0.361323],[accuracy:0.983997]
# [Epocn:11],[batch_count:4.0],[loss:0.346426],[accuracy:0.986436]
# [Epocn:11],[batch_count:5.0],[loss:0.357946],[accuracy:0.984794]
# [Epocn:11],[batch_count:6.0],[loss:0.353583],[accuracy:0.986009]
# [Epocn:11],[batch_count:7.0],[loss:0.342283],[accuracy:0.977287]
# [Epocn:11],[batch_count:8.0],[loss:0.348344],[accuracy:0.981199]
# [Epocn:11],[batch_count:9.0],[loss:0.343461],[accuracy:0.986582]
# [Epocn:11],[batch_count:10.0],[loss:0.346115],[accuracy:0.981186]
# [Epoch 11/201], [loss:0.353052], accuracy:0.984340]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:12],[batch_count:1.0],[loss:0.340673],[accuracy:0.982824]
# [Epocn:12],[batch_count:2.0],[loss:0.348507],[accuracy:0.979846]
# [Epocn:12],[batch_count:3.0],[loss:0.337998],[accuracy:0.980124]
# [Epocn:12],[batch_count:4.0],[loss:0.331129],[accuracy:0.985075]
# [Epocn:12],[batch_count:5.0],[loss:0.342929],[accuracy:0.984416]
# [Epocn:12],[batch_count:6.0],[loss:0.335390],[accuracy:0.978799]
# [Epocn:12],[batch_count:7.0],[loss:0.330195],[accuracy:0.986132]
# [Epocn:12],[batch_count:8.0],[loss:0.325175],[accuracy:0.987164]
# [Epocn:12],[batch_count:9.0],[loss:0.326390],[accuracy:0.987922]
# [Epocn:12],[batch_count:10.0],[loss:0.329270],[accuracy:0.987604]
# [Epoch 12/201], [loss:0.334766], accuracy:0.983991]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:13],[batch_count:1.0],[loss:0.332225],[accuracy:0.975897]
# [Epocn:13],[batch_count:2.0],[loss:0.328560],[accuracy:0.988397]
# [Epocn:13],[batch_count:3.0],[loss:0.326986],[accuracy:0.981964]
# [Epocn:13],[batch_count:4.0],[loss:0.331078],[accuracy:0.980196]
# [Epocn:13],[batch_count:5.0],[loss:0.321915],[accuracy:0.979482]
# [Epocn:13],[batch_count:6.0],[loss:0.316687],[accuracy:0.981513]
# [Epocn:13],[batch_count:7.0],[loss:0.315733],[accuracy:0.979551]
# [Epocn:13],[batch_count:8.0],[loss:0.313876],[accuracy:0.982618]
# [Epocn:13],[batch_count:9.0],[loss:0.307952],[accuracy:0.990042]
# [Epocn:13],[batch_count:10.0],[loss:0.314977],[accuracy:0.988701]
# [Epoch 13/201], [loss:0.320999], accuracy:0.982836]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:14],[batch_count:1.0],[loss:0.321826],[accuracy:0.981242]
# [Epocn:14],[batch_count:2.0],[loss:0.301853],[accuracy:0.987986]
# [Epocn:14],[batch_count:3.0],[loss:0.301147],[accuracy:0.986340]
# [Epocn:14],[batch_count:4.0],[loss:0.304350],[accuracy:0.986106]
# [Epocn:14],[batch_count:5.0],[loss:0.301984],[accuracy:0.987137]
# [Epocn:14],[batch_count:6.0],[loss:0.296469],[accuracy:0.989670]
# [Epocn:14],[batch_count:7.0],[loss:0.335179],[accuracy:0.973498]
# [Epocn:14],[batch_count:8.0],[loss:0.308683],[accuracy:0.986068]
# [Epocn:14],[batch_count:9.0],[loss:0.299088],[accuracy:0.983013]
# [Epocn:14],[batch_count:10.0],[loss:0.296519],[accuracy:0.982342]
# [Epoch 14/201], [loss:0.306710], accuracy:0.984340]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:15],[batch_count:1.0],[loss:0.296921],[accuracy:0.986321]
# [Epocn:15],[batch_count:2.0],[loss:0.302791],[accuracy:0.986910]
# [Epocn:15],[batch_count:3.0],[loss:0.293982],[accuracy:0.983982]
# [Epocn:15],[batch_count:4.0],[loss:0.310026],[accuracy:0.975477]
# [Epocn:15],[batch_count:5.0],[loss:0.296320],[accuracy:0.979868]
# [Epocn:15],[batch_count:6.0],[loss:0.289464],[accuracy:0.983069]
# [Epocn:15],[batch_count:7.0],[loss:0.305842],[accuracy:0.976378]
# [Epocn:15],[batch_count:8.0],[loss:0.289951],[accuracy:0.987070]
# [Epocn:15],[batch_count:9.0],[loss:0.284865],[accuracy:0.986616]
# [Epocn:15],[batch_count:10.0],[loss:0.278332],[accuracy:0.988069]
# [Epoch 15/201], [loss:0.294850], accuracy:0.983376]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:16],[batch_count:1.0],[loss:0.280188],[accuracy:0.988792]
# [Epocn:16],[batch_count:2.0],[loss:0.281862],[accuracy:0.986966]
# [Epocn:16],[batch_count:3.0],[loss:0.286116],[accuracy:0.981143]
# [Epocn:16],[batch_count:4.0],[loss:0.283333],[accuracy:0.981440]
# [Epocn:16],[batch_count:5.0],[loss:0.274427],[accuracy:0.984799]
# [Epocn:16],[batch_count:6.0],[loss:0.281662],[accuracy:0.984596]
# [Epocn:16],[batch_count:7.0],[loss:0.277759],[accuracy:0.988671]
# [Epocn:16],[batch_count:8.0],[loss:0.272389],[accuracy:0.989371]
# [Epocn:16],[batch_count:9.0],[loss:0.276299],[accuracy:0.986764]
# [Epocn:16],[batch_count:10.0],[loss:0.280042],[accuracy:0.986478]
# [Epoch 16/201], [loss:0.279408], accuracy:0.985902]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:17],[batch_count:1.0],[loss:0.271071],[accuracy:0.990042]
# [Epocn:17],[batch_count:2.0],[loss:0.274301],[accuracy:0.986249]
# [Epocn:17],[batch_count:3.0],[loss:0.272381],[accuracy:0.986408]
# [Epocn:17],[batch_count:4.0],[loss:0.273659],[accuracy:0.982155]
# [Epocn:17],[batch_count:5.0],[loss:0.263459],[accuracy:0.986206]
# [Epocn:17],[batch_count:6.0],[loss:0.264912],[accuracy:0.985952]
# [Epocn:17],[batch_count:7.0],[loss:0.280278],[accuracy:0.975120]
# [Epocn:17],[batch_count:8.0],[loss:0.262667],[accuracy:0.983746]
# [Epocn:17],[batch_count:9.0],[loss:0.260990],[accuracy:0.989145]
# [Epocn:17],[batch_count:10.0],[loss:0.257470],[accuracy:0.991082]
# [Epoch 17/201], [loss:0.268119], accuracy:0.985610]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:18],[batch_count:1.0],[loss:0.256378],[accuracy:0.991117]
# [Epocn:18],[batch_count:2.0],[loss:0.260739],[accuracy:0.983916]
# [Epocn:18],[batch_count:3.0],[loss:0.259138],[accuracy:0.987387]
# [Epocn:18],[batch_count:4.0],[loss:0.261930],[accuracy:0.983420]
# [Epocn:18],[batch_count:5.0],[loss:0.265422],[accuracy:0.984123]
# [Epocn:18],[batch_count:6.0],[loss:0.251217],[accuracy:0.987514]
# [Epocn:18],[batch_count:7.0],[loss:0.256745],[accuracy:0.985623]
# [Epocn:18],[batch_count:8.0],[loss:0.250127],[accuracy:0.985813]
# [Epocn:18],[batch_count:9.0],[loss:0.272567],[accuracy:0.978025]
# [Epocn:18],[batch_count:10.0],[loss:0.257413],[accuracy:0.985302]
# [Epoch 18/201], [loss:0.259168], accuracy:0.985224]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:19],[batch_count:1.0],[loss:0.263412],[accuracy:0.978030]
# [Epocn:19],[batch_count:2.0],[loss:0.242063],[accuracy:0.991368]
# [Epocn:19],[batch_count:3.0],[loss:0.251819],[accuracy:0.985212]
# [Epocn:19],[batch_count:4.0],[loss:0.255604],[accuracy:0.980726]
# [Epocn:19],[batch_count:5.0],[loss:0.246415],[accuracy:0.988381]
# [Epocn:19],[batch_count:6.0],[loss:0.249474],[accuracy:0.983145]
# [Epocn:19],[batch_count:7.0],[loss:0.246232],[accuracy:0.988292]
# [Epocn:19],[batch_count:8.0],[loss:0.241672],[accuracy:0.988550]
# [Epocn:19],[batch_count:9.0],[loss:0.250183],[accuracy:0.981401]
# [Epocn:19],[batch_count:10.0],[loss:0.260517],[accuracy:0.988983]
# [Epoch 19/201], [loss:0.250739], accuracy:0.985409]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:20],[batch_count:1.0],[loss:0.243139],[accuracy:0.985388]
# [Epocn:20],[batch_count:2.0],[loss:0.238225],[accuracy:0.990160]
# [Epocn:20],[batch_count:3.0],[loss:0.252078],[accuracy:0.983896]
# [Epocn:20],[batch_count:4.0],[loss:0.232678],[accuracy:0.990811]
# [Epocn:20],[batch_count:5.0],[loss:0.242092],[accuracy:0.989301]
# [Epocn:20],[batch_count:6.0],[loss:0.241792],[accuracy:0.984045]
# [Epocn:20],[batch_count:7.0],[loss:0.240868],[accuracy:0.989040]
# [Epocn:20],[batch_count:8.0],[loss:0.244091],[accuracy:0.983244]
# [Epocn:20],[batch_count:9.0],[loss:0.236408],[accuracy:0.986166]
# [Epocn:20],[batch_count:10.0],[loss:0.237292],[accuracy:0.982783]
# [Epoch 20/201], [loss:0.240866], accuracy:0.986483]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 20
# ------------------------------------------------------------------------------------------
# count:153600,TP:1356,TN:151188,FP:581,FN475
# processing image NO 0, time comsuption 0.007603s
# count:153600,TP:1391,TN:150887,FP:476,FN846
# processing image NO 1, time comsuption 0.008929s
# count:153600,TP:2151,TN:149598,FP:774,FN1077
# processing image NO 2, time comsuption 0.007627s
# count:153600,TP:956,TN:150763,FP:654,FN1227
# processing image NO 3, time comsuption 0.007509s
# count:153600,TP:1287,TN:151286,FP:876,FN151
# processing image NO 4, time comsuption 0.007599s
# count:153600,TP:1315,TN:151326,FP:731,FN228
# processing image NO 5, time comsuption 0.007710s
# count:153600,TP:1557,TN:150853,FP:726,FN464
# processing image NO 6, time comsuption 0.008358s
# count:153600,TP:1716,TN:150927,FP:509,FN448
# processing image NO 7, time comsuption 0.007508s
# count:153600,TP:1067,TN:151319,FP:886,FN328
# processing image NO 8, time comsuption 0.007674s
# count:153600,TP:1035,TN:150723,FP:1621,FN221
# processing image NO 9, time comsuption 0.007562s
# count:153600,TP:1116,TN:150441,FP:901,FN1142
# processing image NO 10, time comsuption 0.007960s
# count:153600,TP:1070,TN:151265,FP:942,FN323
# processing image NO 11, time comsuption 0.007853s
# count:153600,TP:901,TN:151125,FP:1136,FN438
# processing image NO 12, time comsuption 0.007595s
# count:153600,TP:772,TN:150820,FP:1467,FN541
# processing image NO 13, time comsuption 0.007735s
# count:153600,TP:957,TN:151078,FP:904,FN661
# processing image NO 14, time comsuption 0.007711s
# count:153600,TP:1102,TN:151034,FP:837,FN627
# processing image NO 15, time comsuption 0.007559s
# count:153600,TP:1454,TN:150643,FP:660,FN843
# processing image NO 16, time comsuption 0.007785s
# count:153600,TP:907,TN:151472,FP:911,FN310
# processing image NO 17, time comsuption 0.007607s
# count:153600,TP:1032,TN:150992,FP:959,FN617
# processing image NO 18, time comsuption 0.007640s
# count:153600,TP:1017,TN:151114,FP:853,FN616
# processing image NO 19, time comsuption 0.007515s
# count:153600,TP:1160,TN:151273,FP:741,FN426
# processing image NO 20, time comsuption 0.007962s
# count:153600,TP:1279,TN:150418,FP:1019,FN884
# processing image NO 21, time comsuption 0.010671s
# count:153600,TP:1083,TN:151141,FP:950,FN426
# processing image NO 22, time comsuption 0.007706s
# count:153600,TP:1387,TN:150759,FP:711,FN743
# processing image NO 23, time comsuption 0.007583s
# count:153600,TP:914,TN:151383,FP:944,FN359
# processing image NO 24, time comsuption 0.009812s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 20/201], [loss:0.225424], accuracy:0.990563]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:21],[batch_count:1.0],[loss:0.234146],[accuracy:0.989178]
# [Epocn:21],[batch_count:2.0],[loss:0.231753],[accuracy:0.986016]
# [Epocn:21],[batch_count:3.0],[loss:0.227393],[accuracy:0.984614]
# [Epocn:21],[batch_count:4.0],[loss:0.237456],[accuracy:0.984880]
# [Epocn:21],[batch_count:5.0],[loss:0.244685],[accuracy:0.981568]
# [Epocn:21],[batch_count:6.0],[loss:0.230683],[accuracy:0.989252]
# [Epocn:21],[batch_count:7.0],[loss:0.224148],[accuracy:0.988358]
# [Epocn:21],[batch_count:8.0],[loss:0.228620],[accuracy:0.989889]
# [Epocn:21],[batch_count:9.0],[loss:0.227400],[accuracy:0.987604]
# [Epocn:21],[batch_count:10.0],[loss:0.230026],[accuracy:0.984547]
# [Epoch 21/201], [loss:0.231631], accuracy:0.986591]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:22],[batch_count:1.0],[loss:0.228865],[accuracy:0.983252]
# [Epocn:22],[batch_count:2.0],[loss:0.224363],[accuracy:0.985360]
# [Epocn:22],[batch_count:3.0],[loss:0.227773],[accuracy:0.989502]
# [Epocn:22],[batch_count:4.0],[loss:0.226812],[accuracy:0.985803]
# [Epocn:22],[batch_count:5.0],[loss:0.227380],[accuracy:0.989482]
# [Epocn:22],[batch_count:6.0],[loss:0.225855],[accuracy:0.987522]
# [Epocn:22],[batch_count:7.0],[loss:0.219937],[accuracy:0.984690]
# [Epocn:22],[batch_count:8.0],[loss:0.230094],[accuracy:0.984485]
# [Epocn:22],[batch_count:9.0],[loss:0.218914],[accuracy:0.986479]
# [Epocn:22],[batch_count:10.0],[loss:0.217197],[accuracy:0.986878]
# [Epoch 22/201], [loss:0.224719], accuracy:0.986345]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:23],[batch_count:1.0],[loss:0.216473],[accuracy:0.985268]
# [Epocn:23],[batch_count:2.0],[loss:0.214675],[accuracy:0.986321]
# [Epocn:23],[batch_count:3.0],[loss:0.233602],[accuracy:0.988600]
# [Epocn:23],[batch_count:4.0],[loss:0.207944],[accuracy:0.990596]
# [Epocn:23],[batch_count:5.0],[loss:0.218688],[accuracy:0.987755]
# [Epocn:23],[batch_count:6.0],[loss:0.225553],[accuracy:0.982697]
# [Epocn:23],[batch_count:7.0],[loss:0.212112],[accuracy:0.989920]
# [Epocn:23],[batch_count:8.0],[loss:0.222130],[accuracy:0.980698]
# [Epocn:23],[batch_count:9.0],[loss:0.213663],[accuracy:0.988002]
# [Epocn:23],[batch_count:10.0],[loss:0.209138],[accuracy:0.987811]
# [Epoch 23/201], [loss:0.217398], accuracy:0.986767]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:24],[batch_count:1.0],[loss:0.213239],[accuracy:0.984099]
# [Epocn:24],[batch_count:2.0],[loss:0.207569],[accuracy:0.988125]
# [Epocn:24],[batch_count:3.0],[loss:0.208072],[accuracy:0.986182]
# [Epocn:24],[batch_count:4.0],[loss:0.216687],[accuracy:0.981469]
# [Epocn:24],[batch_count:5.0],[loss:0.202070],[accuracy:0.990021]
# [Epocn:24],[batch_count:6.0],[loss:0.205090],[accuracy:0.990183]
# [Epocn:24],[batch_count:7.0],[loss:0.201809],[accuracy:0.987819]
# [Epocn:24],[batch_count:8.0],[loss:0.219081],[accuracy:0.985744]
# [Epocn:24],[batch_count:9.0],[loss:0.205199],[accuracy:0.986935]
# [Epocn:24],[batch_count:10.0],[loss:0.204962],[accuracy:0.988376]
# [Epoch 24/201], [loss:0.208378], accuracy:0.986895]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:25],[batch_count:1.0],[loss:0.200644],[accuracy:0.987959]
# [Epocn:25],[batch_count:2.0],[loss:0.201013],[accuracy:0.989832]
# [Epocn:25],[batch_count:3.0],[loss:0.213880],[accuracy:0.987752]
# [Epocn:25],[batch_count:4.0],[loss:0.202098],[accuracy:0.984847]
# [Epocn:25],[batch_count:5.0],[loss:0.198144],[accuracy:0.989837]
# [Epocn:25],[batch_count:6.0],[loss:0.203040],[accuracy:0.984834]
# [Epocn:25],[batch_count:7.0],[loss:0.199648],[accuracy:0.988156]
# [Epocn:25],[batch_count:8.0],[loss:0.199618],[accuracy:0.990087]
# [Epocn:25],[batch_count:9.0],[loss:0.207747],[accuracy:0.985583]
# [Epocn:25],[batch_count:10.0],[loss:0.199022],[accuracy:0.984303]
# [Epoch 25/201], [loss:0.202485], accuracy:0.987319]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:26],[batch_count:1.0],[loss:0.198295],[accuracy:0.988522]
# [Epocn:26],[batch_count:2.0],[loss:0.198815],[accuracy:0.988991]
# [Epocn:26],[batch_count:3.0],[loss:0.196298],[accuracy:0.986097]
# [Epocn:26],[batch_count:4.0],[loss:0.197696],[accuracy:0.988317]
# [Epocn:26],[batch_count:5.0],[loss:0.190403],[accuracy:0.989112]
# [Epocn:26],[batch_count:6.0],[loss:0.200340],[accuracy:0.986105]
# [Epocn:26],[batch_count:7.0],[loss:0.198529],[accuracy:0.981587]
# [Epocn:26],[batch_count:8.0],[loss:0.192455],[accuracy:0.989184]
# [Epocn:26],[batch_count:9.0],[loss:0.191713],[accuracy:0.991725]
# [Epocn:26],[batch_count:10.0],[loss:0.205703],[accuracy:0.980421]
# [Epoch 26/201], [loss:0.197025], accuracy:0.987006]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:27],[batch_count:1.0],[loss:0.189156],[accuracy:0.989358]
# [Epocn:27],[batch_count:2.0],[loss:0.193462],[accuracy:0.987433]
# [Epocn:27],[batch_count:3.0],[loss:0.194056],[accuracy:0.982574]
# [Epocn:27],[batch_count:4.0],[loss:0.191974],[accuracy:0.989161]
# [Epocn:27],[batch_count:5.0],[loss:0.187694],[accuracy:0.986125]
# [Epocn:27],[batch_count:6.0],[loss:0.185060],[accuracy:0.989062]
# [Epocn:27],[batch_count:7.0],[loss:0.191732],[accuracy:0.988416]
# [Epocn:27],[batch_count:8.0],[loss:0.190138],[accuracy:0.986089]
# [Epocn:27],[batch_count:9.0],[loss:0.195450],[accuracy:0.986145]
# [Epocn:27],[batch_count:10.0],[loss:0.196320],[accuracy:0.979949]
# [Epoch 27/201], [loss:0.191504], accuracy:0.986431]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:28],[batch_count:1.0],[loss:0.183811],[accuracy:0.990033]
# [Epocn:28],[batch_count:2.0],[loss:0.188490],[accuracy:0.987144]
# [Epocn:28],[batch_count:3.0],[loss:0.196672],[accuracy:0.981270]
# [Epocn:28],[batch_count:4.0],[loss:0.192469],[accuracy:0.987346]
# [Epocn:28],[batch_count:5.0],[loss:0.182187],[accuracy:0.988275]
# [Epocn:28],[batch_count:6.0],[loss:0.189643],[accuracy:0.985938]
# [Epocn:28],[batch_count:7.0],[loss:0.188453],[accuracy:0.983814]
# [Epocn:28],[batch_count:8.0],[loss:0.176400],[accuracy:0.991186]
# [Epocn:28],[batch_count:9.0],[loss:0.177608],[accuracy:0.990546]
# [Epocn:28],[batch_count:10.0],[loss:0.197708],[accuracy:0.984882]
# [Epoch 28/201], [loss:0.187344], accuracy:0.987043]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:29],[batch_count:1.0],[loss:0.196173],[accuracy:0.980866]
# [Epocn:29],[batch_count:2.0],[loss:0.176110],[accuracy:0.990143]
# [Epocn:29],[batch_count:3.0],[loss:0.177739],[accuracy:0.988674]
# [Epocn:29],[batch_count:4.0],[loss:0.182715],[accuracy:0.985203]
# [Epocn:29],[batch_count:5.0],[loss:0.187578],[accuracy:0.984581]
# [Epocn:29],[batch_count:6.0],[loss:0.174059],[accuracy:0.990537]
# [Epocn:29],[batch_count:7.0],[loss:0.179416],[accuracy:0.988510]
# [Epocn:29],[batch_count:8.0],[loss:0.176734],[accuracy:0.989896]
# [Epocn:29],[batch_count:9.0],[loss:0.177374],[accuracy:0.985229]
# [Epocn:29],[batch_count:10.0],[loss:0.215144],[accuracy:0.980439]
# [Epoch 29/201], [loss:0.184304], accuracy:0.986408]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:30],[batch_count:1.0],[loss:0.182149],[accuracy:0.980655]
# [Epocn:30],[batch_count:2.0],[loss:0.174493],[accuracy:0.988593]
# [Epocn:30],[batch_count:3.0],[loss:0.183735],[accuracy:0.989801]
# [Epocn:30],[batch_count:4.0],[loss:0.171980],[accuracy:0.989299]
# [Epocn:30],[batch_count:5.0],[loss:0.171970],[accuracy:0.990707]
# [Epocn:30],[batch_count:6.0],[loss:0.192500],[accuracy:0.980018]
# [Epocn:30],[batch_count:7.0],[loss:0.186354],[accuracy:0.980927]
# [Epocn:30],[batch_count:8.0],[loss:0.167889],[accuracy:0.990264]
# [Epocn:30],[batch_count:9.0],[loss:0.174449],[accuracy:0.987860]
# [Epocn:30],[batch_count:10.0],[loss:0.170188],[accuracy:0.990293]
# [Epoch 30/201], [loss:0.177571], accuracy:0.986842]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 30
# ------------------------------------------------------------------------------------------
# count:153600,TP:1326,TN:151215,FP:554,FN505
# processing image NO 0, time comsuption 0.007806s
# count:153600,TP:1326,TN:150850,FP:513,FN911
# processing image NO 1, time comsuption 0.008140s
# count:153600,TP:1969,TN:149716,FP:656,FN1259
# processing image NO 2, time comsuption 0.007587s
# count:153600,TP:925,TN:150575,FP:842,FN1258
# processing image NO 3, time comsuption 0.007785s
# count:153600,TP:1229,TN:151370,FP:792,FN209
# processing image NO 4, time comsuption 0.008025s
# count:153600,TP:1256,TN:151322,FP:735,FN287
# processing image NO 5, time comsuption 0.009354s
# count:153600,TP:1469,TN:150825,FP:754,FN552
# processing image NO 6, time comsuption 0.009019s
# count:153600,TP:1672,TN:150924,FP:512,FN492
# processing image NO 7, time comsuption 0.007997s
# count:153600,TP:1033,TN:151377,FP:828,FN362
# processing image NO 8, time comsuption 0.007620s
# count:153600,TP:1003,TN:150622,FP:1722,FN253
# processing image NO 9, time comsuption 0.007684s
# count:153600,TP:1086,TN:150498,FP:844,FN1172
# processing image NO 10, time comsuption 0.011670s
# count:153600,TP:1126,TN:151237,FP:970,FN267
# processing image NO 11, time comsuption 0.009494s
# count:153600,TP:859,TN:151099,FP:1162,FN480
# processing image NO 12, time comsuption 0.007708s
# count:153600,TP:660,TN:150671,FP:1616,FN653
# processing image NO 13, time comsuption 0.007833s
# count:153600,TP:874,TN:150961,FP:1021,FN744
# processing image NO 14, time comsuption 0.008112s
# count:153600,TP:1035,TN:151007,FP:864,FN694
# processing image NO 15, time comsuption 0.007826s
# count:153600,TP:1521,TN:150645,FP:658,FN776
# processing image NO 16, time comsuption 0.007514s
# count:153600,TP:866,TN:151423,FP:960,FN351
# processing image NO 17, time comsuption 0.007853s
# count:153600,TP:1062,TN:151058,FP:893,FN587
# processing image NO 18, time comsuption 0.007718s
# count:153600,TP:900,TN:151132,FP:835,FN733
# processing image NO 19, time comsuption 0.007987s
# count:153600,TP:1060,TN:151331,FP:683,FN526
# processing image NO 20, time comsuption 0.007825s
# count:153600,TP:1242,TN:150438,FP:999,FN921
# processing image NO 21, time comsuption 0.007721s
# count:153600,TP:1059,TN:150927,FP:1164,FN450
# processing image NO 22, time comsuption 0.007796s
# count:153600,TP:1279,TN:150774,FP:696,FN851
# processing image NO 23, time comsuption 0.008987s
# count:153600,TP:882,TN:151436,FP:891,FN391
# processing image NO 24, time comsuption 0.007672s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 30/201], [loss:0.168345], accuracy:0.990134]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:31],[batch_count:1.0],[loss:0.187935],[accuracy:0.987398]
# [Epocn:31],[batch_count:2.0],[loss:0.180999],[accuracy:0.985865]
# [Epocn:31],[batch_count:3.0],[loss:0.169046],[accuracy:0.989565]
# [Epocn:31],[batch_count:4.0],[loss:0.177787],[accuracy:0.982950]
# [Epocn:31],[batch_count:5.0],[loss:0.172175],[accuracy:0.987829]
# [Epocn:31],[batch_count:6.0],[loss:0.171626],[accuracy:0.988196]
# [Epocn:31],[batch_count:7.0],[loss:0.173490],[accuracy:0.985118]
# [Epocn:31],[batch_count:8.0],[loss:0.183906],[accuracy:0.984606]
# [Epocn:31],[batch_count:9.0],[loss:0.166365],[accuracy:0.990913]
# [Epocn:31],[batch_count:10.0],[loss:0.175454],[accuracy:0.984195]
# [Epoch 31/201], [loss:0.175878], accuracy:0.986663]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:32],[batch_count:1.0],[loss:0.177172],[accuracy:0.980751]
# [Epocn:32],[batch_count:2.0],[loss:0.161076],[accuracy:0.990579]
# [Epocn:32],[batch_count:3.0],[loss:0.178579],[accuracy:0.981483]
# [Epocn:32],[batch_count:4.0],[loss:0.171301],[accuracy:0.987635]
# [Epocn:32],[batch_count:5.0],[loss:0.167163],[accuracy:0.989645]
# [Epocn:32],[batch_count:6.0],[loss:0.167643],[accuracy:0.986825]
# [Epocn:32],[batch_count:7.0],[loss:0.170834],[accuracy:0.987936]
# [Epocn:32],[batch_count:8.0],[loss:0.170488],[accuracy:0.988058]
# [Epocn:32],[batch_count:9.0],[loss:0.164476],[accuracy:0.990485]
# [Epocn:32],[batch_count:10.0],[loss:0.168822],[accuracy:0.989217]
# [Epoch 32/201], [loss:0.169755], accuracy:0.987261]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:33],[batch_count:1.0],[loss:0.172049],[accuracy:0.987938]
# [Epocn:33],[batch_count:2.0],[loss:0.174586],[accuracy:0.987436]
# [Epocn:33],[batch_count:3.0],[loss:0.167467],[accuracy:0.984409]
# [Epocn:33],[batch_count:4.0],[loss:0.160619],[accuracy:0.989971]
# [Epocn:33],[batch_count:5.0],[loss:0.170773],[accuracy:0.981998]
# [Epocn:33],[batch_count:6.0],[loss:0.165249],[accuracy:0.985184]
# [Epocn:33],[batch_count:7.0],[loss:0.162853],[accuracy:0.990385]
# [Epocn:33],[batch_count:8.0],[loss:0.161522],[accuracy:0.991162]
# [Epocn:33],[batch_count:9.0],[loss:0.156652],[accuracy:0.989635]
# [Epocn:33],[batch_count:10.0],[loss:0.174840],[accuracy:0.982383]
# [Epoch 33/201], [loss:0.166661], accuracy:0.987050]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:34],[batch_count:1.0],[loss:0.158141],[accuracy:0.991552]
# [Epocn:34],[batch_count:2.0],[loss:0.155311],[accuracy:0.990738]
# [Epocn:34],[batch_count:3.0],[loss:0.162541],[accuracy:0.984561]
# [Epocn:34],[batch_count:4.0],[loss:0.170242],[accuracy:0.985258]
# [Epocn:34],[batch_count:5.0],[loss:0.163745],[accuracy:0.989886]
# [Epocn:34],[batch_count:6.0],[loss:0.161670],[accuracy:0.985804]
# [Epocn:34],[batch_count:7.0],[loss:0.165257],[accuracy:0.984335]
# [Epocn:34],[batch_count:8.0],[loss:0.166134],[accuracy:0.990495]
# [Epocn:34],[batch_count:9.0],[loss:0.152291],[accuracy:0.989594]
# [Epocn:34],[batch_count:10.0],[loss:0.170941],[accuracy:0.978893]
# [Epoch 34/201], [loss:0.162627], accuracy:0.987112]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:35],[batch_count:1.0],[loss:0.157419],[accuracy:0.986890]
# [Epocn:35],[batch_count:2.0],[loss:0.166223],[accuracy:0.983823]
# [Epocn:35],[batch_count:3.0],[loss:0.157702],[accuracy:0.989184]
# [Epocn:35],[batch_count:4.0],[loss:0.160705],[accuracy:0.989447]
# [Epocn:35],[batch_count:5.0],[loss:0.165874],[accuracy:0.991321]
# [Epocn:35],[batch_count:6.0],[loss:0.161275],[accuracy:0.985208]
# [Epocn:35],[batch_count:7.0],[loss:0.169741],[accuracy:0.980352]
# [Epocn:35],[batch_count:8.0],[loss:0.167619],[accuracy:0.982365]
# [Epocn:35],[batch_count:9.0],[loss:0.155577],[accuracy:0.986021]
# [Epocn:35],[batch_count:10.0],[loss:0.151029],[accuracy:0.990592]
# [Epoch 35/201], [loss:0.161316], accuracy:0.986520]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:36],[batch_count:1.0],[loss:0.168531],[accuracy:0.987298]
# [Epocn:36],[batch_count:2.0],[loss:0.169510],[accuracy:0.983353]
# [Epocn:36],[batch_count:3.0],[loss:0.152832],[accuracy:0.989827]
# [Epocn:36],[batch_count:4.0],[loss:0.153576],[accuracy:0.987719]
# [Epocn:36],[batch_count:5.0],[loss:0.152164],[accuracy:0.985691]
# [Epocn:36],[batch_count:6.0],[loss:0.165113],[accuracy:0.980911]
# [Epocn:36],[batch_count:7.0],[loss:0.160026],[accuracy:0.985600]
# [Epocn:36],[batch_count:8.0],[loss:0.148241],[accuracy:0.990777]
# [Epocn:36],[batch_count:9.0],[loss:0.147393],[accuracy:0.991050]
# [Epocn:36],[batch_count:10.0],[loss:0.152458],[accuracy:0.986138]
# [Epoch 36/201], [loss:0.156984], accuracy:0.986837]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:37],[batch_count:1.0],[loss:0.150831],[accuracy:0.989633]
# [Epocn:37],[batch_count:2.0],[loss:0.156236],[accuracy:0.989557]
# [Epocn:37],[batch_count:3.0],[loss:0.155546],[accuracy:0.988395]
# [Epocn:37],[batch_count:4.0],[loss:0.148467],[accuracy:0.985884]
# [Epocn:37],[batch_count:5.0],[loss:0.153037],[accuracy:0.985988]
# [Epocn:37],[batch_count:6.0],[loss:0.152706],[accuracy:0.981736]
# [Epocn:37],[batch_count:7.0],[loss:0.149554],[accuracy:0.987325]
# [Epocn:37],[batch_count:8.0],[loss:0.149398],[accuracy:0.989005]
# [Epocn:37],[batch_count:9.0],[loss:0.153945],[accuracy:0.983522]
# [Epocn:37],[batch_count:10.0],[loss:0.147767],[accuracy:0.990707]
# [Epoch 37/201], [loss:0.151749], accuracy:0.987175]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:38],[batch_count:1.0],[loss:0.152716],[accuracy:0.984127]
# [Epocn:38],[batch_count:2.0],[loss:0.140956],[accuracy:0.990637]
# [Epocn:38],[batch_count:3.0],[loss:0.149777],[accuracy:0.987076]
# [Epocn:38],[batch_count:4.0],[loss:0.148596],[accuracy:0.989127]
# [Epocn:38],[batch_count:5.0],[loss:0.150897],[accuracy:0.983679]
# [Epocn:38],[batch_count:6.0],[loss:0.150205],[accuracy:0.990320]
# [Epocn:38],[batch_count:7.0],[loss:0.148225],[accuracy:0.985985]
# [Epocn:38],[batch_count:8.0],[loss:0.146575],[accuracy:0.988594]
# [Epocn:38],[batch_count:9.0],[loss:0.142384],[accuracy:0.990470]
# [Epocn:38],[batch_count:10.0],[loss:0.148240],[accuracy:0.987365]
# [Epoch 38/201], [loss:0.147857], accuracy:0.987738]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:39],[batch_count:1.0],[loss:0.144947],[accuracy:0.989257]
# [Epocn:39],[batch_count:2.0],[loss:0.141361],[accuracy:0.989984]
# [Epocn:39],[batch_count:3.0],[loss:0.146446],[accuracy:0.985418]
# [Epocn:39],[batch_count:4.0],[loss:0.144295],[accuracy:0.990534]
# [Epocn:39],[batch_count:5.0],[loss:0.145249],[accuracy:0.988889]
# [Epocn:39],[batch_count:6.0],[loss:0.136152],[accuracy:0.989523]
# [Epocn:39],[batch_count:7.0],[loss:0.147216],[accuracy:0.989086]
# [Epocn:39],[batch_count:8.0],[loss:0.143467],[accuracy:0.985883]
# [Epocn:39],[batch_count:9.0],[loss:0.145668],[accuracy:0.985745]
# [Epocn:39],[batch_count:10.0],[loss:0.147516],[accuracy:0.986316]
# [Epoch 39/201], [loss:0.144232], accuracy:0.988063]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:40],[batch_count:1.0],[loss:0.140456],[accuracy:0.990860]
# [Epocn:40],[batch_count:2.0],[loss:0.136715],[accuracy:0.990543]
# [Epocn:40],[batch_count:3.0],[loss:0.137903],[accuracy:0.989663]
# [Epocn:40],[batch_count:4.0],[loss:0.154032],[accuracy:0.981861]
# [Epocn:40],[batch_count:5.0],[loss:0.139775],[accuracy:0.990208]
# [Epocn:40],[batch_count:6.0],[loss:0.144618],[accuracy:0.986861]
# [Epocn:40],[batch_count:7.0],[loss:0.136571],[accuracy:0.989133]
# [Epocn:40],[batch_count:8.0],[loss:0.135753],[accuracy:0.989193]
# [Epocn:40],[batch_count:9.0],[loss:0.146519],[accuracy:0.984255]
# [Epocn:40],[batch_count:10.0],[loss:0.136029],[accuracy:0.989616]
# [Epoch 40/201], [loss:0.140837], accuracy:0.988219]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 40
# ------------------------------------------------------------------------------------------
# count:153600,TP:1343,TN:151248,FP:521,FN488
# processing image NO 0, time comsuption 0.008023s
# count:153600,TP:1358,TN:151051,FP:312,FN879
# processing image NO 1, time comsuption 0.007696s
# count:153600,TP:2056,TN:149741,FP:631,FN1172
# processing image NO 2, time comsuption 0.007955s
# count:153600,TP:1184,TN:150788,FP:629,FN999
# processing image NO 3, time comsuption 0.007836s
# count:153600,TP:1247,TN:151481,FP:681,FN191
# processing image NO 4, time comsuption 0.007524s
# count:153600,TP:1330,TN:151522,FP:535,FN213
# processing image NO 5, time comsuption 0.007620s
# count:153600,TP:1597,TN:151026,FP:553,FN424
# processing image NO 6, time comsuption 0.007742s
# count:153600,TP:1715,TN:151004,FP:432,FN449
# processing image NO 7, time comsuption 0.007600s
# count:153600,TP:1083,TN:151420,FP:785,FN312
# processing image NO 8, time comsuption 0.008048s
# count:153600,TP:981,TN:150572,FP:1772,FN275
# processing image NO 9, time comsuption 0.007754s
# count:153600,TP:1226,TN:150461,FP:881,FN1032
# processing image NO 10, time comsuption 0.007643s
# count:153600,TP:1136,TN:151313,FP:894,FN257
# processing image NO 11, time comsuption 0.007749s
# count:153600,TP:946,TN:151301,FP:960,FN393
# processing image NO 12, time comsuption 0.008088s
# count:153600,TP:717,TN:151233,FP:1054,FN596
# processing image NO 13, time comsuption 0.007643s
# count:153600,TP:1037,TN:151067,FP:915,FN581
# processing image NO 14, time comsuption 0.007646s
# count:153600,TP:1120,TN:151133,FP:738,FN609
# processing image NO 15, time comsuption 0.011776s
# count:153600,TP:1482,TN:150640,FP:663,FN815
# processing image NO 16, time comsuption 0.007677s
# count:153600,TP:940,TN:151578,FP:805,FN277
# processing image NO 17, time comsuption 0.007646s
# count:153600,TP:1157,TN:151097,FP:854,FN492
# processing image NO 18, time comsuption 0.007715s
# count:153600,TP:1031,TN:151255,FP:712,FN602
# processing image NO 19, time comsuption 0.007837s
# count:153600,TP:1154,TN:151430,FP:584,FN432
# processing image NO 20, time comsuption 0.007503s
# count:153600,TP:1509,TN:150390,FP:1047,FN654
# processing image NO 21, time comsuption 0.007721s
# count:153600,TP:1074,TN:151239,FP:852,FN435
# processing image NO 22, time comsuption 0.007732s
# count:153600,TP:1580,TN:150781,FP:689,FN550
# processing image NO 23, time comsuption 0.007994s
# count:153600,TP:909,TN:151571,FP:756,FN364
# processing image NO 24, time comsuption 0.007601s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 40/201], [loss:0.131518], accuracy:0.991463]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:41],[batch_count:1.0],[loss:0.153639],[accuracy:0.980496]
# [Epocn:41],[batch_count:2.0],[loss:0.138941],[accuracy:0.989891]
# [Epocn:41],[batch_count:3.0],[loss:0.133899],[accuracy:0.990461]
# [Epocn:41],[batch_count:4.0],[loss:0.157725],[accuracy:0.978643]
# [Epocn:41],[batch_count:5.0],[loss:0.133973],[accuracy:0.990441]
# [Epocn:41],[batch_count:6.0],[loss:0.130810],[accuracy:0.992044]
# [Epocn:41],[batch_count:7.0],[loss:0.138849],[accuracy:0.988363]
# [Epocn:41],[batch_count:8.0],[loss:0.136811],[accuracy:0.989250]
# [Epocn:41],[batch_count:9.0],[loss:0.134767],[accuracy:0.989544]
# [Epocn:41],[batch_count:10.0],[loss:0.143531],[accuracy:0.988582]
# [Epoch 41/201], [loss:0.140294], accuracy:0.987772]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:42],[batch_count:1.0],[loss:0.134808],[accuracy:0.990144]
# [Epocn:42],[batch_count:2.0],[loss:0.135263],[accuracy:0.989644]
# [Epocn:42],[batch_count:3.0],[loss:0.133614],[accuracy:0.988735]
# [Epocn:42],[batch_count:4.0],[loss:0.132601],[accuracy:0.989936]
# [Epocn:42],[batch_count:5.0],[loss:0.134277],[accuracy:0.990063]
# [Epocn:42],[batch_count:6.0],[loss:0.133644],[accuracy:0.988419]
# [Epocn:42],[batch_count:7.0],[loss:0.145177],[accuracy:0.982504]
# [Epocn:42],[batch_count:8.0],[loss:0.141041],[accuracy:0.988582]
# [Epocn:42],[batch_count:9.0],[loss:0.134307],[accuracy:0.989780]
# [Epocn:42],[batch_count:10.0],[loss:0.148400],[accuracy:0.978365]
# [Epoch 42/201], [loss:0.137313], accuracy:0.987617]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:43],[batch_count:1.0],[loss:0.135472],[accuracy:0.988985]
# [Epocn:43],[batch_count:2.0],[loss:0.133336],[accuracy:0.988060]
# [Epocn:43],[batch_count:3.0],[loss:0.138382],[accuracy:0.986875]
# [Epocn:43],[batch_count:4.0],[loss:0.138988],[accuracy:0.988745]
# [Epocn:43],[batch_count:5.0],[loss:0.129953],[accuracy:0.990679]
# [Epocn:43],[batch_count:6.0],[loss:0.132163],[accuracy:0.988635]
# [Epocn:43],[batch_count:7.0],[loss:0.144475],[accuracy:0.978558]
# [Epocn:43],[batch_count:8.0],[loss:0.134029],[accuracy:0.988366]
# [Epocn:43],[batch_count:9.0],[loss:0.133521],[accuracy:0.986911]
# [Epocn:43],[batch_count:10.0],[loss:0.138803],[accuracy:0.989505]
# [Epoch 43/201], [loss:0.135912], accuracy:0.987532]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:44],[batch_count:1.0],[loss:0.133072],[accuracy:0.986326]
# [Epocn:44],[batch_count:2.0],[loss:0.131526],[accuracy:0.988762]
# [Epocn:44],[batch_count:3.0],[loss:0.129110],[accuracy:0.989164]
# [Epocn:44],[batch_count:4.0],[loss:0.138392],[accuracy:0.982862]
# [Epocn:44],[batch_count:5.0],[loss:0.131350],[accuracy:0.990486]
# [Epocn:44],[batch_count:6.0],[loss:0.137023],[accuracy:0.988286]
# [Epocn:44],[batch_count:7.0],[loss:0.127338],[accuracy:0.989533]
# [Epocn:44],[batch_count:8.0],[loss:0.125466],[accuracy:0.991769]
