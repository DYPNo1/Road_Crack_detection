# %%
# !nvidia-smi # 查看GPU信息
# Out:
# Fri Jun 12 17:01:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 进入需要训练项目的文件夹
# %cd /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrack
# Out:
# /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrack

# %%
# !pip install xlutils
# Out:
# Collecting xlutils
#   Downloading https://files.pythonhosted.org/packages/c7/55/e22ac73dbb316cabb5db28bef6c87044a95914f713a6e81b593f8a0d2f79/xlutils-2.0.0-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 6.2MB/s
# Requirement already satisfied: xlrd>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.1.0)
# Requirement already satisfied: xlwt>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.3.0)
# Installing collected packages: xlutils
# Successfully installed xlutils-2.0.0

# %%
from models_deepcrack import SegmentNet, weights_init_normal
from dataset_deepcrack import CFDDataset

import torch.nn as nn
import torch

from torchvision import datasets
from torchvision.utils import save_image
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

import os
import sys
import argparse
import time
import PIL.Image as Image

import numpy as np

import xlwt
import xlrd
from xlutils.copy import copy

# %%
# 在ipynb文件中，parse的创建用函数来创建
# 直接用parser=parser = argparse.ArgumentParser() 来创建之后调用会报错

def get_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--cuda", type=bool, default=True, help="number of gpu")
    parser.add_argument("--gpu_num", type=int, default=1, help="number of gpu")
    parser.add_argument("--worker_num", type=int, default=0, help="number of input workers") # 只有一个GPU,default=0表示单进程加载
    parser.add_argument("--batch_size", type=int, default=6, help="batch size of input")
    parser.add_argument("--lr", type=float, default=0.01, help="adam: learning rate")
    parser.add_argument("--b1", type=float, default=0.90, help="adam: decay of first order momentum of gradient")
    parser.add_argument("--b2", type=float, default=0.997, help="adam: decay of second order momentum of gradient")
    parser.add_argument("--weight_decay", type=float, default=0.0005, help="adam: weight decay coefficient")

    parser.add_argument("--begin_epoch", type=int, default=1, help="begin_epoch")
    parser.add_argument("--end_epoch", type=int, default=201, help="end_epoch")

    parser.add_argument("--need_test", type=bool, default=True, help="need to test")
    parser.add_argument("--test_interval", type=int, default=10, help="interval of test")
    parser.add_argument("--need_save", type=bool, default=True, help="need to save")
    parser.add_argument("--save_interval", type=int, default=10, help="interval of save weights")

    parser.add_argument("--img_width", type=int, default=480, help="size of image width")
    parser.add_argument("--img_height", type=int, default=320, help="size of image height")
    
    return parser.parse_args(args=[])

opt = get_arguments()

print(opt)
# Out:
# Namespace(b1=0.9, b2=0.997, batch_size=6, begin_epoch=1, cuda=True, end_epoch=201, gpu_num=1, img_height=320, img_width=480, lr=0.01, need_save=True, need_test=True, save_interval=10, test_interval=10, weight_decay=0.0005, worker_num=0)

# %%
dataSetRoot = "../Data_cleaned"

# %%
# 建立网络
segment_net = SegmentNet(init_weights=True)

# 选择二分类交叉熵损失函数
criterion_segment  = torch.nn.BCELoss()

# %%
# 选择Adam优化器
optimizer_seg = torch.optim.Adam(segment_net.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=opt.weight_decay)

# 指数方式调整学习率，每一个epoch之后学习率变为原来的0.98倍
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_seg, gamma=0.98)

# %%
# 选择训练环境和参数
if opt.cuda:
    segment_net = segment_net.cuda()
    criterion_segment.cuda()

if opt.gpu_num > 1:
    segment_net = torch.nn.DataParallel(segment_net, device_ids=list(range(opt.gpu_num)))

if opt.begin_epoch != 1:
    # 加载前期训练的模型
    segment_net.load_state_dict(torch.load("./saved_models/segment_net_%d.pth" % (opt.begin_epoch-1)))
else:
    # 初始化权重
    segment_net.apply(weights_init_normal)

# %%
# 对原始数据和真实值进行一定前期处理，方便后续训练
transforms_ = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width), Image.BICUBIC),
    transforms.ToTensor()
])

transforms_mask = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width)), 
    transforms.ToTensor()
])

# %%
# 加载训练集和测试集
trainCFDloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask, subFold="CFD", isTrain=True),
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.worker_num,
)

testloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask,  subFold="CFD/cfd_TEST", isTrain=True),
    batch_size=1,
    shuffle=False,
    num_workers=opt.worker_num
)

# %%
# 定义对输出结果进行阈值化处理的函数，将小于阈值的计算为0，大于阈值的计算为1，在图像中像素为1的点为白色，为0的点为黑色
def data_threshold(data, threshold):
    threshold = torch.Tensor([threshold]).cuda()
    data_target = torch.Tensor([i//threshold for i in data]).cuda()
    return data_target

# %%
# 获取训练之后的 accuracy, precision , recall ,F1评价指标
# mask是真实值，data是预测值
def evaluate_metric(mask, data):
    m = metrics.confusion_matrix(mask, data)
    count_TP = m[1, 1]
    count_TN = m[0, 0]
    count_FN = m[1, 0] 
    count_FP = m[0 ,1]
    
    count = count_TP + count_FN + count_FP +count_TN
    print("count:{0},TP:{1},TN:{2},FP:{3},FN:{4}".format(count, count_TP, count_TN, count_FP, count_FN))  
    
    # 准确率
    accuracy = (count_TP+count_TN)/count 
    # 精准率
    precision = count_TP / (count_TP + count_FP) 
    # 查全率
    recall = count_TP / (count_TP + count_FN)
    # F1分
    F1 = 2*count_TP/(2*count_TP + count_FP + count_FN)
    
    return accuracy, precision, recall, F1

# %%
if opt.begin_epoch == 1:
  # 将训练过程的需要保存的数据保存到xls文件中
  # 创建一个workbook，设置编码
  workbook = xlwt.Workbook(encoding = 'utf-8')

  #---------------------写入训练过程的epoch, loss, accuracy------------------
  # 创建一个worksheet
  worksheet = workbook.add_sheet('sheet1')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')

  #---------------------写入测试过程的epoch, loss, accuracy------------------
  worksheet = workbook.add_sheet('sheet2')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')
                  
  #---------------------写入测试过程的epoch, accuracy, precision, recall, F1------------------                
  worksheet = workbook.add_sheet('sheet3')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'accuracy')
  worksheet.write(0, 2, 'precision')
  worksheet.write(0, 3, 'recall')
  worksheet.write(0, 4, 'F1')

  # 保存
  workbook.save('evaluate_data.xls')

def write_excel_xls_append(path, value, sheet_num):
  index = len(value)  # 获取需要写入数据的行数
  workbook = xlrd.open_workbook(path)            # 打开工作簿
  sheets = workbook.sheet_names()                # 获取工作簿中的所有表格
  worksheet = workbook.sheet_by_name(sheets[sheet_num])  # 获取工作簿中所有表格中的的第一个表格
  rows_old = worksheet.nrows                 # 获取表格中已存在的数据的行数
  new_workbook = copy(workbook)                # 将xlrd对象拷贝转化为xlwt对象
  new_worksheet = new_workbook.get_sheet(sheet_num)      # 获取转化后工作簿中的第sheet_num个表格
  
  for i in range(0, index):
      new_worksheet.write(rows_old, i, value[i])  # 追加写入数据
  new_workbook.save(path)  # 保存工作簿
  print("xls格式表格[追加]写入数据成功！")

# %%
for epoch in range(opt.begin_epoch, opt.end_epoch):

  iterCFD = trainCFDloader.__iter__()

  lenNum = len(trainCFDloader)

  segment_net.train()

  # -----------------------------------------------------------------------------
  # 开始训练
  # 记录每一个epoch的总损失和总精度
  train_loss_sum, train_acc_sum, batch_count = 0.0, 0.0, 0.0

  for i in range(0, lenNum):
      
    batchData = iterCFD.__next__()

    if opt.cuda:
        img = batchData["img"].cuda()
        mask = batchData["mask"].cuda()
    else:
        img = batchData["img"]
        mask = batchData["mask"]

    optimizer_seg.zero_grad()

    rst = segment_net(img)
    seg = rst["seg"]

    # 计算训练过程的损失loss
    loss_seg = 0.45*criterion_segment(seg, mask)+0.25*criterion_segment(rst["scale4"], mask)+0.15*criterion_segment(rst["scale3"], mask)\
            +0.1*criterion_segment(rst["scale2"], mask)+0.05*criterion_segment(rst["scale1"], mask)
    loss_seg.backward()
    optimizer_seg.step()

    train_loss_sum += loss_seg.item() 
    
    # 计算训练过程的accuracy
    net_seg = data_threshold(seg.clone().flatten(), 0.5)    # 预测值
    mask_seg = mask.clone().flatten()              # 真实值
    
    # 对每个像素点的值进行比较，相同的点计入right_seg 
    right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
    total_num = float(mask.clone().flatten().size()[0])
    
    batch_acc = right_seg/total_num
    train_acc_sum += batch_acc
    
    batch_count += 1
    
    # 输出每个epoch之中每个batch的信息
    print("[Epocn:{0}],[batch_count:{1}],[loss:{2:.6f}],[accuracy:{3:.6f}]".format(epoch, batch_count, loss_seg.item(), batch_acc))
    

  
  # 输出训练过程每个epoch平均的loss和accuracy
  print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, train_loss_sum/batch_count, train_acc_sum/batch_count))
    
  # 将上述epoch, loss, accuracy数据写入xls文件
  print("------------------------------------------------------------------------------------------")
  print("开始写入训练过程的epoch, loss, accuracy")
  train_xls_value = [epoch, train_loss_sum/batch_count, train_acc_sum/batch_count]
  write_excel_xls_append("evaluate_data.xls", train_xls_value, 0)
  print("------------------------------------------------------------------------------------------")
  

  # -----------------------------------------------------------------------------
  # 以一定周期保存训练之后的模型
  if opt.need_save and epoch % opt.save_interval == 0 and epoch >= opt.save_interval:

    save_path_str = "./saved_models"
    if os.path.exists(save_path_str) == False:
        os.makedirs(save_path_str, exist_ok=True)

    torch.save(segment_net.state_dict(), "%s/segment_net_%d.pth" % (save_path_str, epoch))
    print("------------------------------------------------------------------------------------------")
    print("save weights ! epoch = %d" %epoch)
    print("------------------------------------------------------------------------------------------")
    pass
    

  # -----------------------------------------------------------------------------
  # 对模型进行测试，并保存结果
  if opt.need_test and epoch % opt.test_interval == 0 and epoch >= opt.test_interval:

    test_loss_sum, test_acc_sum, batch_count = 0.0, 0.0, 0.0
    result_evaluate_epoch = np.array([0.0, 0.0, 0.0, 0.0])

    for i, testBatch in enumerate(testloader):
      imgTest = testBatch["img"].cuda()
      t1 = time.time()
      rstTest = segment_net(imgTest)
      t2 = time.time()

      # 计算测试过程的损失loss
      mask = testBatch["mask"].cuda()
      loss_test = criterion_segment(rstTest["seg"], mask)

      test_loss_sum += loss_test.item()

      # 计算测试过程的accuracy
      net_seg = data_threshold(rstTest["seg"].clone().flatten(), 0.5)  # 预测值
      mask_seg = mask.clone().flatten()                  # 真实值
      
      # 对每个像素点的值进行比较，相同的点计入right_seg 
      right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
      total_num = float(mask.clone().flatten().size()[0])
      
      batch_acc = right_seg/total_num
      test_acc_sum += batch_acc
      
      batch_count += 1

      # 对一个batch测试结果进行综合评估，并进行累加，方便后续保存
      result_evaluate_batch = np.array(list(evaluate_metric(mask_seg, net_seg)))
      result_evaluate_epoch += result_evaluate_batch
      
      # 对保存的图片进行阈值化处理
      seg_shape = rstTest["seg"].data.shape
      segTest_flatten = data_threshold(rstTest["seg"].flatten(), 0.5)
      segTest = segTest_flatten.reshape(seg_shape[0], seg_shape[1], seg_shape[2], seg_shape[3])

      # 建立文件的保存路径
      save_path_str = "./testResultSeg/epoch_%d"%(epoch)
      if os.path.exists(save_path_str) == False:
          os.makedirs(save_path_str, exist_ok=True)

      # 输出文件的保存信息
      print("processing image NO %d, time comsuption %fs"%(i, t2 - t1))
      save_image(imgTest.data, "%s/img_%d.jpg"% (save_path_str, i))
      save_image(segTest.data, "%s/img_%d_seg.jpg"% (save_path_str, i))

    # 将上述测试过程的评估参数acc,precision,recall和F1分数进行保存
    print("------------------------------------------------------------------------------------------")
    print("开始写入评估参数")
    result_evaluate_epoch = result_evaluate_epoch/np.array([batch_count])
    test_xls_metric = [epoch] + list(result_evaluate_epoch)
    write_excel_xls_append("evaluate_data.xls", test_xls_metric, 2)
    print("------------------------------------------------------------------------------------------")
    
    # 输出测试过程每个epoch平均的loss和accuracy
    print("------------------------------------------------------------------------------------------")
    print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, test_loss_sum/batch_count, test_acc_sum/batch_count))
    print("------------------------------------------------------------------------------------------")
    
    # 将上述epoch, loss, accuracy数据写入xls文件
    print("------------------------------------------------------------------------------------------")
    print("开始写入测试过程的epoch, loss, accuracy")
    test_xls_value = [epoch, test_loss_sum/batch_count, test_acc_sum/batch_count]
    write_excel_xls_append("evaluate_data.xls", test_xls_value, 1)
    print("------------------------------------------------------------------------------------------")

  # 利用schedular对学习率进行调节
  scheduler.step()
# Out:
# [Epocn:1],[batch_count:1.0],[loss:0.794308],[accuracy:0.502155]
# [Epocn:1],[batch_count:2.0],[loss:0.711865],[accuracy:0.770319]
# [Epocn:1],[batch_count:3.0],[loss:0.694617],[accuracy:0.817439]
# [Epocn:1],[batch_count:4.0],[loss:0.718551],[accuracy:0.837375]
# [Epocn:1],[batch_count:5.0],[loss:0.687266],[accuracy:0.827793]
# [Epocn:1],[batch_count:6.0],[loss:0.676303],[accuracy:0.813046]
# [Epocn:1],[batch_count:7.0],[loss:0.672217],[accuracy:0.872658]
# [Epocn:1],[batch_count:8.0],[loss:0.659474],[accuracy:0.890514]
# [Epocn:1],[batch_count:9.0],[loss:0.661968],[accuracy:0.889335]
# [Epocn:1],[batch_count:10.0],[loss:0.666257],[accuracy:0.886763]
# [Epoch 1/201], [loss:0.694283], accuracy:0.810740]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:2],[batch_count:1.0],[loss:0.638397],[accuracy:0.912012]
# [Epocn:2],[batch_count:2.0],[loss:0.650457],[accuracy:0.846938]
# [Epocn:2],[batch_count:3.0],[loss:0.624922],[accuracy:0.939950]
# [Epocn:2],[batch_count:4.0],[loss:0.621276],[accuracy:0.938568]
# [Epocn:2],[batch_count:5.0],[loss:0.635039],[accuracy:0.934155]
# [Epocn:2],[batch_count:6.0],[loss:0.613839],[accuracy:0.941854]
# [Epocn:2],[batch_count:7.0],[loss:0.606227],[accuracy:0.959517]
# [Epocn:2],[batch_count:8.0],[loss:0.609168],[accuracy:0.930881]
# [Epocn:2],[batch_count:9.0],[loss:0.589326],[accuracy:0.951037]
# [Epocn:2],[batch_count:10.0],[loss:0.598659],[accuracy:0.940409]
# [Epoch 2/201], [loss:0.618731], accuracy:0.929532]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:3],[batch_count:1.0],[loss:0.610396],[accuracy:0.922363]
# [Epocn:3],[batch_count:2.0],[loss:0.601537],[accuracy:0.947465]
# [Epocn:3],[batch_count:3.0],[loss:0.586508],[accuracy:0.949460]
# [Epocn:3],[batch_count:4.0],[loss:0.596649],[accuracy:0.950547]
# [Epocn:3],[batch_count:5.0],[loss:0.573855],[accuracy:0.953181]
# [Epocn:3],[batch_count:6.0],[loss:0.570345],[accuracy:0.960676]
# [Epocn:3],[batch_count:7.0],[loss:0.551385],[accuracy:0.963754]
# [Epocn:3],[batch_count:8.0],[loss:0.560552],[accuracy:0.954696]
# [Epocn:3],[batch_count:9.0],[loss:0.540668],[accuracy:0.962573]
# [Epocn:3],[batch_count:10.0],[loss:0.576780],[accuracy:0.919241]
# [Epoch 3/201], [loss:0.576868], accuracy:0.948396]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:4],[batch_count:1.0],[loss:0.550819],[accuracy:0.959418]
# [Epocn:4],[batch_count:2.0],[loss:0.541318],[accuracy:0.970549]
# [Epocn:4],[batch_count:3.0],[loss:0.551583],[accuracy:0.976568]
# [Epocn:4],[batch_count:4.0],[loss:0.545186],[accuracy:0.954377]
# [Epocn:4],[batch_count:5.0],[loss:0.539402],[accuracy:0.959324]
# [Epocn:4],[batch_count:6.0],[loss:0.523961],[accuracy:0.974376]
# [Epocn:4],[batch_count:7.0],[loss:0.522997],[accuracy:0.962867]
# [Epocn:4],[batch_count:8.0],[loss:0.521663],[accuracy:0.953422]
# [Epocn:4],[batch_count:9.0],[loss:0.529700],[accuracy:0.947268]
# [Epocn:4],[batch_count:10.0],[loss:0.513739],[accuracy:0.966660]
# [Epoch 4/201], [loss:0.534037], accuracy:0.962483]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:5],[batch_count:1.0],[loss:0.517296],[accuracy:0.972464]
# [Epocn:5],[batch_count:2.0],[loss:0.512574],[accuracy:0.960704]
# [Epocn:5],[batch_count:3.0],[loss:0.511636],[accuracy:0.964549]
# [Epocn:5],[batch_count:4.0],[loss:0.500171],[accuracy:0.950146]
# [Epocn:5],[batch_count:5.0],[loss:0.504445],[accuracy:0.950327]
# [Epocn:5],[batch_count:6.0],[loss:0.487173],[accuracy:0.969002]
# [Epocn:5],[batch_count:7.0],[loss:0.489697],[accuracy:0.972507]
# [Epocn:5],[batch_count:8.0],[loss:0.504524],[accuracy:0.950891]
# [Epocn:5],[batch_count:9.0],[loss:0.487205],[accuracy:0.970998]
# [Epocn:5],[batch_count:10.0],[loss:0.484519],[accuracy:0.974174]
# [Epoch 5/201], [loss:0.499924], accuracy:0.963576]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:6],[batch_count:1.0],[loss:0.474452],[accuracy:0.974971]
# [Epocn:6],[batch_count:2.0],[loss:0.464812],[accuracy:0.978022]
# [Epocn:6],[batch_count:3.0],[loss:0.474714],[accuracy:0.970166]
# [Epocn:6],[batch_count:4.0],[loss:0.478889],[accuracy:0.956237]
# [Epocn:6],[batch_count:5.0],[loss:0.471660],[accuracy:0.972156]
# [Epocn:6],[batch_count:6.0],[loss:0.475494],[accuracy:0.979253]
# [Epocn:6],[batch_count:7.0],[loss:0.463140],[accuracy:0.982891]
# [Epocn:6],[batch_count:8.0],[loss:0.466437],[accuracy:0.965025]
# [Epocn:6],[batch_count:9.0],[loss:0.457993],[accuracy:0.964440]
# [Epocn:6],[batch_count:10.0],[loss:0.461430],[accuracy:0.973913]
# [Epoch 6/201], [loss:0.468902], accuracy:0.971707]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:7],[batch_count:1.0],[loss:0.447543],[accuracy:0.979002]
# [Epocn:7],[batch_count:2.0],[loss:0.451453],[accuracy:0.970093]
# [Epocn:7],[batch_count:3.0],[loss:0.446598],[accuracy:0.979641]
# [Epocn:7],[batch_count:4.0],[loss:0.437037],[accuracy:0.977938]
# [Epocn:7],[batch_count:5.0],[loss:0.445824],[accuracy:0.973866]
# [Epocn:7],[batch_count:6.0],[loss:0.437150],[accuracy:0.970354]
# [Epocn:7],[batch_count:7.0],[loss:0.449845],[accuracy:0.961202]
# [Epocn:7],[batch_count:8.0],[loss:0.429711],[accuracy:0.980040]
# [Epocn:7],[batch_count:9.0],[loss:0.445936],[accuracy:0.976380]
# [Epocn:7],[batch_count:10.0],[loss:0.422860],[accuracy:0.976490]
# [Epoch 7/201], [loss:0.441396], accuracy:0.974501]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:8],[batch_count:1.0],[loss:0.431283],[accuracy:0.970112]
# [Epocn:8],[batch_count:2.0],[loss:0.426241],[accuracy:0.969595]
# [Epocn:8],[batch_count:3.0],[loss:0.424041],[accuracy:0.970943]
# [Epocn:8],[batch_count:4.0],[loss:0.413446],[accuracy:0.979327]
# [Epocn:8],[batch_count:5.0],[loss:0.410293],[accuracy:0.974899]
# [Epocn:8],[batch_count:6.0],[loss:0.410892],[accuracy:0.981481]
# [Epocn:8],[batch_count:7.0],[loss:0.411549],[accuracy:0.974036]
# [Epocn:8],[batch_count:8.0],[loss:0.412602],[accuracy:0.980404]
# [Epocn:8],[batch_count:9.0],[loss:0.401222],[accuracy:0.982860]
# [Epocn:8],[batch_count:10.0],[loss:0.404521],[accuracy:0.978059]
# [Epoch 8/201], [loss:0.414609], accuracy:0.976172]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:9],[batch_count:1.0],[loss:0.399931],[accuracy:0.977893]
# [Epocn:9],[batch_count:2.0],[loss:0.406853],[accuracy:0.973513]
# [Epocn:9],[batch_count:3.0],[loss:0.411154],[accuracy:0.971391]
# [Epocn:9],[batch_count:4.0],[loss:0.397707],[accuracy:0.986182]
# [Epocn:9],[batch_count:5.0],[loss:0.388901],[accuracy:0.982115]
# [Epocn:9],[batch_count:6.0],[loss:0.385090],[accuracy:0.983413]
# [Epocn:9],[batch_count:7.0],[loss:0.386774],[accuracy:0.980041]
# [Epocn:9],[batch_count:8.0],[loss:0.386100],[accuracy:0.979575]
# [Epocn:9],[batch_count:9.0],[loss:0.374679],[accuracy:0.981602]
# [Epocn:9],[batch_count:10.0],[loss:0.382940],[accuracy:0.972831]
# [Epoch 9/201], [loss:0.392013], accuracy:0.978855]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:10],[batch_count:1.0],[loss:0.376659],[accuracy:0.984424]
# [Epocn:10],[batch_count:2.0],[loss:0.371951],[accuracy:0.985395]
# [Epocn:10],[batch_count:3.0],[loss:0.376577],[accuracy:0.981811]
# [Epocn:10],[batch_count:4.0],[loss:0.376587],[accuracy:0.981381]
# [Epocn:10],[batch_count:5.0],[loss:0.361001],[accuracy:0.987000]
# [Epocn:10],[batch_count:6.0],[loss:0.368830],[accuracy:0.984606]
# [Epocn:10],[batch_count:7.0],[loss:0.362638],[accuracy:0.982597]
# [Epocn:10],[batch_count:8.0],[loss:0.374525],[accuracy:0.973484]
# [Epocn:10],[batch_count:9.0],[loss:0.365250],[accuracy:0.981801]
# [Epocn:10],[batch_count:10.0],[loss:0.359991],[accuracy:0.982185]
# [Epoch 10/201], [loss:0.369401], accuracy:0.982468]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 10
# ------------------------------------------------------------------------------------------
# count:153600,TP:1610,TN:150791,FP:978,FN221
# processing image NO 0, time comsuption 0.007818s
# count:153600,TP:1696,TN:150432,FP:931,FN541
# processing image NO 1, time comsuption 0.007261s
# count:153600,TP:2464,TN:148931,FP:1441,FN764
# processing image NO 2, time comsuption 0.008655s
# count:153600,TP:1404,TN:149745,FP:1672,FN779
# processing image NO 3, time comsuption 0.008966s
# count:153600,TP:1393,TN:151048,FP:1114,FN45
# processing image NO 4, time comsuption 0.008768s
# count:153600,TP:1462,TN:150969,FP:1088,FN81
# processing image NO 5, time comsuption 0.007503s
# count:153600,TP:1805,TN:150413,FP:1166,FN216
# processing image NO 6, time comsuption 0.007104s
# count:153600,TP:1982,TN:150579,FP:857,FN182
# processing image NO 7, time comsuption 0.008635s
# count:153600,TP:1259,TN:150753,FP:1452,FN136
# processing image NO 8, time comsuption 0.008597s
# count:153600,TP:1150,TN:149528,FP:2816,FN106
# processing image NO 9, time comsuption 0.007382s
# count:153600,TP:1370,TN:149791,FP:1551,FN888
# processing image NO 10, time comsuption 0.008856s
# count:153600,TP:1282,TN:150331,FP:1876,FN111
# processing image NO 11, time comsuption 0.007338s
# count:153600,TP:1101,TN:149414,FP:2847,FN238
# processing image NO 12, time comsuption 0.008457s
# count:153600,TP:942,TN:148000,FP:4287,FN371
# processing image NO 13, time comsuption 0.007337s
# count:153600,TP:1215,TN:150000,FP:1982,FN403
# processing image NO 14, time comsuption 0.008802s
# count:153600,TP:1357,TN:149870,FP:2001,FN372
# processing image NO 15, time comsuption 0.007432s
# count:153600,TP:1808,TN:150123,FP:1180,FN489
# processing image NO 16, time comsuption 0.007661s
# count:153600,TP:1068,TN:151077,FP:1306,FN149
# processing image NO 17, time comsuption 0.007458s
# count:153600,TP:1309,TN:150227,FP:1724,FN340
# processing image NO 18, time comsuption 0.008677s
# count:153600,TP:1208,TN:150443,FP:1524,FN425
# processing image NO 19, time comsuption 0.007528s
# count:153600,TP:1275,TN:151075,FP:939,FN311
# processing image NO 20, time comsuption 0.007264s
# count:153600,TP:1607,TN:149739,FP:1698,FN556
# processing image NO 21, time comsuption 0.007899s
# count:153600,TP:1298,TN:148932,FP:3159,FN211
# processing image NO 22, time comsuption 0.007268s
# count:153600,TP:1701,TN:150467,FP:1003,FN429
# processing image NO 23, time comsuption 0.007533s
# count:153600,TP:1083,TN:150303,FP:2024,FN190
# processing image NO 24, time comsuption 0.007403s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 10/201], [loss:0.354646], accuracy:0.986671]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:11],[batch_count:1.0],[loss:0.362733],[accuracy:0.982097]
# [Epocn:11],[batch_count:2.0],[loss:0.359193],[accuracy:0.983032]
# [Epocn:11],[batch_count:3.0],[loss:0.359661],[accuracy:0.977826]
# [Epocn:11],[batch_count:4.0],[loss:0.348913],[accuracy:0.986815]
# [Epocn:11],[batch_count:5.0],[loss:0.348101],[accuracy:0.984000]
# [Epocn:11],[batch_count:6.0],[loss:0.352465],[accuracy:0.978102]
# [Epocn:11],[batch_count:7.0],[loss:0.342803],[accuracy:0.986916]
# [Epocn:11],[batch_count:8.0],[loss:0.343624],[accuracy:0.982244]
# [Epocn:11],[batch_count:9.0],[loss:0.354817],[accuracy:0.971336]
# [Epocn:11],[batch_count:10.0],[loss:0.337634],[accuracy:0.985387]
# [Epoch 11/201], [loss:0.350994], accuracy:0.981775]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:12],[batch_count:1.0],[loss:0.343440],[accuracy:0.985455]
# [Epocn:12],[batch_count:2.0],[loss:0.345063],[accuracy:0.981429]
# [Epocn:12],[batch_count:3.0],[loss:0.334102],[accuracy:0.985281]
# [Epocn:12],[batch_count:4.0],[loss:0.332324],[accuracy:0.982298]
# [Epocn:12],[batch_count:5.0],[loss:0.334803],[accuracy:0.982614]
# [Epocn:12],[batch_count:6.0],[loss:0.331636],[accuracy:0.986143]
# [Epocn:12],[batch_count:7.0],[loss:0.327457],[accuracy:0.981615]
# [Epocn:12],[batch_count:8.0],[loss:0.329183],[accuracy:0.982360]
# [Epocn:12],[batch_count:9.0],[loss:0.325203],[accuracy:0.984446]
# [Epocn:12],[batch_count:10.0],[loss:0.325606],[accuracy:0.984874]
# [Epoch 12/201], [loss:0.332882], accuracy:0.983651]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:13],[batch_count:1.0],[loss:0.322102],[accuracy:0.984512]
# [Epocn:13],[batch_count:2.0],[loss:0.317656],[accuracy:0.987303]
# [Epocn:13],[batch_count:3.0],[loss:0.319683],[accuracy:0.985938]
# [Epocn:13],[batch_count:4.0],[loss:0.315776],[accuracy:0.983023]
# [Epocn:13],[batch_count:5.0],[loss:0.320553],[accuracy:0.985257]
# [Epocn:13],[batch_count:6.0],[loss:0.328828],[accuracy:0.973970]
# [Epocn:13],[batch_count:7.0],[loss:0.311576],[accuracy:0.988802]
# [Epocn:13],[batch_count:8.0],[loss:0.316811],[accuracy:0.983441]
# [Epocn:13],[batch_count:9.0],[loss:0.315467],[accuracy:0.981957]
# [Epocn:13],[batch_count:10.0],[loss:0.306215],[accuracy:0.981470]
# [Epoch 13/201], [loss:0.317467], accuracy:0.983567]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:14],[batch_count:1.0],[loss:0.308873],[accuracy:0.985570]
# [Epocn:14],[batch_count:2.0],[loss:0.312362],[accuracy:0.977185]
# [Epocn:14],[batch_count:3.0],[loss:0.305878],[accuracy:0.983550]
# [Epocn:14],[batch_count:4.0],[loss:0.308520],[accuracy:0.983991]
# [Epocn:14],[batch_count:5.0],[loss:0.302405],[accuracy:0.981829]
# [Epocn:14],[batch_count:6.0],[loss:0.301752],[accuracy:0.985809]
# [Epocn:14],[batch_count:7.0],[loss:0.302174],[accuracy:0.987643]
# [Epocn:14],[batch_count:8.0],[loss:0.298590],[accuracy:0.983955]
# [Epocn:14],[batch_count:9.0],[loss:0.297175],[accuracy:0.982935]
# [Epocn:14],[batch_count:10.0],[loss:0.297878],[accuracy:0.988260]
# [Epoch 14/201], [loss:0.303561], accuracy:0.984073]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:15],[batch_count:1.0],[loss:0.298703],[accuracy:0.984113]
# [Epocn:15],[batch_count:2.0],[loss:0.292954],[accuracy:0.988150]
# [Epocn:15],[batch_count:3.0],[loss:0.291511],[accuracy:0.989134]
# [Epocn:15],[batch_count:4.0],[loss:0.291214],[accuracy:0.986970]
# [Epocn:15],[batch_count:5.0],[loss:0.296727],[accuracy:0.977346]
# [Epocn:15],[batch_count:6.0],[loss:0.291851],[accuracy:0.987109]
# [Epocn:15],[batch_count:7.0],[loss:0.280442],[accuracy:0.986927]
# [Epocn:15],[batch_count:8.0],[loss:0.286103],[accuracy:0.984617]
# [Epocn:15],[batch_count:9.0],[loss:0.285048],[accuracy:0.980559]
# [Epocn:15],[batch_count:10.0],[loss:0.278119],[accuracy:0.990349]
# [Epoch 15/201], [loss:0.289267], accuracy:0.985528]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:16],[batch_count:1.0],[loss:0.283621],[accuracy:0.985572]
# [Epocn:16],[batch_count:2.0],[loss:0.283491],[accuracy:0.985598]
# [Epocn:16],[batch_count:3.0],[loss:0.275404],[accuracy:0.990130]
# [Epocn:16],[batch_count:4.0],[loss:0.274986],[accuracy:0.989596]
# [Epocn:16],[batch_count:5.0],[loss:0.277362],[accuracy:0.983564]
# [Epocn:16],[batch_count:6.0],[loss:0.274765],[accuracy:0.986190]
# [Epocn:16],[batch_count:7.0],[loss:0.271420],[accuracy:0.987711]
# [Epocn:16],[batch_count:8.0],[loss:0.276352],[accuracy:0.983420]
# [Epocn:16],[batch_count:9.0],[loss:0.272371],[accuracy:0.983287]
# [Epocn:16],[batch_count:10.0],[loss:0.269755],[accuracy:0.985845]
# [Epoch 16/201], [loss:0.275953], accuracy:0.986091]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:17],[batch_count:1.0],[loss:0.266529],[accuracy:0.988454]
# [Epocn:17],[batch_count:2.0],[loss:0.267254],[accuracy:0.985577]
# [Epocn:17],[batch_count:3.0],[loss:0.277392],[accuracy:0.979526]
# [Epocn:17],[batch_count:4.0],[loss:0.266086],[accuracy:0.983945]
# [Epocn:17],[batch_count:5.0],[loss:0.269466],[accuracy:0.983734]
# [Epocn:17],[batch_count:6.0],[loss:0.266641],[accuracy:0.981786]
# [Epocn:17],[batch_count:7.0],[loss:0.265848],[accuracy:0.982606]
# [Epocn:17],[batch_count:8.0],[loss:0.261790],[accuracy:0.990397]
# [Epocn:17],[batch_count:9.0],[loss:0.263288],[accuracy:0.987607]
# [Epocn:17],[batch_count:10.0],[loss:0.254981],[accuracy:0.990866]
# [Epoch 17/201], [loss:0.265927], accuracy:0.985450]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:18],[batch_count:1.0],[loss:0.252261],[accuracy:0.991497]
# [Epocn:18],[batch_count:2.0],[loss:0.255495],[accuracy:0.989444]
# [Epocn:18],[batch_count:3.0],[loss:0.257647],[accuracy:0.984392]
# [Epocn:18],[batch_count:4.0],[loss:0.260032],[accuracy:0.982711]
# [Epocn:18],[batch_count:5.0],[loss:0.261057],[accuracy:0.980167]
# [Epocn:18],[batch_count:6.0],[loss:0.252534],[accuracy:0.985778]
# [Epocn:18],[batch_count:7.0],[loss:0.249961],[accuracy:0.986618]
# [Epocn:18],[batch_count:8.0],[loss:0.262355],[accuracy:0.976712]
# [Epocn:18],[batch_count:9.0],[loss:0.255137],[accuracy:0.984273]
# [Epocn:18],[batch_count:10.0],[loss:0.250587],[accuracy:0.984341]
# [Epoch 18/201], [loss:0.255706], accuracy:0.984593]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:19],[batch_count:1.0],[loss:0.245697],[accuracy:0.987567]
# [Epocn:19],[batch_count:2.0],[loss:0.245073],[accuracy:0.988500]
# [Epocn:19],[batch_count:3.0],[loss:0.251084],[accuracy:0.987542]
# [Epocn:19],[batch_count:4.0],[loss:0.244084],[accuracy:0.988920]
# [Epocn:19],[batch_count:5.0],[loss:0.244073],[accuracy:0.989444]
# [Epocn:19],[batch_count:6.0],[loss:0.241757],[accuracy:0.989619]
# [Epocn:19],[batch_count:7.0],[loss:0.244930],[accuracy:0.984868]
# [Epocn:19],[batch_count:8.0],[loss:0.245589],[accuracy:0.982997]
# [Epocn:19],[batch_count:9.0],[loss:0.245962],[accuracy:0.980807]
# [Epocn:19],[batch_count:10.0],[loss:0.240405],[accuracy:0.986693]
# [Epoch 19/201], [loss:0.244865], accuracy:0.986696]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:20],[batch_count:1.0],[loss:0.234482],[accuracy:0.988585]
# [Epocn:20],[batch_count:2.0],[loss:0.238655],[accuracy:0.983202]
# [Epocn:20],[batch_count:3.0],[loss:0.235363],[accuracy:0.989118]
# [Epocn:20],[batch_count:4.0],[loss:0.235645],[accuracy:0.987879]
# [Epocn:20],[batch_count:5.0],[loss:0.233053],[accuracy:0.988688]
# [Epocn:20],[batch_count:6.0],[loss:0.245126],[accuracy:0.982244]
# [Epocn:20],[batch_count:7.0],[loss:0.234952],[accuracy:0.984791]
# [Epocn:20],[batch_count:8.0],[loss:0.228223],[accuracy:0.989614]
# [Epocn:20],[batch_count:9.0],[loss:0.234720],[accuracy:0.987641]
# [Epocn:20],[batch_count:10.0],[loss:0.229597],[accuracy:0.989857]
# [Epoch 20/201], [loss:0.234982], accuracy:0.987162]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 20
# ------------------------------------------------------------------------------------------
# count:153600,TP:1556,TN:151101,FP:668,FN275
# processing image NO 0, time comsuption 0.008702s
# count:153600,TP:1469,TN:150794,FP:569,FN768
# processing image NO 1, time comsuption 0.007741s
# count:153600,TP:2171,TN:149661,FP:711,FN1057
# processing image NO 2, time comsuption 0.008590s
# count:153600,TP:1372,TN:150451,FP:966,FN811
# processing image NO 3, time comsuption 0.007304s
# count:153600,TP:1313,TN:151475,FP:687,FN125
# processing image NO 4, time comsuption 0.007370s
# count:153600,TP:1432,TN:151413,FP:644,FN111
# processing image NO 5, time comsuption 0.007494s
# count:153600,TP:1652,TN:150944,FP:635,FN369
# processing image NO 6, time comsuption 0.007706s
# count:153600,TP:1806,TN:151004,FP:432,FN358
# processing image NO 7, time comsuption 0.010247s
# count:153600,TP:1262,TN:151321,FP:884,FN133
# processing image NO 8, time comsuption 0.007746s
# count:153600,TP:1055,TN:150141,FP:2203,FN201
# processing image NO 9, time comsuption 0.007608s
# count:153600,TP:1406,TN:150246,FP:1096,FN852
# processing image NO 10, time comsuption 0.008265s
# count:153600,TP:1194,TN:150966,FP:1241,FN199
# processing image NO 11, time comsuption 0.008007s
# count:153600,TP:1042,TN:150382,FP:1879,FN297
# processing image NO 12, time comsuption 0.007612s
# count:153600,TP:855,TN:148894,FP:3393,FN458
# processing image NO 13, time comsuption 0.007594s
# count:153600,TP:1119,TN:150598,FP:1384,FN499
# processing image NO 14, time comsuption 0.007362s
# count:153600,TP:1227,TN:150617,FP:1254,FN502
# processing image NO 15, time comsuption 0.008071s
# count:153600,TP:1699,TN:150580,FP:723,FN598
# processing image NO 16, time comsuption 0.008119s
# count:153600,TP:1007,TN:151374,FP:1009,FN210
# processing image NO 17, time comsuption 0.007765s
# count:153600,TP:1142,TN:150621,FP:1330,FN507
# processing image NO 18, time comsuption 0.007920s
# count:153600,TP:1243,TN:150835,FP:1132,FN390
# processing image NO 19, time comsuption 0.007485s
# count:153600,TP:1233,TN:151411,FP:603,FN353
# processing image NO 20, time comsuption 0.007829s
# count:153600,TP:1560,TN:150291,FP:1146,FN603
# processing image NO 21, time comsuption 0.008301s
# count:153600,TP:1158,TN:149930,FP:2161,FN351
# processing image NO 22, time comsuption 0.010319s
# count:153600,TP:1560,TN:150712,FP:758,FN570
# processing image NO 23, time comsuption 0.007976s
# count:153600,TP:969,TN:150871,FP:1456,FN304
# processing image NO 24, time comsuption 0.007551s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 20/201], [loss:0.227074], accuracy:0.989616]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:21],[batch_count:1.0],[loss:0.237139],[accuracy:0.981535]
# [Epocn:21],[batch_count:2.0],[loss:0.231598],[accuracy:0.988356]
# [Epocn:21],[batch_count:3.0],[loss:0.230307],[accuracy:0.984858]
# [Epocn:21],[batch_count:4.0],[loss:0.231348],[accuracy:0.983027]
# [Epocn:21],[batch_count:5.0],[loss:0.228962],[accuracy:0.987806]
# [Epocn:21],[batch_count:6.0],[loss:0.226078],[accuracy:0.988509]
# [Epocn:21],[batch_count:7.0],[loss:0.225639],[accuracy:0.984644]
# [Epocn:21],[batch_count:8.0],[loss:0.221136],[accuracy:0.990515]
# [Epocn:21],[batch_count:9.0],[loss:0.224190],[accuracy:0.986061]
# [Epocn:21],[batch_count:10.0],[loss:0.222081],[accuracy:0.989012]
# [Epoch 21/201], [loss:0.227848], accuracy:0.986432]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:22],[batch_count:1.0],[loss:0.224048],[accuracy:0.985803]
# [Epocn:22],[batch_count:2.0],[loss:0.221719],[accuracy:0.986183]
# [Epocn:22],[batch_count:3.0],[loss:0.222615],[accuracy:0.986102]
# [Epocn:22],[batch_count:4.0],[loss:0.237941],[accuracy:0.974804]
# [Epocn:22],[batch_count:5.0],[loss:0.223925],[accuracy:0.984605]
# [Epocn:22],[batch_count:6.0],[loss:0.221259],[accuracy:0.983103]
# [Epocn:22],[batch_count:7.0],[loss:0.218191],[accuracy:0.988958]
# [Epocn:22],[batch_count:8.0],[loss:0.217744],[accuracy:0.987873]
# [Epocn:22],[batch_count:9.0],[loss:0.223982],[accuracy:0.981947]
# [Epocn:22],[batch_count:10.0],[loss:0.213223],[accuracy:0.990702]
# [Epoch 22/201], [loss:0.222465], accuracy:0.985008]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:23],[batch_count:1.0],[loss:0.215315],[accuracy:0.987322]
# [Epocn:23],[batch_count:2.0],[loss:0.218467],[accuracy:0.987426]
# [Epocn:23],[batch_count:3.0],[loss:0.211042],[accuracy:0.987288]
# [Epocn:23],[batch_count:4.0],[loss:0.210771],[accuracy:0.989760]
# [Epocn:23],[batch_count:5.0],[loss:0.211826],[accuracy:0.989566]
# [Epocn:23],[batch_count:6.0],[loss:0.216124],[accuracy:0.983044]
# [Epocn:23],[batch_count:7.0],[loss:0.211483],[accuracy:0.985493]
# [Epocn:23],[batch_count:8.0],[loss:0.211372],[accuracy:0.987881]
# [Epocn:23],[batch_count:9.0],[loss:0.211005],[accuracy:0.986472]
# [Epocn:23],[batch_count:10.0],[loss:0.209510],[accuracy:0.985421]
# [Epoch 23/201], [loss:0.212691], accuracy:0.986967]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:24],[batch_count:1.0],[loss:0.208409],[accuracy:0.986125]
# [Epocn:24],[batch_count:2.0],[loss:0.206424],[accuracy:0.987585]
# [Epocn:24],[batch_count:3.0],[loss:0.207590],[accuracy:0.986429]
# [Epocn:24],[batch_count:4.0],[loss:0.212502],[accuracy:0.982283]
# [Epocn:24],[batch_count:5.0],[loss:0.202334],[accuracy:0.988295]
# [Epocn:24],[batch_count:6.0],[loss:0.207193],[accuracy:0.989233]
# [Epocn:24],[batch_count:7.0],[loss:0.200651],[accuracy:0.991547]
# [Epocn:24],[batch_count:8.0],[loss:0.206385],[accuracy:0.984436]
# [Epocn:24],[batch_count:9.0],[loss:0.197720],[accuracy:0.991012]
# [Epocn:24],[batch_count:10.0],[loss:0.205334],[accuracy:0.987242]
# [Epoch 24/201], [loss:0.205454], accuracy:0.987419]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:25],[batch_count:1.0],[loss:0.201286],[accuracy:0.988797]
# [Epocn:25],[batch_count:2.0],[loss:0.196328],[accuracy:0.991560]
# [Epocn:25],[batch_count:3.0],[loss:0.198293],[accuracy:0.988158]
# [Epocn:25],[batch_count:4.0],[loss:0.196604],[accuracy:0.990966]
# [Epocn:25],[batch_count:5.0],[loss:0.197804],[accuracy:0.988390]
# [Epocn:25],[batch_count:6.0],[loss:0.200610],[accuracy:0.985094]
# [Epocn:25],[batch_count:7.0],[loss:0.199005],[accuracy:0.988924]
# [Epocn:25],[batch_count:8.0],[loss:0.203244],[accuracy:0.981166]
# [Epocn:25],[batch_count:9.0],[loss:0.195186],[accuracy:0.990013]
# [Epocn:25],[batch_count:10.0],[loss:0.199423],[accuracy:0.983475]
# [Epoch 25/201], [loss:0.198778], accuracy:0.987654]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:26],[batch_count:1.0],[loss:0.193280],[accuracy:0.988892]
# [Epocn:26],[batch_count:2.0],[loss:0.198208],[accuracy:0.986604]
# [Epocn:26],[batch_count:3.0],[loss:0.188635],[accuracy:0.991916]
# [Epocn:26],[batch_count:4.0],[loss:0.198795],[accuracy:0.983214]
# [Epocn:26],[batch_count:5.0],[loss:0.192864],[accuracy:0.984136]
# [Epocn:26],[batch_count:6.0],[loss:0.191489],[accuracy:0.989087]
# [Epocn:26],[batch_count:7.0],[loss:0.194027],[accuracy:0.986188]
# [Epocn:26],[batch_count:8.0],[loss:0.188272],[accuracy:0.988906]
# [Epocn:26],[batch_count:9.0],[loss:0.194836],[accuracy:0.985913]
# [Epocn:26],[batch_count:10.0],[loss:0.189435],[accuracy:0.991542]
# [Epoch 26/201], [loss:0.192984], accuracy:0.987640]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:27],[batch_count:1.0],[loss:0.187536],[accuracy:0.989615]
# [Epocn:27],[batch_count:2.0],[loss:0.185312],[accuracy:0.991022]
# [Epocn:27],[batch_count:3.0],[loss:0.186385],[accuracy:0.990658]
# [Epocn:27],[batch_count:4.0],[loss:0.192898],[accuracy:0.985347]
# [Epocn:27],[batch_count:5.0],[loss:0.187166],[accuracy:0.989019]
# [Epocn:27],[batch_count:6.0],[loss:0.187452],[accuracy:0.987442]
# [Epocn:27],[batch_count:7.0],[loss:0.183937],[accuracy:0.990131]
# [Epocn:27],[batch_count:8.0],[loss:0.184963],[accuracy:0.987053]
# [Epocn:27],[batch_count:9.0],[loss:0.188374],[accuracy:0.983363]
# [Epocn:27],[batch_count:10.0],[loss:0.188593],[accuracy:0.985854]
# [Epoch 27/201], [loss:0.187262], accuracy:0.987950]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:28],[batch_count:1.0],[loss:0.182197],[accuracy:0.987301]
# [Epocn:28],[batch_count:2.0],[loss:0.180627],[accuracy:0.989204]
# [Epocn:28],[batch_count:3.0],[loss:0.184305],[accuracy:0.988369]
# [Epocn:28],[batch_count:4.0],[loss:0.179658],[accuracy:0.990646]
# [Epocn:28],[batch_count:5.0],[loss:0.184210],[accuracy:0.987658]
# [Epocn:28],[batch_count:6.0],[loss:0.178833],[accuracy:0.989557]
# [Epocn:28],[batch_count:7.0],[loss:0.177279],[accuracy:0.991682]
# [Epocn:28],[batch_count:8.0],[loss:0.184329],[accuracy:0.982661]
# [Epocn:28],[batch_count:9.0],[loss:0.181896],[accuracy:0.988012]
# [Epocn:28],[batch_count:10.0],[loss:0.183274],[accuracy:0.987380]
# [Epoch 28/201], [loss:0.181661], accuracy:0.988247]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:29],[batch_count:1.0],[loss:0.176499],[accuracy:0.991008]
# [Epocn:29],[batch_count:2.0],[loss:0.178125],[accuracy:0.986760]
# [Epocn:29],[batch_count:3.0],[loss:0.182117],[accuracy:0.986000]
# [Epocn:29],[batch_count:4.0],[loss:0.179304],[accuracy:0.986803]
# [Epocn:29],[batch_count:5.0],[loss:0.177937],[accuracy:0.986469]
# [Epocn:29],[batch_count:6.0],[loss:0.179956],[accuracy:0.986606]
# [Epocn:29],[batch_count:7.0],[loss:0.176666],[accuracy:0.988651]
# [Epocn:29],[batch_count:8.0],[loss:0.173593],[accuracy:0.989628]
# [Epocn:29],[batch_count:9.0],[loss:0.173535],[accuracy:0.989718]
# [Epocn:29],[batch_count:10.0],[loss:0.174331],[accuracy:0.988083]
# [Epoch 29/201], [loss:0.177206], accuracy:0.987973]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:30],[batch_count:1.0],[loss:0.174063],[accuracy:0.989437]
# [Epocn:30],[batch_count:2.0],[loss:0.177581],[accuracy:0.987185]
# [Epocn:30],[batch_count:3.0],[loss:0.173797],[accuracy:0.987665]
# [Epocn:30],[batch_count:4.0],[loss:0.174647],[accuracy:0.987059]
# [Epocn:30],[batch_count:5.0],[loss:0.175720],[accuracy:0.987052]
# [Epocn:30],[batch_count:6.0],[loss:0.168289],[accuracy:0.990099]
# [Epocn:30],[batch_count:7.0],[loss:0.171282],[accuracy:0.986900]
# [Epocn:30],[batch_count:8.0],[loss:0.172491],[accuracy:0.985935]
# [Epocn:30],[batch_count:9.0],[loss:0.172013],[accuracy:0.986886]
# [Epocn:30],[batch_count:10.0],[loss:0.164071],[accuracy:0.993013]
# [Epoch 30/201], [loss:0.172395], accuracy:0.988123]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 30
# ------------------------------------------------------------------------------------------
# count:153600,TP:1595,TN:151278,FP:491,FN236
# processing image NO 0, time comsuption 0.008096s
# count:153600,TP:1552,TN:150986,FP:377,FN685
# processing image NO 1, time comsuption 0.007416s
# count:153600,TP:2063,TN:149810,FP:562,FN1165
# processing image NO 2, time comsuption 0.007302s
# count:153600,TP:1298,TN:150819,FP:598,FN885
# processing image NO 3, time comsuption 0.010207s
# count:153600,TP:1315,TN:151510,FP:652,FN123
# processing image NO 4, time comsuption 0.007562s
# count:153600,TP:1409,TN:151473,FP:584,FN134
# processing image NO 5, time comsuption 0.007223s
# count:153600,TP:1610,TN:150979,FP:600,FN411
# processing image NO 6, time comsuption 0.008640s
# count:153600,TP:1778,TN:151066,FP:370,FN386
# processing image NO 7, time comsuption 0.007197s
# count:153600,TP:1247,TN:151373,FP:832,FN148
# processing image NO 8, time comsuption 0.007526s
# count:153600,TP:1086,TN:150701,FP:1643,FN170
# processing image NO 9, time comsuption 0.008054s
# count:153600,TP:1441,TN:150517,FP:825,FN817
# processing image NO 10, time comsuption 0.007243s
# count:153600,TP:1171,TN:151333,FP:874,FN222
# processing image NO 11, time comsuption 0.007671s
# count:153600,TP:1054,TN:151190,FP:1071,FN285
# processing image NO 12, time comsuption 0.009080s
# count:153600,TP:934,TN:150896,FP:1391,FN379
# processing image NO 13, time comsuption 0.007623s
# count:153600,TP:1112,TN:151129,FP:853,FN506
# processing image NO 14, time comsuption 0.007446s
# count:153600,TP:1229,TN:151083,FP:788,FN500
# processing image NO 15, time comsuption 0.007552s
# count:153600,TP:1605,TN:150795,FP:508,FN692
# processing image NO 16, time comsuption 0.007164s
# count:153600,TP:1066,TN:151513,FP:870,FN151
# processing image NO 17, time comsuption 0.009387s
# count:153600,TP:1187,TN:151066,FP:885,FN462
# processing image NO 18, time comsuption 0.007602s
# count:153600,TP:1285,TN:151189,FP:778,FN348
# processing image NO 19, time comsuption 0.007605s
# count:153600,TP:1227,TN:151500,FP:514,FN359
# processing image NO 20, time comsuption 0.007629s
# count:153600,TP:1481,TN:150492,FP:945,FN682
# processing image NO 21, time comsuption 0.007887s
# count:153600,TP:1175,TN:151192,FP:899,FN334
# processing image NO 22, time comsuption 0.007885s
# count:153600,TP:1544,TN:150918,FP:552,FN586
# processing image NO 23, time comsuption 0.007599s
# count:153600,TP:988,TN:151535,FP:792,FN285
# processing image NO 24, time comsuption 0.007867s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 30/201], [loss:0.164069], accuracy:0.992134]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:31],[batch_count:1.0],[loss:0.167819],[accuracy:0.989112]
# [Epocn:31],[batch_count:2.0],[loss:0.177716],[accuracy:0.982346]
# [Epocn:31],[batch_count:3.0],[loss:0.168493],[accuracy:0.988129]
# [Epocn:31],[batch_count:4.0],[loss:0.169908],[accuracy:0.989006]
# [Epocn:31],[batch_count:5.0],[loss:0.166879],[accuracy:0.987857]
# [Epocn:31],[batch_count:6.0],[loss:0.165886],[accuracy:0.990101]
# [Epocn:31],[batch_count:7.0],[loss:0.164670],[accuracy:0.990193]
# [Epocn:31],[batch_count:8.0],[loss:0.163388],[accuracy:0.991547]
# [Epocn:31],[batch_count:9.0],[loss:0.163956],[accuracy:0.988432]
# [Epocn:31],[batch_count:10.0],[loss:0.167954],[accuracy:0.987499]
# [Epoch 31/201], [loss:0.167667], accuracy:0.988422]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:32],[batch_count:1.0],[loss:0.159552],[accuracy:0.993114]
# [Epocn:32],[batch_count:2.0],[loss:0.163779],[accuracy:0.987762]
# [Epocn:32],[batch_count:3.0],[loss:0.163563],[accuracy:0.989429]
# [Epocn:32],[batch_count:4.0],[loss:0.158896],[accuracy:0.992742]
# [Epocn:32],[batch_count:5.0],[loss:0.167524],[accuracy:0.986698]
# [Epocn:32],[batch_count:6.0],[loss:0.163680],[accuracy:0.989347]
# [Epocn:32],[batch_count:7.0],[loss:0.166521],[accuracy:0.984969]
# [Epocn:32],[batch_count:8.0],[loss:0.162327],[accuracy:0.989780]
# [Epocn:32],[batch_count:9.0],[loss:0.164499],[accuracy:0.987419]
# [Epocn:32],[batch_count:10.0],[loss:0.167096],[accuracy:0.982776]
# [Epoch 32/201], [loss:0.163744], accuracy:0.988403]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:33],[batch_count:1.0],[loss:0.161302],[accuracy:0.987762]
# [Epocn:33],[batch_count:2.0],[loss:0.159602],[accuracy:0.989623]
# [Epocn:33],[batch_count:3.0],[loss:0.162927],[accuracy:0.987452]
# [Epocn:33],[batch_count:4.0],[loss:0.158406],[accuracy:0.991119]
# [Epocn:33],[batch_count:5.0],[loss:0.159301],[accuracy:0.986925]
# [Epocn:33],[batch_count:6.0],[loss:0.160477],[accuracy:0.987553]
# [Epocn:33],[batch_count:7.0],[loss:0.157203],[accuracy:0.990847]
# [Epocn:33],[batch_count:8.0],[loss:0.161202],[accuracy:0.987270]
# [Epocn:33],[batch_count:9.0],[loss:0.165254],[accuracy:0.982933]
# [Epocn:33],[batch_count:10.0],[loss:0.155252],[accuracy:0.990534]
# [Epoch 33/201], [loss:0.160093], accuracy:0.988202]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:34],[batch_count:1.0],[loss:0.155696],[accuracy:0.989607]
# [Epocn:34],[batch_count:2.0],[loss:0.153058],[accuracy:0.992286]
# [Epocn:34],[batch_count:3.0],[loss:0.159585],[accuracy:0.984825]
# [Epocn:34],[batch_count:4.0],[loss:0.161515],[accuracy:0.986033]
# [Epocn:34],[batch_count:5.0],[loss:0.155061],[accuracy:0.989606]
# [Epocn:34],[batch_count:6.0],[loss:0.159345],[accuracy:0.984800]
# [Epocn:34],[batch_count:7.0],[loss:0.157076],[accuracy:0.988226]
# [Epocn:34],[batch_count:8.0],[loss:0.154795],[accuracy:0.987764]
# [Epocn:34],[batch_count:9.0],[loss:0.155685],[accuracy:0.989755]
# [Epocn:34],[batch_count:10.0],[loss:0.159522],[accuracy:0.986215]
# [Epoch 34/201], [loss:0.157134], accuracy:0.987912]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:35],[batch_count:1.0],[loss:0.160439],[accuracy:0.982832]
# [Epocn:35],[batch_count:2.0],[loss:0.151985],[accuracy:0.990576]
# [Epocn:35],[batch_count:3.0],[loss:0.150257],[accuracy:0.990877]
# [Epocn:35],[batch_count:4.0],[loss:0.147713],[accuracy:0.993506]
# [Epocn:35],[batch_count:5.0],[loss:0.152178],[accuracy:0.989952]
# [Epocn:35],[batch_count:6.0],[loss:0.152747],[accuracy:0.989310]
# [Epocn:35],[batch_count:7.0],[loss:0.158052],[accuracy:0.983057]
# [Epocn:35],[batch_count:8.0],[loss:0.151668],[accuracy:0.989338]
# [Epocn:35],[batch_count:9.0],[loss:0.153089],[accuracy:0.987427]
# [Epocn:35],[batch_count:10.0],[loss:0.148777],[accuracy:0.989990]
# [Epoch 35/201], [loss:0.152690], accuracy:0.988686]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:36],[batch_count:1.0],[loss:0.147765],[accuracy:0.990776]
# [Epocn:36],[batch_count:2.0],[loss:0.146460],[accuracy:0.991378]
# [Epocn:36],[batch_count:3.0],[loss:0.155609],[accuracy:0.984424]
# [Epocn:36],[batch_count:4.0],[loss:0.151171],[accuracy:0.988738]
# [Epocn:36],[batch_count:5.0],[loss:0.157531],[accuracy:0.981835]
# [Epocn:36],[batch_count:6.0],[loss:0.146490],[accuracy:0.991181]
# [Epocn:36],[batch_count:7.0],[loss:0.145000],[accuracy:0.990947]
# [Epocn:36],[batch_count:8.0],[loss:0.145026],[accuracy:0.990796]
# [Epocn:36],[batch_count:9.0],[loss:0.147867],[accuracy:0.989477]
# [Epocn:36],[batch_count:10.0],[loss:0.146672],[accuracy:0.987327]
# [Epoch 36/201], [loss:0.148959], accuracy:0.988688]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:37],[batch_count:1.0],[loss:0.154018],[accuracy:0.982934]
# [Epocn:37],[batch_count:2.0],[loss:0.143236],[accuracy:0.991676]
# [Epocn:37],[batch_count:3.0],[loss:0.146401],[accuracy:0.987708]
# [Epocn:37],[batch_count:4.0],[loss:0.144776],[accuracy:0.990084]
# [Epocn:37],[batch_count:5.0],[loss:0.139683],[accuracy:0.992631]
# [Epocn:37],[batch_count:6.0],[loss:0.145645],[accuracy:0.988839]
# [Epocn:37],[batch_count:7.0],[loss:0.144319],[accuracy:0.989004]
# [Epocn:37],[batch_count:8.0],[loss:0.143252],[accuracy:0.990801]
# [Epocn:37],[batch_count:9.0],[loss:0.147292],[accuracy:0.987477]
# [Epocn:37],[batch_count:10.0],[loss:0.143995],[accuracy:0.990138]
# [Epoch 37/201], [loss:0.145262], accuracy:0.989129]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:38],[batch_count:1.0],[loss:0.141176],[accuracy:0.990492]
# [Epocn:38],[batch_count:2.0],[loss:0.140085],[accuracy:0.990258]
# [Epocn:38],[batch_count:3.0],[loss:0.145732],[accuracy:0.987960]
# [Epocn:38],[batch_count:4.0],[loss:0.146471],[accuracy:0.986430]
# [Epocn:38],[batch_count:5.0],[loss:0.139252],[accuracy:0.991113]
# [Epocn:38],[batch_count:6.0],[loss:0.138536],[accuracy:0.991678]
# [Epocn:38],[batch_count:7.0],[loss:0.143089],[accuracy:0.988201]
# [Epocn:38],[batch_count:8.0],[loss:0.142273],[accuracy:0.989180]
# [Epocn:38],[batch_count:9.0],[loss:0.138527],[accuracy:0.990611]
# [Epocn:38],[batch_count:10.0],[loss:0.143230],[accuracy:0.985688]
# [Epoch 38/201], [loss:0.141837], accuracy:0.989161]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:39],[batch_count:1.0],[loss:0.143490],[accuracy:0.987717]
# [Epocn:39],[batch_count:2.0],[loss:0.139116],[accuracy:0.990882]
# [Epocn:39],[batch_count:3.0],[loss:0.138157],[accuracy:0.990326]
# [Epocn:39],[batch_count:4.0],[loss:0.148313],[accuracy:0.983582]
# [Epocn:39],[batch_count:5.0],[loss:0.142265],[accuracy:0.987359]
# [Epocn:39],[batch_count:6.0],[loss:0.143523],[accuracy:0.987327]
# [Epocn:39],[batch_count:7.0],[loss:0.135378],[accuracy:0.991372]
# [Epocn:39],[batch_count:8.0],[loss:0.139018],[accuracy:0.987917]
# [Epocn:39],[batch_count:9.0],[loss:0.136429],[accuracy:0.990860]
# [Epocn:39],[batch_count:10.0],[loss:0.138183],[accuracy:0.988885]
# [Epoch 39/201], [loss:0.140387], accuracy:0.988623]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:40],[batch_count:1.0],[loss:0.137709],[accuracy:0.989171]
# [Epocn:40],[batch_count:2.0],[loss:0.137522],[accuracy:0.989035]
# [Epocn:40],[batch_count:3.0],[loss:0.141744],[accuracy:0.986874]
# [Epocn:40],[batch_count:4.0],[loss:0.136449],[accuracy:0.990485]
# [Epocn:40],[batch_count:5.0],[loss:0.136714],[accuracy:0.990461]
# [Epocn:40],[batch_count:6.0],[loss:0.141914],[accuracy:0.984010]
# [Epocn:40],[batch_count:7.0],[loss:0.137163],[accuracy:0.988188]
# [Epocn:40],[batch_count:8.0],[loss:0.138479],[accuracy:0.988664]
# [Epocn:40],[batch_count:9.0],[loss:0.132839],[accuracy:0.991815]
# [Epocn:40],[batch_count:10.0],[loss:0.137449],[accuracy:0.987607]
# [Epoch 40/201], [loss:0.137798], accuracy:0.988631]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 40
# ------------------------------------------------------------------------------------------
# count:153600,TP:1561,TN:151264,FP:505,FN270
# processing image NO 0, time comsuption 0.007818s
# count:153600,TP:1590,TN:150994,FP:369,FN647
# processing image NO 1, time comsuption 0.007759s
# count:153600,TP:2099,TN:149829,FP:543,FN1129
# processing image NO 2, time comsuption 0.007837s
# count:153600,TP:1433,TN:150933,FP:484,FN750
# processing image NO 3, time comsuption 0.007762s
# count:153600,TP:1326,TN:151506,FP:656,FN112
# processing image NO 4, time comsuption 0.007837s
# count:153600,TP:1403,TN:151474,FP:583,FN140
# processing image NO 5, time comsuption 0.007754s
# count:153600,TP:1686,TN:151028,FP:551,FN335
# processing image NO 6, time comsuption 0.007833s
# count:153600,TP:1742,TN:151072,FP:364,FN422
# processing image NO 7, time comsuption 0.007633s
# count:153600,TP:1267,TN:151430,FP:775,FN128
# processing image NO 8, time comsuption 0.007356s
# count:153600,TP:1106,TN:150872,FP:1472,FN150
# processing image NO 9, time comsuption 0.008157s
# count:153600,TP:1470,TN:150542,FP:800,FN788
# processing image NO 10, time comsuption 0.007692s
# count:153600,TP:1191,TN:151336,FP:871,FN202
# processing image NO 11, time comsuption 0.007380s
# count:153600,TP:1077,TN:151255,FP:1006,FN262
# processing image NO 12, time comsuption 0.007852s
# count:153600,TP:946,TN:151175,FP:1112,FN367
# processing image NO 13, time comsuption 0.008472s
# count:153600,TP:1156,TN:151204,FP:778,FN462
# processing image NO 14, time comsuption 0.008257s
# count:153600,TP:1280,TN:151185,FP:686,FN449
# processing image NO 15, time comsuption 0.008016s
# count:153600,TP:1657,TN:150763,FP:540,FN640
# processing image NO 16, time comsuption 0.007693s
# count:153600,TP:1049,TN:151492,FP:891,FN168
# processing image NO 17, time comsuption 0.007914s
# count:153600,TP:1203,TN:151111,FP:840,FN446
# processing image NO 18, time comsuption 0.010217s
# count:153600,TP:1321,TN:151219,FP:748,FN312
# processing image NO 19, time comsuption 0.007512s
# count:153600,TP:1267,TN:151441,FP:573,FN319
# processing image NO 20, time comsuption 0.007792s
# count:153600,TP:1511,TN:150582,FP:855,FN652
# processing image NO 21, time comsuption 0.007696s
# count:153600,TP:1174,TN:151353,FP:738,FN335
# processing image NO 22, time comsuption 0.007801s
# count:153600,TP:1564,TN:150844,FP:626,FN566
# processing image NO 23, time comsuption 0.007773s
# count:153600,TP:1036,TN:151561,FP:766,FN237
# processing image NO 24, time comsuption 0.007663s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 40/201], [loss:0.130062], accuracy:0.992599]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:41],[batch_count:1.0],[loss:0.137646],[accuracy:0.987371]
# [Epocn:41],[batch_count:2.0],[loss:0.136503],[accuracy:0.987313]
# [Epocn:41],[batch_count:3.0],[loss:0.136707],[accuracy:0.987692]
# [Epocn:41],[batch_count:4.0],[loss:0.136425],[accuracy:0.986764]
# [Epocn:41],[batch_count:5.0],[loss:0.133015],[accuracy:0.990502]
# [Epocn:41],[batch_count:6.0],[loss:0.132281],[accuracy:0.990432]
# [Epocn:41],[batch_count:7.0],[loss:0.130120],[accuracy:0.991468]
# [Epocn:41],[batch_count:8.0],[loss:0.136449],[accuracy:0.986663]
# [Epocn:41],[batch_count:9.0],[loss:0.131721],[accuracy:0.991865]
# [Epocn:41],[batch_count:10.0],[loss:0.129329],[accuracy:0.992503]
# [Epoch 41/201], [loss:0.134019], accuracy:0.989257]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:42],[batch_count:1.0],[loss:0.132886],[accuracy:0.989651]
# [Epocn:42],[batch_count:2.0],[loss:0.129258],[accuracy:0.991788]
# [Epocn:42],[batch_count:3.0],[loss:0.135360],[accuracy:0.986247]
# [Epocn:42],[batch_count:4.0],[loss:0.128394],[accuracy:0.992141]
# [Epocn:42],[batch_count:5.0],[loss:0.137344],[accuracy:0.984505]
# [Epocn:42],[batch_count:6.0],[loss:0.129427],[accuracy:0.990607]
