# %%
# !nvidia-smi # 查看GPU信息
# Out:
# Fri Jun 12 17:27:37 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 进入需要训练项目的文件夹
# %cd /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate5
# Out:
# /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate5

# %%
# !pip install xlutils
# Out:
# Collecting xlutils
#   Downloading https://files.pythonhosted.org/packages/c7/55/e22ac73dbb316cabb5db28bef6c87044a95914f713a6e81b593f8a0d2f79/xlutils-2.0.0-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 6.1MB/s
# Requirement already satisfied: xlwt>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.3.0)
# Requirement already satisfied: xlrd>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.1.0)
# Installing collected packages: xlutils
# Successfully installed xlutils-2.0.0

# %%
from models_deepcrack_unet import SegmentNet, weights_init_normal
from dataset_deepcrack_unet import CFDDataset

import torch.nn as nn
import torch

from torchvision import datasets
from torchvision.utils import save_image
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

import os
import sys
import argparse
import time
import PIL.Image as Image

import numpy as np

import xlwt
import xlrd
from xlutils.copy import copy

# %%
# 在ipynb文件中，parse的创建用函数来创建
# 直接用parser=parser = argparse.ArgumentParser() 来创建之后调用会报错

def get_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--cuda", type=bool, default=True, help="number of gpu")
    parser.add_argument("--gpu_num", type=int, default=1, help="number of gpu")
    parser.add_argument("--worker_num", type=int, default=0, help="number of input workers") # 只有一个GPU,default=0表示单进程加载
    parser.add_argument("--batch_size", type=int, default=6, help="batch size of input")
    parser.add_argument("--lr", type=float, default=0.01, help="adam: learning rate")
    parser.add_argument("--b1", type=float, default=0.90, help="adam: decay of first order momentum of gradient")
    parser.add_argument("--b2", type=float, default=0.997, help="adam: decay of second order momentum of gradient")
    parser.add_argument("--weight_decay", type=float, default=0.0005, help="adam: weight decay coefficient")

    parser.add_argument("--begin_epoch", type=int, default=1, help="begin_epoch")
    parser.add_argument("--end_epoch", type=int, default=201, help="end_epoch")

    parser.add_argument("--need_test", type=bool, default=True, help="need to test")
    parser.add_argument("--test_interval", type=int, default=10, help="interval of test")
    parser.add_argument("--need_save", type=bool, default=True, help="need to save")
    parser.add_argument("--save_interval", type=int, default=10, help="interval of save weights")

    parser.add_argument("--img_width", type=int, default=480, help="size of image width")
    parser.add_argument("--img_height", type=int, default=320, help="size of image height")
    
    return parser.parse_args(args=[])

opt = get_arguments()

print(opt)
# Out:
# Namespace(b1=0.9, b2=0.997, batch_size=6, begin_epoch=1, cuda=True, end_epoch=201, gpu_num=1, img_height=320, img_width=480, lr=0.01, need_save=True, need_test=True, save_interval=10, test_interval=10, weight_decay=0.0005, worker_num=0)

# %%
dataSetRoot = "../Data_cleaned"

# %%
# 建立网络
segment_net = SegmentNet(init_weights=True)

# 选择二分类交叉熵损失函数
criterion_segment  = torch.nn.BCELoss()

# %%
# 选择Adam优化器
optimizer_seg = torch.optim.Adam(segment_net.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=opt.weight_decay)

# 指数方式调整学习率，每一个epoch之后学习率变为原来的0.98倍
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_seg, gamma=0.98)

# %%
# 选择训练环境和参数
if opt.cuda:
    segment_net = segment_net.cuda()
    criterion_segment.cuda()

if opt.gpu_num > 1:
    segment_net = torch.nn.DataParallel(segment_net, device_ids=list(range(opt.gpu_num)))

if opt.begin_epoch != 1:
    # 加载前期训练的模型
    segment_net.load_state_dict(torch.load("./saved_models/segment_net_%d.pth" % (opt.begin_epoch-1)))
else:
    # 初始化权重
    segment_net.apply(weights_init_normal)

# %%
# 对原始数据和真实值进行一定前期处理，方便后续训练
transforms_ = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width), Image.BICUBIC),
    transforms.ToTensor()
])

transforms_mask = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width)), 
    transforms.ToTensor()
])

# %%
# 加载训练集和测试集
trainCFDloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask, subFold="CFD", isTrain=True),
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.worker_num,
)

testloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask,  subFold="CFD/cfd_TEST", isTrain=True),
    batch_size=1,
    shuffle=False,
    num_workers=opt.worker_num
)

# %%
# 定义对输出结果进行阈值化处理的函数，将小于阈值的计算为0，大于阈值的计算为1，在图像中像素为1的点为白色，为0的点为黑色
def data_threshold(data, threshold):
    threshold = torch.Tensor([threshold]).cuda()
    data_target = torch.Tensor([i//threshold for i in data]).cuda()
    return data_target

# %%
# 获取训练之后的 accuracy, precision , recall ,F1评价指标
# mask是真实值，data是预测值
def evaluate_metric(mask, data):
    m = metrics.confusion_matrix(mask, data)
    count_TP = m[1, 1]
    count_TN = m[0, 0]
    count_FN = m[1, 0] 
    count_FP = m[0 ,1]
    
    count = count_TP + count_FN + count_FP +count_TN
    print("count:{0},TP:{1},TN:{2},FP:{3},FN:{4}".format(count, count_TP, count_TN, count_FP, count_FN))  
    
    # 准确率
    accuracy = (count_TP+count_TN)/count 
    # 精准率
    precision = count_TP / (count_TP + count_FP) 
    # 查全率
    recall = count_TP / (count_TP + count_FN)
    # F1分
    F1 = 2*count_TP/(2*count_TP + count_FP + count_FN)
    
    return accuracy, precision, recall, F1

# %%
if opt.begin_epoch == 1:
  # 将训练过程的需要保存的数据保存到xls文件中
  # 创建一个workbook，设置编码
  workbook = xlwt.Workbook(encoding = 'utf-8')

  #---------------------写入训练过程的epoch, loss, accuracy------------------
  # 创建一个worksheet
  worksheet = workbook.add_sheet('sheet1')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')

  #---------------------写入测试过程的epoch, loss, accuracy------------------
  worksheet = workbook.add_sheet('sheet2')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')
                  
  #---------------------写入测试过程的epoch, accuracy, precision, recall, F1------------------                
  worksheet = workbook.add_sheet('sheet3')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'accuracy')
  worksheet.write(0, 2, 'precision')
  worksheet.write(0, 3, 'recall')
  worksheet.write(0, 4, 'F1')

  # 保存
  workbook.save('evaluate_data.xls')

def write_excel_xls_append(path, value, sheet_num):
  index = len(value)  # 获取需要写入数据的行数
  workbook = xlrd.open_workbook(path)            # 打开工作簿
  sheets = workbook.sheet_names()                # 获取工作簿中的所有表格
  worksheet = workbook.sheet_by_name(sheets[sheet_num])  # 获取工作簿中所有表格中的的第一个表格
  rows_old = worksheet.nrows                 # 获取表格中已存在的数据的行数
  new_workbook = copy(workbook)                # 将xlrd对象拷贝转化为xlwt对象
  new_worksheet = new_workbook.get_sheet(sheet_num)      # 获取转化后工作簿中的第sheet_num个表格
  
  for i in range(0, index):
      new_worksheet.write(rows_old, i, value[i])  # 追加写入数据
  new_workbook.save(path)  # 保存工作簿
  print("xls格式表格[追加]写入数据成功！")

# %%
for epoch in range(opt.begin_epoch, opt.end_epoch):

  iterCFD = trainCFDloader.__iter__()

  lenNum = len(trainCFDloader)

  segment_net.train()

  # -----------------------------------------------------------------------------
  # 开始训练
  # 记录每一个epoch的总损失和总精度
  train_loss_sum, train_acc_sum, batch_count = 0.0, 0.0, 0.0

  for i in range(0, lenNum):
      
    batchData = iterCFD.__next__()

    if opt.cuda:
        img = batchData["img"].cuda()
        mask = batchData["mask"].cuda()
    else:
        img = batchData["img"]
        mask = batchData["mask"]

    optimizer_seg.zero_grad()

    rst = segment_net(img)
    seg = rst["seg"]

    # 计算训练过程的损失loss
    loss_seg = 0.45*criterion_segment(seg, mask)+0.25*criterion_segment(rst["scale4"], mask)+0.15*criterion_segment(rst["scale3"], mask)\
            +0.1*criterion_segment(rst["scale2"], mask)+0.05*criterion_segment(rst["scale1"], mask)
    loss_seg.backward()
    optimizer_seg.step()

    train_loss_sum += loss_seg.item() 
    
    # 计算训练过程的accuracy
    net_seg = data_threshold(seg.clone().flatten(), 0.5)    # 预测值
    mask_seg = mask.clone().flatten()              # 真实值
    
    # 对每个像素点的值进行比较，相同的点计入right_seg 
    right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
    total_num = float(mask.clone().flatten().size()[0])
    
    batch_acc = right_seg/total_num
    train_acc_sum += batch_acc
    
    batch_count += 1
    
    # 输出每个epoch之中每个batch的信息
    print("[Epocn:{0}],[batch_count:{1}],[loss:{2:.6f}],[accuracy:{3:.6f}]".format(epoch, batch_count, loss_seg.item(), batch_acc))
    

  
  # 输出训练过程每个epoch平均的loss和accuracy
  print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, train_loss_sum/batch_count, train_acc_sum/batch_count))
    
  # 将上述epoch, loss, accuracy数据写入xls文件
  print("------------------------------------------------------------------------------------------")
  print("开始写入训练过程的epoch, loss, accuracy")
  train_xls_value = [epoch, train_loss_sum/batch_count, train_acc_sum/batch_count]
  write_excel_xls_append("evaluate_data.xls", train_xls_value, 0)
  print("------------------------------------------------------------------------------------------")
  

  # -----------------------------------------------------------------------------
  # 以一定周期保存训练之后的模型
  if opt.need_save and epoch % opt.save_interval == 0 and epoch >= opt.save_interval:

    save_path_str = "./saved_models"
    if os.path.exists(save_path_str) == False:
        os.makedirs(save_path_str, exist_ok=True)

    torch.save(segment_net.state_dict(), "%s/segment_net_%d.pth" % (save_path_str, epoch))
    print("------------------------------------------------------------------------------------------")
    print("save weights ! epoch = %d" %epoch)
    print("------------------------------------------------------------------------------------------")
    pass
    

  # -----------------------------------------------------------------------------
  # 对模型进行测试，并保存结果
  if opt.need_test and epoch % opt.test_interval == 0 and epoch >= opt.test_interval:

    test_loss_sum, test_acc_sum, batch_count = 0.0, 0.0, 0.0
    result_evaluate_epoch = np.array([0.0, 0.0, 0.0, 0.0])

    for i, testBatch in enumerate(testloader):
      imgTest = testBatch["img"].cuda()
      t1 = time.time()
      rstTest = segment_net(imgTest)
      t2 = time.time()

      # 计算测试过程的损失loss
      mask = testBatch["mask"].cuda()
      loss_test = criterion_segment(rstTest["seg"], mask)

      test_loss_sum += loss_test.item()

      # 计算测试过程的accuracy
      net_seg = data_threshold(rstTest["seg"].clone().flatten(), 0.5)  # 预测值
      mask_seg = mask.clone().flatten()                  # 真实值
      
      # 对每个像素点的值进行比较，相同的点计入right_seg 
      right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
      total_num = float(mask.clone().flatten().size()[0])
      
      batch_acc = right_seg/total_num
      test_acc_sum += batch_acc
      
      batch_count += 1

      # 对一个batch测试结果进行综合评估，并进行累加，方便后续保存
      result_evaluate_batch = np.array(list(evaluate_metric(mask_seg, net_seg)))
      result_evaluate_epoch += result_evaluate_batch
      
      # 对保存的图片进行阈值化处理
      seg_shape = rstTest["seg"].data.shape
      segTest_flatten = data_threshold(rstTest["seg"].flatten(), 0.5)
      segTest = segTest_flatten.reshape(seg_shape[0], seg_shape[1], seg_shape[2], seg_shape[3])

      # 建立文件的保存路径
      save_path_str = "./testResultSeg/epoch_%d"%(epoch)
      if os.path.exists(save_path_str) == False:
          os.makedirs(save_path_str, exist_ok=True)

      # 输出文件的保存信息
      print("processing image NO %d, time comsuption %fs"%(i, t2 - t1))
      save_image(imgTest.data, "%s/img_%d.jpg"% (save_path_str, i))
      save_image(segTest.data, "%s/img_%d_seg.jpg"% (save_path_str, i))
      save_image(rstTest["seg"].data, "%s/img_%d_raw_seg.jpg"% (save_path_str, i))

    # 将上述测试过程的评估参数acc,precision,recall和F1分数进行保存
    print("------------------------------------------------------------------------------------------")
    print("开始写入评估参数")
    result_evaluate_epoch = result_evaluate_epoch/np.array([batch_count])
    test_xls_metric = [epoch] + list(result_evaluate_epoch)
    write_excel_xls_append("evaluate_data.xls", test_xls_metric, 2)
    print("------------------------------------------------------------------------------------------")
    
    # 输出测试过程每个epoch平均的loss和accuracy
    print("------------------------------------------------------------------------------------------")
    print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, test_loss_sum/batch_count, test_acc_sum/batch_count))
    print("------------------------------------------------------------------------------------------")
    
    # 将上述epoch, loss, accuracy数据写入xls文件
    print("------------------------------------------------------------------------------------------")
    print("开始写入测试过程的epoch, loss, accuracy")
    test_xls_value = [epoch, test_loss_sum/batch_count, test_acc_sum/batch_count]
    write_excel_xls_append("evaluate_data.xls", test_xls_value, 1)
    print("------------------------------------------------------------------------------------------")

  # 利用schedular对学习率进行调节
  scheduler.step()
# Out:
# [Epocn:1],[batch_count:1.0],[loss:0.783423],[accuracy:0.536606]
# [Epocn:1],[batch_count:2.0],[loss:0.693826],[accuracy:0.836938]
# [Epocn:1],[batch_count:3.0],[loss:0.735478],[accuracy:0.803160]
# [Epocn:1],[batch_count:4.0],[loss:0.676990],[accuracy:0.825601]
# [Epocn:1],[batch_count:5.0],[loss:0.642757],[accuracy:0.847877]
# [Epocn:1],[batch_count:6.0],[loss:0.656677],[accuracy:0.843823]
# [Epocn:1],[batch_count:7.0],[loss:0.698938],[accuracy:0.841872]
# [Epocn:1],[batch_count:8.0],[loss:0.615157],[accuracy:0.898252]
# [Epocn:1],[batch_count:9.0],[loss:0.606913],[accuracy:0.917744]
# [Epocn:1],[batch_count:10.0],[loss:0.637563],[accuracy:0.916743]
# [Epoch 1/201], [loss:0.674772], accuracy:0.826862]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:2],[batch_count:1.0],[loss:0.599383],[accuracy:0.942474]
# [Epocn:2],[batch_count:2.0],[loss:0.604683],[accuracy:0.940544]
# [Epocn:2],[batch_count:3.0],[loss:0.595649],[accuracy:0.930089]
# [Epocn:2],[batch_count:4.0],[loss:0.584989],[accuracy:0.930711]
# [Epocn:2],[batch_count:5.0],[loss:0.605027],[accuracy:0.910551]
# [Epocn:2],[batch_count:6.0],[loss:0.560313],[accuracy:0.959992]
# [Epocn:2],[batch_count:7.0],[loss:0.567992],[accuracy:0.941876]
# [Epocn:2],[batch_count:8.0],[loss:0.581637],[accuracy:0.941836]
# [Epocn:2],[batch_count:9.0],[loss:0.569741],[accuracy:0.951485]
# [Epocn:2],[batch_count:10.0],[loss:0.571758],[accuracy:0.908431]
# [Epoch 2/201], [loss:0.584117], accuracy:0.935799]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:3],[batch_count:1.0],[loss:0.542083],[accuracy:0.944368]
# [Epocn:3],[batch_count:2.0],[loss:0.531881],[accuracy:0.950250]
# [Epocn:3],[batch_count:3.0],[loss:0.541738],[accuracy:0.939973]
# [Epocn:3],[batch_count:4.0],[loss:0.529166],[accuracy:0.914698]
# [Epocn:3],[batch_count:5.0],[loss:0.543170],[accuracy:0.923838]
# [Epocn:3],[batch_count:6.0],[loss:0.544051],[accuracy:0.947972]
# [Epocn:3],[batch_count:7.0],[loss:0.536940],[accuracy:0.953803]
# [Epocn:3],[batch_count:8.0],[loss:0.557709],[accuracy:0.940450]
# [Epocn:3],[batch_count:9.0],[loss:0.592129],[accuracy:0.842768]
# [Epocn:3],[batch_count:10.0],[loss:0.528065],[accuracy:0.922352]
# [Epoch 3/201], [loss:0.544693], accuracy:0.928047]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:4],[batch_count:1.0],[loss:0.529892],[accuracy:0.935820]
# [Epocn:4],[batch_count:2.0],[loss:0.504363],[accuracy:0.941573]
# [Epocn:4],[batch_count:3.0],[loss:0.537799],[accuracy:0.905678]
# [Epocn:4],[batch_count:4.0],[loss:0.553414],[accuracy:0.920866]
# [Epocn:4],[batch_count:5.0],[loss:0.537006],[accuracy:0.934147]
# [Epocn:4],[batch_count:6.0],[loss:0.503280],[accuracy:0.963277]
# [Epocn:4],[batch_count:7.0],[loss:0.499931],[accuracy:0.953665]
# [Epocn:4],[batch_count:8.0],[loss:0.491891],[accuracy:0.959831]
# [Epocn:4],[batch_count:9.0],[loss:0.469796],[accuracy:0.959027]
# [Epocn:4],[batch_count:10.0],[loss:0.492786],[accuracy:0.928651]
# [Epoch 4/201], [loss:0.512016], accuracy:0.940254]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:5],[batch_count:1.0],[loss:0.489275],[accuracy:0.937088]
# [Epocn:5],[batch_count:2.0],[loss:0.477646],[accuracy:0.939414]
# [Epocn:5],[batch_count:3.0],[loss:0.472146],[accuracy:0.958838]
# [Epocn:5],[batch_count:4.0],[loss:0.483554],[accuracy:0.938126]
# [Epocn:5],[batch_count:5.0],[loss:0.467644],[accuracy:0.958891]
# [Epocn:5],[batch_count:6.0],[loss:0.470080],[accuracy:0.965660]
# [Epocn:5],[batch_count:7.0],[loss:0.462843],[accuracy:0.965163]
# [Epocn:5],[batch_count:8.0],[loss:0.460788],[accuracy:0.954980]
# [Epocn:5],[batch_count:9.0],[loss:0.461644],[accuracy:0.955826]
# [Epocn:5],[batch_count:10.0],[loss:0.462007],[accuracy:0.954719]
# [Epoch 5/201], [loss:0.470763], accuracy:0.952870]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:6],[batch_count:1.0],[loss:0.435750],[accuracy:0.969569]
# [Epocn:6],[batch_count:2.0],[loss:0.450811],[accuracy:0.966149]
# [Epocn:6],[batch_count:3.0],[loss:0.448553],[accuracy:0.970908]
# [Epocn:6],[batch_count:4.0],[loss:0.448671],[accuracy:0.961525]
# [Epocn:6],[batch_count:5.0],[loss:0.432784],[accuracy:0.973708]
# [Epocn:6],[batch_count:6.0],[loss:0.457930],[accuracy:0.945567]
# [Epocn:6],[batch_count:7.0],[loss:0.419247],[accuracy:0.970959]
# [Epocn:6],[batch_count:8.0],[loss:0.437650],[accuracy:0.958715]
# [Epocn:6],[batch_count:9.0],[loss:0.429067],[accuracy:0.968638]
# [Epocn:6],[batch_count:10.0],[loss:0.439943],[accuracy:0.954904]
# [Epoch 6/201], [loss:0.440041], accuracy:0.964064]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:7],[batch_count:1.0],[loss:0.430160],[accuracy:0.956845]
# [Epocn:7],[batch_count:2.0],[loss:0.416615],[accuracy:0.970731]
# [Epocn:7],[batch_count:3.0],[loss:0.418648],[accuracy:0.971664]
# [Epocn:7],[batch_count:4.0],[loss:0.411533],[accuracy:0.962375]
# [Epocn:7],[batch_count:5.0],[loss:0.416628],[accuracy:0.953980]
# [Epocn:7],[batch_count:6.0],[loss:0.410179],[accuracy:0.968475]
# [Epocn:7],[batch_count:7.0],[loss:0.402782],[accuracy:0.968192]
# [Epocn:7],[batch_count:8.0],[loss:0.412554],[accuracy:0.970388]
# [Epocn:7],[batch_count:9.0],[loss:0.386594],[accuracy:0.971128]
# [Epocn:7],[batch_count:10.0],[loss:0.415880],[accuracy:0.960495]
# [Epoch 7/201], [loss:0.412157], accuracy:0.965428]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:8],[batch_count:1.0],[loss:0.421166],[accuracy:0.951018]
# [Epocn:8],[batch_count:2.0],[loss:0.387128],[accuracy:0.967024]
# [Epocn:8],[batch_count:3.0],[loss:0.397926],[accuracy:0.960095]
# [Epocn:8],[batch_count:4.0],[loss:0.375094],[accuracy:0.973253]
# [Epocn:8],[batch_count:5.0],[loss:0.384901],[accuracy:0.970921]
# [Epocn:8],[batch_count:6.0],[loss:0.391201],[accuracy:0.958120]
# [Epocn:8],[batch_count:7.0],[loss:0.387677],[accuracy:0.967091]
# [Epocn:8],[batch_count:8.0],[loss:0.381457],[accuracy:0.973312]
# [Epocn:8],[batch_count:9.0],[loss:0.385976],[accuracy:0.969262]
# [Epocn:8],[batch_count:10.0],[loss:0.363115],[accuracy:0.979822]
# [Epoch 8/201], [loss:0.387564], accuracy:0.966992]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:9],[batch_count:1.0],[loss:0.360430],[accuracy:0.971161]
# [Epocn:9],[batch_count:2.0],[loss:0.392530],[accuracy:0.962715]
# [Epocn:9],[batch_count:3.0],[loss:0.373157],[accuracy:0.965972]
# [Epocn:9],[batch_count:4.0],[loss:0.367387],[accuracy:0.978628]
# [Epocn:9],[batch_count:5.0],[loss:0.364776],[accuracy:0.970256]
# [Epocn:9],[batch_count:6.0],[loss:0.375914],[accuracy:0.966037]
# [Epocn:9],[batch_count:7.0],[loss:0.353375],[accuracy:0.973570]
# [Epocn:9],[batch_count:8.0],[loss:0.356547],[accuracy:0.961532]
# [Epocn:9],[batch_count:9.0],[loss:0.390781],[accuracy:0.949149]
# [Epocn:9],[batch_count:10.0],[loss:0.352822],[accuracy:0.971066]
# [Epoch 9/201], [loss:0.368772], accuracy:0.967009]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:10],[batch_count:1.0],[loss:0.352219],[accuracy:0.973723]
# [Epocn:10],[batch_count:2.0],[loss:0.355516],[accuracy:0.971077]
# [Epocn:10],[batch_count:3.0],[loss:0.354264],[accuracy:0.950584]
# [Epocn:10],[batch_count:4.0],[loss:0.330225],[accuracy:0.976251]
# [Epocn:10],[batch_count:5.0],[loss:0.353693],[accuracy:0.965523]
# [Epocn:10],[batch_count:6.0],[loss:0.361894],[accuracy:0.952549]
# [Epocn:10],[batch_count:7.0],[loss:0.338303],[accuracy:0.972792]
# [Epocn:10],[batch_count:8.0],[loss:0.334100],[accuracy:0.979887]
# [Epocn:10],[batch_count:9.0],[loss:0.350736],[accuracy:0.968300]
# [Epocn:10],[batch_count:10.0],[loss:0.335086],[accuracy:0.972734]
# [Epoch 10/201], [loss:0.346604], accuracy:0.968342]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 10
# ------------------------------------------------------------------------------------------
# count:153600,TP:4179,TN:147448,FP:1283,FN690
# processing image NO 0, time comsuption 0.008025s
# count:153600,TP:4168,TN:147351,FP:1154,FN927
# processing image NO 1, time comsuption 0.007695s
# count:153600,TP:6424,TN:143410,FP:1290,FN2476
# processing image NO 2, time comsuption 0.007587s
# count:153600,TP:3530,TN:146098,FP:1836,FN2136
# processing image NO 3, time comsuption 0.007558s
# count:153600,TP:4001,TN:148113,FP:1396,FN90
# processing image NO 4, time comsuption 0.007828s
# count:153600,TP:4009,TN:148042,FP:1325,FN224
# processing image NO 5, time comsuption 0.007946s
# count:153600,TP:4806,TN:146804,FP:1253,FN737
# processing image NO 6, time comsuption 0.007534s
# count:153600,TP:4697,TN:147600,FP:964,FN339
# processing image NO 7, time comsuption 0.008026s
# count:153600,TP:4008,TN:147637,FP:1525,FN430
# processing image NO 8, time comsuption 0.007684s
# count:153600,TP:3504,TN:146195,FP:3486,FN415
# processing image NO 9, time comsuption 0.008092s
# count:153600,TP:3993,TN:144733,FP:1728,FN3146
# processing image NO 10, time comsuption 0.007990s
# count:153600,TP:3645,TN:147110,FP:2437,FN408
# processing image NO 11, time comsuption 0.007581s
# count:153600,TP:3321,TN:146122,FP:3519,FN638
# processing image NO 12, time comsuption 0.007713s
# count:153600,TP:2428,TN:144232,FP:5505,FN1435
# processing image NO 13, time comsuption 0.007695s
# count:153600,TP:3500,TN:146345,FP:2036,FN1719
# processing image NO 14, time comsuption 0.007515s
# count:153600,TP:3690,TN:146412,FP:2447,FN1051
# processing image NO 15, time comsuption 0.007445s
# count:153600,TP:4197,TN:146805,FP:1378,FN1220
# processing image NO 16, time comsuption 0.008385s
# count:153600,TP:3436,TN:148055,FP:1559,FN550
# processing image NO 17, time comsuption 0.007644s
# count:153600,TP:3675,TN:146780,FP:2204,FN941
# processing image NO 18, time comsuption 0.007547s
# count:153600,TP:3632,TN:147095,FP:1718,FN1155
# processing image NO 19, time comsuption 0.007678s
# count:153600,TP:3589,TN:147914,FP:1219,FN878
# processing image NO 20, time comsuption 0.007502s
# count:153600,TP:4711,TN:145435,FP:1689,FN1765
# processing image NO 21, time comsuption 0.007791s
# count:153600,TP:3385,TN:146144,FP:3299,FN772
# processing image NO 22, time comsuption 0.007505s
# count:153600,TP:4269,TN:146693,FP:1259,FN1379
# processing image NO 23, time comsuption 0.007466s
# count:153600,TP:3153,TN:147368,FP:2499,FN580
# processing image NO 24, time comsuption 0.007481s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 10/201], [loss:0.325585], accuracy:0.980180]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:11],[batch_count:1.0],[loss:0.344105],[accuracy:0.972905]
# [Epocn:11],[batch_count:2.0],[loss:0.358128],[accuracy:0.967141]
# [Epocn:11],[batch_count:3.0],[loss:0.334330],[accuracy:0.978406]
# [Epocn:11],[batch_count:4.0],[loss:0.326926],[accuracy:0.968543]
# [Epocn:11],[batch_count:5.0],[loss:0.326563],[accuracy:0.970416]
# [Epocn:11],[batch_count:6.0],[loss:0.330200],[accuracy:0.964609]
# [Epocn:11],[batch_count:7.0],[loss:0.317990],[accuracy:0.971187]
# [Epocn:11],[batch_count:8.0],[loss:0.334044],[accuracy:0.961697]
# [Epocn:11],[batch_count:9.0],[loss:0.317619],[accuracy:0.969881]
# [Epocn:11],[batch_count:10.0],[loss:0.304142],[accuracy:0.982177]
# [Epoch 11/201], [loss:0.329405], accuracy:0.970696]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:12],[batch_count:1.0],[loss:0.321819],[accuracy:0.968764]
# [Epocn:12],[batch_count:2.0],[loss:0.315749],[accuracy:0.974470]
# [Epocn:12],[batch_count:3.0],[loss:0.337743],[accuracy:0.954461]
# [Epocn:12],[batch_count:4.0],[loss:0.311691],[accuracy:0.960639]
# [Epocn:12],[batch_count:5.0],[loss:0.299050],[accuracy:0.968443]
# [Epocn:12],[batch_count:6.0],[loss:0.343396],[accuracy:0.951576]
# [Epocn:12],[batch_count:7.0],[loss:0.319297],[accuracy:0.966306]
# [Epocn:12],[batch_count:8.0],[loss:0.324462],[accuracy:0.966514]
# [Epocn:12],[batch_count:9.0],[loss:0.309285],[accuracy:0.974370]
# [Epocn:12],[batch_count:10.0],[loss:0.313467],[accuracy:0.967814]
# [Epoch 12/201], [loss:0.319596], accuracy:0.965336]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:13],[batch_count:1.0],[loss:0.315257],[accuracy:0.972622]
# [Epocn:13],[batch_count:2.0],[loss:0.303999],[accuracy:0.972079]
# [Epocn:13],[batch_count:3.0],[loss:0.302356],[accuracy:0.974692]
# [Epocn:13],[batch_count:4.0],[loss:0.291831],[accuracy:0.977959]
# [Epocn:13],[batch_count:5.0],[loss:0.283775],[accuracy:0.985624]
# [Epocn:13],[batch_count:6.0],[loss:0.298596],[accuracy:0.972786]
# [Epocn:13],[batch_count:7.0],[loss:0.293251],[accuracy:0.977378]
# [Epocn:13],[batch_count:8.0],[loss:0.289475],[accuracy:0.977192]
# [Epocn:13],[batch_count:9.0],[loss:0.307316],[accuracy:0.958966]
# [Epocn:13],[batch_count:10.0],[loss:0.291264],[accuracy:0.968158]
# [Epoch 13/201], [loss:0.297712], accuracy:0.973746]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:14],[batch_count:1.0],[loss:0.280558],[accuracy:0.974338]
# [Epocn:14],[batch_count:2.0],[loss:0.298638],[accuracy:0.967534]
# [Epocn:14],[batch_count:3.0],[loss:0.278750],[accuracy:0.968655]
# [Epocn:14],[batch_count:4.0],[loss:0.289418],[accuracy:0.971069]
# [Epocn:14],[batch_count:5.0],[loss:0.277059],[accuracy:0.976811]
# [Epocn:14],[batch_count:6.0],[loss:0.291332],[accuracy:0.963423]
# [Epocn:14],[batch_count:7.0],[loss:0.302602],[accuracy:0.960199]
# [Epocn:14],[batch_count:8.0],[loss:0.279000],[accuracy:0.980869]
# [Epocn:14],[batch_count:9.0],[loss:0.294248],[accuracy:0.971927]
# [Epocn:14],[batch_count:10.0],[loss:0.292290],[accuracy:0.967108]
# [Epoch 14/201], [loss:0.288390], accuracy:0.970193]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:15],[batch_count:1.0],[loss:0.279681],[accuracy:0.976271]
# [Epocn:15],[batch_count:2.0],[loss:0.274696],[accuracy:0.976099]
# [Epocn:15],[batch_count:3.0],[loss:0.277745],[accuracy:0.977992]
# [Epocn:15],[batch_count:4.0],[loss:0.271079],[accuracy:0.979232]
# [Epocn:15],[batch_count:5.0],[loss:0.273184],[accuracy:0.967735]
# [Epocn:15],[batch_count:6.0],[loss:0.269428],[accuracy:0.976494]
# [Epocn:15],[batch_count:7.0],[loss:0.286064],[accuracy:0.962674]
# [Epocn:15],[batch_count:8.0],[loss:0.267690],[accuracy:0.969138]
# [Epocn:15],[batch_count:9.0],[loss:0.295404],[accuracy:0.960388]
# [Epocn:15],[batch_count:10.0],[loss:0.263645],[accuracy:0.970630]
# [Epoch 15/201], [loss:0.275862], accuracy:0.971665]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:16],[batch_count:1.0],[loss:0.268120],[accuracy:0.972738]
# [Epocn:16],[batch_count:2.0],[loss:0.272661],[accuracy:0.974970]
# [Epocn:16],[batch_count:3.0],[loss:0.257041],[accuracy:0.979058]
# [Epocn:16],[batch_count:4.0],[loss:0.250638],[accuracy:0.982650]
# [Epocn:16],[batch_count:5.0],[loss:0.279380],[accuracy:0.960018]
# [Epocn:16],[batch_count:6.0],[loss:0.265238],[accuracy:0.972855]
# [Epocn:16],[batch_count:7.0],[loss:0.256293],[accuracy:0.969014]
# [Epocn:16],[batch_count:8.0],[loss:0.268966],[accuracy:0.964412]
# [Epocn:16],[batch_count:9.0],[loss:0.251586],[accuracy:0.978967]
# [Epocn:16],[batch_count:10.0],[loss:0.254018],[accuracy:0.973348]
# [Epoch 16/201], [loss:0.262394], accuracy:0.972803]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:17],[batch_count:1.0],[loss:0.250625],[accuracy:0.970903]
# [Epocn:17],[batch_count:2.0],[loss:0.258638],[accuracy:0.972425]
# [Epocn:17],[batch_count:3.0],[loss:0.274414],[accuracy:0.962740]
# [Epocn:17],[batch_count:4.0],[loss:0.249210],[accuracy:0.971502]
# [Epocn:17],[batch_count:5.0],[loss:0.261031],[accuracy:0.966695]
# [Epocn:17],[batch_count:6.0],[loss:0.252898],[accuracy:0.972805]
# [Epocn:17],[batch_count:7.0],[loss:0.238643],[accuracy:0.982362]
# [Epocn:17],[batch_count:8.0],[loss:0.239462],[accuracy:0.975678]
# [Epocn:17],[batch_count:9.0],[loss:0.249875],[accuracy:0.975880]
# [Epocn:17],[batch_count:10.0],[loss:0.258697],[accuracy:0.970268]
# [Epoch 17/201], [loss:0.253349], accuracy:0.972126]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:18],[batch_count:1.0],[loss:0.242763],[accuracy:0.979430]
# [Epocn:18],[batch_count:2.0],[loss:0.238250],[accuracy:0.981828]
# [Epocn:18],[batch_count:3.0],[loss:0.255237],[accuracy:0.966568]
# [Epocn:18],[batch_count:4.0],[loss:0.241117],[accuracy:0.977753]
# [Epocn:18],[batch_count:5.0],[loss:0.239083],[accuracy:0.976066]
# [Epocn:18],[batch_count:6.0],[loss:0.232737],[accuracy:0.979103]
# [Epocn:18],[batch_count:7.0],[loss:0.255851],[accuracy:0.971637]
# [Epocn:18],[batch_count:8.0],[loss:0.237938],[accuracy:0.969063]
# [Epocn:18],[batch_count:9.0],[loss:0.233762],[accuracy:0.975641]
# [Epocn:18],[batch_count:10.0],[loss:0.224220],[accuracy:0.975017]
# [Epoch 18/201], [loss:0.240096], accuracy:0.975211]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:19],[batch_count:1.0],[loss:0.245323],[accuracy:0.973717]
# [Epocn:19],[batch_count:2.0],[loss:0.237703],[accuracy:0.971224]
# [Epocn:19],[batch_count:3.0],[loss:0.230462],[accuracy:0.979548]
# [Epocn:19],[batch_count:4.0],[loss:0.246897],[accuracy:0.966332]
# [Epocn:19],[batch_count:5.0],[loss:0.224010],[accuracy:0.981693]
# [Epocn:19],[batch_count:6.0],[loss:0.240532],[accuracy:0.966543]
# [Epocn:19],[batch_count:7.0],[loss:0.229490],[accuracy:0.974171]
# [Epocn:19],[batch_count:8.0],[loss:0.233807],[accuracy:0.972401]
# [Epocn:19],[batch_count:9.0],[loss:0.212793],[accuracy:0.983933]
# [Epocn:19],[batch_count:10.0],[loss:0.224096],[accuracy:0.972311]
# [Epoch 19/201], [loss:0.232511], accuracy:0.974187]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:20],[batch_count:1.0],[loss:0.223516],[accuracy:0.979112]
# [Epocn:20],[batch_count:2.0],[loss:0.219926],[accuracy:0.978828]
# [Epocn:20],[batch_count:3.0],[loss:0.231734],[accuracy:0.968614]
# [Epocn:20],[batch_count:4.0],[loss:0.226226],[accuracy:0.979390]
# [Epocn:20],[batch_count:5.0],[loss:0.230395],[accuracy:0.977125]
# [Epocn:20],[batch_count:6.0],[loss:0.240757],[accuracy:0.964950]
# [Epocn:20],[batch_count:7.0],[loss:0.222129],[accuracy:0.973353]
# [Epocn:20],[batch_count:8.0],[loss:0.213019],[accuracy:0.973651]
# [Epocn:20],[batch_count:9.0],[loss:0.221231],[accuracy:0.974976]
# [Epocn:20],[batch_count:10.0],[loss:0.224416],[accuracy:0.970212]
# [Epoch 20/201], [loss:0.225335], accuracy:0.974021]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 20
# ------------------------------------------------------------------------------------------
# count:153600,TP:3871,TN:148094,FP:637,FN998
# processing image NO 0, time comsuption 0.007931s
# count:153600,TP:3846,TN:148000,FP:505,FN1249
# processing image NO 1, time comsuption 0.007903s
# count:153600,TP:6144,TN:144094,FP:606,FN2756
# processing image NO 2, time comsuption 0.007625s
# count:153600,TP:3174,TN:146985,FP:949,FN2492
# processing image NO 3, time comsuption 0.007805s
# count:153600,TP:3868,TN:148806,FP:703,FN223
# processing image NO 4, time comsuption 0.007541s
# count:153600,TP:3856,TN:148706,FP:661,FN377
# processing image NO 5, time comsuption 0.007833s
# count:153600,TP:4592,TN:147519,FP:538,FN951
# processing image NO 6, time comsuption 0.007676s
# count:153600,TP:4513,TN:148158,FP:406,FN523
# processing image NO 7, time comsuption 0.007612s
# count:153600,TP:3789,TN:148435,FP:727,FN649
# processing image NO 8, time comsuption 0.007943s
# count:153600,TP:3422,TN:147133,FP:2548,FN497
# processing image NO 9, time comsuption 0.007762s
# count:153600,TP:3830,TN:145455,FP:1006,FN3309
# processing image NO 10, time comsuption 0.007878s
# count:153600,TP:3418,TN:148101,FP:1446,FN635
# processing image NO 11, time comsuption 0.007507s
# count:153600,TP:3082,TN:147631,FP:2010,FN877
# processing image NO 12, time comsuption 0.007357s
# count:153600,TP:2393,TN:145341,FP:4396,FN1470
# processing image NO 13, time comsuption 0.007482s
# count:153600,TP:3139,TN:147210,FP:1171,FN2080
# processing image NO 14, time comsuption 0.007625s
# count:153600,TP:3480,TN:147411,FP:1448,FN1261
# processing image NO 15, time comsuption 0.007941s
# count:153600,TP:4076,TN:147532,FP:651,FN1341
# processing image NO 16, time comsuption 0.007828s
# count:153600,TP:3238,TN:148702,FP:912,FN748
# processing image NO 17, time comsuption 0.007613s
# count:153600,TP:3290,TN:147668,FP:1316,FN1326
# processing image NO 18, time comsuption 0.007756s
# count:153600,TP:3419,TN:147976,FP:837,FN1368
# processing image NO 19, time comsuption 0.007847s
# count:153600,TP:3295,TN:148519,FP:614,FN1172
# processing image NO 20, time comsuption 0.007491s
# count:153600,TP:4604,TN:146148,FP:976,FN1872
# processing image NO 21, time comsuption 0.007623s
# count:153600,TP:3262,TN:147215,FP:2228,FN895
# processing image NO 22, time comsuption 0.007911s
# count:153600,TP:4107,TN:147249,FP:703,FN1541
# processing image NO 23, time comsuption 0.007428s
# count:153600,TP:2990,TN:148501,FP:1366,FN743
# processing image NO 24, time comsuption 0.007360s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 20/201], [loss:0.205057], accuracy:0.984189]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:21],[batch_count:1.0],[loss:0.214060],[accuracy:0.977289]
# [Epocn:21],[batch_count:2.0],[loss:0.214225],[accuracy:0.974103]
# [Epocn:21],[batch_count:3.0],[loss:0.219453],[accuracy:0.971108]
# [Epocn:21],[batch_count:4.0],[loss:0.226986],[accuracy:0.968479]
# [Epocn:21],[batch_count:5.0],[loss:0.226198],[accuracy:0.973391]
# [Epocn:21],[batch_count:6.0],[loss:0.221900],[accuracy:0.972227]
# [Epocn:21],[batch_count:7.0],[loss:0.221365],[accuracy:0.970476]
# [Epocn:21],[batch_count:8.0],[loss:0.212822],[accuracy:0.979709]
# [Epocn:21],[batch_count:9.0],[loss:0.213750],[accuracy:0.978178]
# [Epocn:21],[batch_count:10.0],[loss:0.219237],[accuracy:0.976142]
# [Epoch 21/201], [loss:0.219000], accuracy:0.974110]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:22],[batch_count:1.0],[loss:0.222205],[accuracy:0.970661]
# [Epocn:22],[batch_count:2.0],[loss:0.207061],[accuracy:0.978424]
# [Epocn:22],[batch_count:3.0],[loss:0.216303],[accuracy:0.971013]
# [Epocn:22],[batch_count:4.0],[loss:0.218887],[accuracy:0.971248]
# [Epocn:22],[batch_count:5.0],[loss:0.212709],[accuracy:0.977727]
# [Epocn:22],[batch_count:6.0],[loss:0.202774],[accuracy:0.980403]
# [Epocn:22],[batch_count:7.0],[loss:0.201970],[accuracy:0.978961]
# [Epocn:22],[batch_count:8.0],[loss:0.205215],[accuracy:0.972278]
# [Epocn:22],[batch_count:9.0],[loss:0.209049],[accuracy:0.975235]
# [Epocn:22],[batch_count:10.0],[loss:0.202357],[accuracy:0.978207]
# [Epoch 22/201], [loss:0.209853], accuracy:0.975416]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:23],[batch_count:1.0],[loss:0.200279],[accuracy:0.983052]
# [Epocn:23],[batch_count:2.0],[loss:0.214473],[accuracy:0.971747]
# [Epocn:23],[batch_count:3.0],[loss:0.198324],[accuracy:0.977533]
# [Epocn:23],[batch_count:4.0],[loss:0.196891],[accuracy:0.976540]
# [Epocn:23],[batch_count:5.0],[loss:0.206045],[accuracy:0.974337]
# [Epocn:23],[batch_count:6.0],[loss:0.182952],[accuracy:0.986075]
# [Epocn:23],[batch_count:7.0],[loss:0.200087],[accuracy:0.973333]
# [Epocn:23],[batch_count:8.0],[loss:0.201245],[accuracy:0.972900]
# [Epocn:23],[batch_count:9.0],[loss:0.214930],[accuracy:0.966578]
# [Epocn:23],[batch_count:10.0],[loss:0.200688],[accuracy:0.979740]
# [Epoch 23/201], [loss:0.201591], accuracy:0.976183]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:24],[batch_count:1.0],[loss:0.192903],[accuracy:0.980024]
# [Epocn:24],[batch_count:2.0],[loss:0.193535],[accuracy:0.980119]
# [Epocn:24],[batch_count:3.0],[loss:0.249540],[accuracy:0.968541]
# [Epocn:24],[batch_count:4.0],[loss:0.187809],[accuracy:0.975467]
# [Epocn:24],[batch_count:5.0],[loss:0.213136],[accuracy:0.964168]
# [Epocn:24],[batch_count:6.0],[loss:0.192132],[accuracy:0.981466]
# [Epocn:24],[batch_count:7.0],[loss:0.211404],[accuracy:0.970151]
# [Epocn:24],[batch_count:8.0],[loss:0.193284],[accuracy:0.973003]
# [Epocn:24],[batch_count:9.0],[loss:0.197217],[accuracy:0.979198]
# [Epocn:24],[batch_count:10.0],[loss:0.192131],[accuracy:0.976014]
# [Epoch 24/201], [loss:0.202309], accuracy:0.974815]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:25],[batch_count:1.0],[loss:0.255894],[accuracy:0.963865]
# [Epocn:25],[batch_count:2.0],[loss:0.188241],[accuracy:0.976283]
# [Epocn:25],[batch_count:3.0],[loss:0.206105],[accuracy:0.971427]
# [Epocn:25],[batch_count:4.0],[loss:0.203208],[accuracy:0.977923]
# [Epocn:25],[batch_count:5.0],[loss:0.193863],[accuracy:0.974150]
# [Epocn:25],[batch_count:6.0],[loss:0.187933],[accuracy:0.974880]
# [Epocn:25],[batch_count:7.0],[loss:0.185547],[accuracy:0.978768]
# [Epocn:25],[batch_count:8.0],[loss:0.186584],[accuracy:0.978981]
# [Epocn:25],[batch_count:9.0],[loss:0.176006],[accuracy:0.982951]
# [Epocn:25],[batch_count:10.0],[loss:0.173249],[accuracy:0.979531]
# [Epoch 25/201], [loss:0.195663], accuracy:0.975876]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:26],[batch_count:1.0],[loss:0.181504],[accuracy:0.979328]
# [Epocn:26],[batch_count:2.0],[loss:0.194219],[accuracy:0.973607]
# [Epocn:26],[batch_count:3.0],[loss:0.182350],[accuracy:0.978639]
# [Epocn:26],[batch_count:4.0],[loss:0.203205],[accuracy:0.966366]
# [Epocn:26],[batch_count:5.0],[loss:0.179198],[accuracy:0.979971]
# [Epocn:26],[batch_count:6.0],[loss:0.177857],[accuracy:0.981487]
# [Epocn:26],[batch_count:7.0],[loss:0.191643],[accuracy:0.977917]
# [Epocn:26],[batch_count:8.0],[loss:0.181003],[accuracy:0.980313]
# [Epocn:26],[batch_count:9.0],[loss:0.171259],[accuracy:0.980144]
# [Epocn:26],[batch_count:10.0],[loss:0.216114],[accuracy:0.954594]
# [Epoch 26/201], [loss:0.187835], accuracy:0.975237]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:27],[batch_count:1.0],[loss:0.174778],[accuracy:0.982033]
# [Epocn:27],[batch_count:2.0],[loss:0.194149],[accuracy:0.972416]
# [Epocn:27],[batch_count:3.0],[loss:0.188439],[accuracy:0.973457]
# [Epocn:27],[batch_count:4.0],[loss:0.172439],[accuracy:0.982420]
# [Epocn:27],[batch_count:5.0],[loss:0.172599],[accuracy:0.982171]
# [Epocn:27],[batch_count:6.0],[loss:0.161368],[accuracy:0.982535]
# [Epocn:27],[batch_count:7.0],[loss:0.179619],[accuracy:0.974907]
# [Epocn:27],[batch_count:8.0],[loss:0.163336],[accuracy:0.982643]
# [Epocn:27],[batch_count:9.0],[loss:0.184550],[accuracy:0.970692]
# [Epocn:27],[batch_count:10.0],[loss:0.172715],[accuracy:0.980039]
# [Epoch 27/201], [loss:0.176399], accuracy:0.978331]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:28],[batch_count:1.0],[loss:0.169183],[accuracy:0.976747]
# [Epocn:28],[batch_count:2.0],[loss:0.199166],[accuracy:0.961589]
# [Epocn:28],[batch_count:3.0],[loss:0.168295],[accuracy:0.981689]
# [Epocn:28],[batch_count:4.0],[loss:0.177759],[accuracy:0.974182]
# [Epocn:28],[batch_count:5.0],[loss:0.169935],[accuracy:0.982355]
# [Epocn:28],[batch_count:6.0],[loss:0.184858],[accuracy:0.975340]
# [Epocn:28],[batch_count:7.0],[loss:0.163366],[accuracy:0.976198]
# [Epocn:28],[batch_count:8.0],[loss:0.172440],[accuracy:0.978969]
# [Epocn:28],[batch_count:9.0],[loss:0.169731],[accuracy:0.983240]
# [Epocn:28],[batch_count:10.0],[loss:0.172333],[accuracy:0.980581]
# [Epoch 28/201], [loss:0.174707], accuracy:0.977089]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:29],[batch_count:1.0],[loss:0.163401],[accuracy:0.980105]
# [Epocn:29],[batch_count:2.0],[loss:0.174850],[accuracy:0.971169]
# [Epocn:29],[batch_count:3.0],[loss:0.184028],[accuracy:0.970304]
# [Epocn:29],[batch_count:4.0],[loss:0.174920],[accuracy:0.978257]
# [Epocn:29],[batch_count:5.0],[loss:0.176637],[accuracy:0.976787]
# [Epocn:29],[batch_count:6.0],[loss:0.165808],[accuracy:0.977103]
# [Epocn:29],[batch_count:7.0],[loss:0.168982],[accuracy:0.974785]
# [Epocn:29],[batch_count:8.0],[loss:0.163661],[accuracy:0.981049]
# [Epocn:29],[batch_count:9.0],[loss:0.167382],[accuracy:0.979736]
# [Epocn:29],[batch_count:10.0],[loss:0.160283],[accuracy:0.984745]
# [Epoch 29/201], [loss:0.169995], accuracy:0.977404]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:30],[batch_count:1.0],[loss:0.163966],[accuracy:0.978280]
# [Epocn:30],[batch_count:2.0],[loss:0.187139],[accuracy:0.963146]
# [Epocn:30],[batch_count:3.0],[loss:0.164991],[accuracy:0.980335]
# [Epocn:30],[batch_count:4.0],[loss:0.154997],[accuracy:0.983721]
# [Epocn:30],[batch_count:5.0],[loss:0.166668],[accuracy:0.978479]
# [Epocn:30],[batch_count:6.0],[loss:0.168271],[accuracy:0.976771]
# [Epocn:30],[batch_count:7.0],[loss:0.158300],[accuracy:0.982568]
# [Epocn:30],[batch_count:8.0],[loss:0.174597],[accuracy:0.974945]
# [Epocn:30],[batch_count:9.0],[loss:0.158380],[accuracy:0.984424]
# [Epocn:30],[batch_count:10.0],[loss:0.167619],[accuracy:0.973840]
# [Epoch 30/201], [loss:0.166493], accuracy:0.977651]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 30
# ------------------------------------------------------------------------------------------
# count:153600,TP:3668,TN:148401,FP:330,FN1201
# processing image NO 0, time comsuption 0.008848s
# count:153600,TP:3234,TN:148006,FP:499,FN1861
# processing image NO 1, time comsuption 0.007858s
# count:153600,TP:5716,TN:144314,FP:386,FN3184
# processing image NO 2, time comsuption 0.007908s
# count:153600,TP:2861,TN:146835,FP:1099,FN2805
# processing image NO 3, time comsuption 0.011719s
# count:153600,TP:3275,TN:149144,FP:365,FN816
# processing image NO 4, time comsuption 0.007863s
# count:153600,TP:3418,TN:149065,FP:302,FN815
# processing image NO 5, time comsuption 0.007991s
# count:153600,TP:4045,TN:147667,FP:390,FN1498
# processing image NO 6, time comsuption 0.008166s
# count:153600,TP:3717,TN:148417,FP:147,FN1319
# processing image NO 7, time comsuption 0.007931s
# count:153600,TP:3548,TN:148623,FP:539,FN890
# processing image NO 8, time comsuption 0.007683s
# count:153600,TP:3136,TN:148826,FP:855,FN783
# processing image NO 9, time comsuption 0.008193s
# count:153600,TP:3973,TN:145802,FP:659,FN3166
# processing image NO 10, time comsuption 0.007742s
# count:153600,TP:3070,TN:148961,FP:586,FN983
# processing image NO 11, time comsuption 0.008230s
# count:153600,TP:2933,TN:148111,FP:1530,FN1026
# processing image NO 12, time comsuption 0.007457s
# count:153600,TP:2672,TN:147360,FP:2377,FN1191
# processing image NO 13, time comsuption 0.007865s
# count:153600,TP:3339,TN:147615,FP:766,FN1880
# processing image NO 14, time comsuption 0.008089s
# count:153600,TP:3186,TN:148048,FP:811,FN1555
# processing image NO 15, time comsuption 0.007794s
# count:153600,TP:3297,TN:147716,FP:467,FN2120
# processing image NO 16, time comsuption 0.007719s
# count:153600,TP:3031,TN:148994,FP:620,FN955
# processing image NO 17, time comsuption 0.007685s
# count:153600,TP:3007,TN:148044,FP:940,FN1609
# processing image NO 18, time comsuption 0.007746s
# count:153600,TP:3493,TN:147988,FP:825,FN1294
# processing image NO 19, time comsuption 0.007620s
# count:153600,TP:3082,TN:148845,FP:288,FN1385
# processing image NO 20, time comsuption 0.007574s
# count:153600,TP:4558,TN:146568,FP:556,FN1918
# processing image NO 21, time comsuption 0.007831s
# count:153600,TP:2990,TN:147943,FP:1500,FN1167
# processing image NO 22, time comsuption 0.007656s
# count:153600,TP:3688,TN:147582,FP:370,FN1960
# processing image NO 23, time comsuption 0.007572s
# count:153600,TP:2643,TN:148904,FP:963,FN1090
# processing image NO 24, time comsuption 0.007828s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 30/201], [loss:0.149343], accuracy:0.985249]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:31],[batch_count:1.0],[loss:0.163617],[accuracy:0.972708]
# [Epocn:31],[batch_count:2.0],[loss:0.154273],[accuracy:0.982238]
# [Epocn:31],[batch_count:3.0],[loss:0.150624],[accuracy:0.983959]
# [Epocn:31],[batch_count:4.0],[loss:0.165658],[accuracy:0.974256]
# [Epocn:31],[batch_count:5.0],[loss:0.171023],[accuracy:0.974460]
# [Epocn:31],[batch_count:6.0],[loss:0.153560],[accuracy:0.981246]
# [Epocn:31],[batch_count:7.0],[loss:0.168646],[accuracy:0.975395]
# [Epocn:31],[batch_count:8.0],[loss:0.160583],[accuracy:0.979306]
# [Epocn:31],[batch_count:9.0],[loss:0.150984],[accuracy:0.983564]
# [Epocn:31],[batch_count:10.0],[loss:0.150681],[accuracy:0.977911]
# [Epoch 31/201], [loss:0.158965], accuracy:0.978504]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:32],[batch_count:1.0],[loss:0.155555],[accuracy:0.981648]
# [Epocn:32],[batch_count:2.0],[loss:0.152603],[accuracy:0.983340]
# [Epocn:32],[batch_count:3.0],[loss:0.145389],[accuracy:0.983480]
# [Epocn:32],[batch_count:4.0],[loss:0.161745],[accuracy:0.978852]
# [Epocn:32],[batch_count:5.0],[loss:0.155024],[accuracy:0.982423]
# [Epocn:32],[batch_count:6.0],[loss:0.150302],[accuracy:0.980115]
# [Epocn:32],[batch_count:7.0],[loss:0.145582],[accuracy:0.981988]
# [Epocn:32],[batch_count:8.0],[loss:0.164485],[accuracy:0.966030]
# [Epocn:32],[batch_count:9.0],[loss:0.170013],[accuracy:0.967534]
# [Epocn:32],[batch_count:10.0],[loss:0.162989],[accuracy:0.974698]
# [Epoch 32/201], [loss:0.156369], accuracy:0.978011]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:33],[batch_count:1.0],[loss:0.155958],[accuracy:0.972972]
# [Epocn:33],[batch_count:2.0],[loss:0.156700],[accuracy:0.982288]
# [Epocn:33],[batch_count:3.0],[loss:0.171635],[accuracy:0.975901]
# [Epocn:33],[batch_count:4.0],[loss:0.155747],[accuracy:0.979647]
# [Epocn:33],[batch_count:5.0],[loss:0.151616],[accuracy:0.983354]
# [Epocn:33],[batch_count:6.0],[loss:0.153822],[accuracy:0.980190]
# [Epocn:33],[batch_count:7.0],[loss:0.151336],[accuracy:0.980321]
# [Epocn:33],[batch_count:8.0],[loss:0.153647],[accuracy:0.978666]
# [Epocn:33],[batch_count:9.0],[loss:0.160458],[accuracy:0.974415]
# [Epocn:33],[batch_count:10.0],[loss:0.141742],[accuracy:0.977023]
# [Epoch 33/201], [loss:0.155266], accuracy:0.978478]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:34],[batch_count:1.0],[loss:0.167227],[accuracy:0.975802]
# [Epocn:34],[batch_count:2.0],[loss:0.139711],[accuracy:0.985211]
# [Epocn:34],[batch_count:3.0],[loss:0.158281],[accuracy:0.971531]
# [Epocn:34],[batch_count:4.0],[loss:0.147556],[accuracy:0.975451]
# [Epocn:34],[batch_count:5.0],[loss:0.143908],[accuracy:0.983278]
# [Epocn:34],[batch_count:6.0],[loss:0.137449],[accuracy:0.985085]
# [Epocn:34],[batch_count:7.0],[loss:0.154911],[accuracy:0.976220]
# [Epocn:34],[batch_count:8.0],[loss:0.154325],[accuracy:0.977791]
# [Epocn:34],[batch_count:9.0],[loss:0.171392],[accuracy:0.974151]
# [Epocn:34],[batch_count:10.0],[loss:0.166905],[accuracy:0.970970]
# [Epoch 34/201], [loss:0.154166], accuracy:0.977549]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:35],[batch_count:1.0],[loss:0.154739],[accuracy:0.970837]
# [Epocn:35],[batch_count:2.0],[loss:0.139938],[accuracy:0.983843]
# [Epocn:35],[batch_count:3.0],[loss:0.138894],[accuracy:0.981895]
# [Epocn:35],[batch_count:4.0],[loss:0.160477],[accuracy:0.974495]
# [Epocn:35],[batch_count:5.0],[loss:0.167160],[accuracy:0.970774]
# [Epocn:35],[batch_count:6.0],[loss:0.153621],[accuracy:0.977559]
# [Epocn:35],[batch_count:7.0],[loss:0.147484],[accuracy:0.981087]
# [Epocn:35],[batch_count:8.0],[loss:0.141623],[accuracy:0.981144]
# [Epocn:35],[batch_count:9.0],[loss:0.149814],[accuracy:0.972493]
# [Epocn:35],[batch_count:10.0],[loss:0.149981],[accuracy:0.980012]
# [Epoch 35/201], [loss:0.150373], accuracy:0.977414]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:36],[batch_count:1.0],[loss:0.144352],[accuracy:0.983506]
# [Epocn:36],[batch_count:2.0],[loss:0.150523],[accuracy:0.976324]
# [Epocn:36],[batch_count:3.0],[loss:0.154984],[accuracy:0.971845]
# [Epocn:36],[batch_count:4.0],[loss:0.133815],[accuracy:0.982781]
# [Epocn:36],[batch_count:5.0],[loss:0.141383],[accuracy:0.975685]
# [Epocn:36],[batch_count:6.0],[loss:0.133389],[accuracy:0.986183]
# [Epocn:36],[batch_count:7.0],[loss:0.133683],[accuracy:0.985464]
# [Epocn:36],[batch_count:8.0],[loss:0.150711],[accuracy:0.973436]
# [Epocn:36],[batch_count:9.0],[loss:0.127456],[accuracy:0.987965]
# [Epocn:36],[batch_count:10.0],[loss:0.143558],[accuracy:0.975638]
# [Epoch 36/201], [loss:0.141385], accuracy:0.979883]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:37],[batch_count:1.0],[loss:0.139174],[accuracy:0.981671]
# [Epocn:37],[batch_count:2.0],[loss:0.131836],[accuracy:0.981096]
# [Epocn:37],[batch_count:3.0],[loss:0.166931],[accuracy:0.974807]
# [Epocn:37],[batch_count:4.0],[loss:0.146446],[accuracy:0.972145]
# [Epocn:37],[batch_count:5.0],[loss:0.135011],[accuracy:0.984510]
# [Epocn:37],[batch_count:6.0],[loss:0.144520],[accuracy:0.975817]
# [Epocn:37],[batch_count:7.0],[loss:0.152769],[accuracy:0.973449]
# [Epocn:37],[batch_count:8.0],[loss:0.135027],[accuracy:0.982762]
# [Epocn:37],[batch_count:9.0],[loss:0.134486],[accuracy:0.981810]
# [Epocn:37],[batch_count:10.0],[loss:0.142077],[accuracy:0.978396]
# [Epoch 37/201], [loss:0.142828], accuracy:0.978646]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:38],[batch_count:1.0],[loss:0.140313],[accuracy:0.979969]
# [Epocn:38],[batch_count:2.0],[loss:0.132443],[accuracy:0.981743]
# [Epocn:38],[batch_count:3.0],[loss:0.136898],[accuracy:0.975955]
# [Epocn:38],[batch_count:4.0],[loss:0.145233],[accuracy:0.979466]
# [Epocn:38],[batch_count:5.0],[loss:0.143221],[accuracy:0.975073]
# [Epocn:38],[batch_count:6.0],[loss:0.135124],[accuracy:0.977236]
# [Epocn:38],[batch_count:7.0],[loss:0.131584],[accuracy:0.983696]
# [Epocn:38],[batch_count:8.0],[loss:0.130573],[accuracy:0.984017]
# [Epocn:38],[batch_count:9.0],[loss:0.143023],[accuracy:0.977668]
# [Epocn:38],[batch_count:10.0],[loss:0.132342],[accuracy:0.978750]
# [Epoch 38/201], [loss:0.137076], accuracy:0.979357]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:39],[batch_count:1.0],[loss:0.131987],[accuracy:0.980946]
# [Epocn:39],[batch_count:2.0],[loss:0.146162],[accuracy:0.977912]
# [Epocn:39],[batch_count:3.0],[loss:0.130058],[accuracy:0.982893]
# [Epocn:39],[batch_count:4.0],[loss:0.127399],[accuracy:0.982367]
# [Epocn:39],[batch_count:5.0],[loss:0.133109],[accuracy:0.981594]
# [Epocn:39],[batch_count:6.0],[loss:0.137173],[accuracy:0.974980]
# [Epocn:39],[batch_count:7.0],[loss:0.132892],[accuracy:0.980538]
# [Epocn:39],[batch_count:8.0],[loss:0.122657],[accuracy:0.986702]
# [Epocn:39],[batch_count:9.0],[loss:0.129322],[accuracy:0.980396]
# [Epocn:39],[batch_count:10.0],[loss:0.158444],[accuracy:0.963370]
# [Epoch 39/201], [loss:0.134920], accuracy:0.979170]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:40],[batch_count:1.0],[loss:0.120548],[accuracy:0.985327]
# [Epocn:40],[batch_count:2.0],[loss:0.144517],[accuracy:0.972704]
# [Epocn:40],[batch_count:3.0],[loss:0.129912],[accuracy:0.981058]
# [Epocn:40],[batch_count:4.0],[loss:0.122010],[accuracy:0.985059]
# [Epocn:40],[batch_count:5.0],[loss:0.120516],[accuracy:0.985774]
# [Epocn:40],[batch_count:6.0],[loss:0.134223],[accuracy:0.982495]
# [Epocn:40],[batch_count:7.0],[loss:0.131697],[accuracy:0.975832]
# [Epocn:40],[batch_count:8.0],[loss:0.131459],[accuracy:0.976523]
# [Epocn:40],[batch_count:9.0],[loss:0.119548],[accuracy:0.984923]
# [Epocn:40],[batch_count:10.0],[loss:0.134752],[accuracy:0.977121]
# [Epoch 40/201], [loss:0.128918], accuracy:0.980682]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 40
# ------------------------------------------------------------------------------------------
# count:153600,TP:4021,TN:148284,FP:447,FN848
# processing image NO 0, time comsuption 0.007884s
# count:153600,TP:3733,TN:147627,FP:878,FN1362
# processing image NO 1, time comsuption 0.008197s
# count:153600,TP:6700,TN:144285,FP:415,FN2200
# processing image NO 2, time comsuption 0.008054s
# count:153600,TP:3501,TN:147020,FP:914,FN2165
# processing image NO 3, time comsuption 0.008006s
# count:153600,TP:3398,TN:149068,FP:441,FN693
# processing image NO 4, time comsuption 0.007863s
# count:153600,TP:3386,TN:148819,FP:548,FN847
# processing image NO 5, time comsuption 0.007935s
# count:153600,TP:4248,TN:147495,FP:562,FN1295
# processing image NO 6, time comsuption 0.007959s
# count:153600,TP:3994,TN:148267,FP:297,FN1042
# ...
# [Epocn:54],[batch_count:8.0],[loss:0.110302],[accuracy:0.983213]
# [Epocn:54],[batch_count:9.0],[loss:0.112572],[accuracy:0.973817]
# [Epocn:54],[batch_count:10.0],[loss:0.105671],[accuracy:0.980913]
# [Epoch 54/201], [loss:0.107672], accuracy:0.979896]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:55],[batch_count:1.0],[loss:0.100828],[accuracy:0.979060]
# [Epocn:55],[batch_count:2.0],[loss:0.098700],[accuracy:0.987393]
# [Epocn:55],[batch_count:3.0],[loss:0.112013],[accuracy:0.975574]
# [Epocn:55],[batch_count:4.0],[loss:0.098732],[accuracy:0.983372]
# [Epocn:55],[batch_count:5.0],[loss:0.114048],[accuracy:0.976472]
# [Epocn:55],[batch_count:6.0],[loss:0.110331],[accuracy:0.978698]
# [Epocn:55],[batch_count:7.0],[loss:0.116520],[accuracy:0.976941]
# [Epocn:55],[batch_count:8.0],[loss:0.099138],[accuracy:0.983874]
# [Epocn:55],[batch_count:9.0],[loss:0.094084],[accuracy:0.985102]
# [Epocn:55],[batch_count:10.0],[loss:0.096891],[accuracy:0.982169]
# [Epoch 55/201], [loss:0.104129], accuracy:0.980866]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:56],[batch_count:1.0],[loss:0.104533],[accuracy:0.976970]
# [Epocn:56],[batch_count:2.0],[loss:0.116537],[accuracy:0.972958]
# [Epocn:56],[batch_count:3.0],[loss:0.099558],[accuracy:0.982090]
# [Epocn:56],[batch_count:4.0],[loss:0.092001],[accuracy:0.986225]
# [Epocn:56],[batch_count:5.0],[loss:0.097844],[accuracy:0.982074]
# [Epocn:56],[batch_count:6.0],[loss:0.100454],[accuracy:0.983050]
# [Epocn:56],[batch_count:7.0],[loss:0.097987],[accuracy:0.983413]
# [Epocn:56],[batch_count:8.0],[loss:0.102131],[accuracy:0.979508]
# [Epocn:56],[batch_count:9.0],[loss:0.088771],[accuracy:0.986775]
# [Epocn:56],[batch_count:10.0],[loss:0.093250],[accuracy:0.984857]
# [Epoch 56/201], [loss:0.099306], accuracy:0.981792]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:57],[batch_count:1.0],[loss:0.109322],[accuracy:0.976801]
# [Epocn:57],[batch_count:2.0],[loss:0.105649],[accuracy:0.975768]
# [Epocn:57],[batch_count:3.0],[loss:0.093525],[accuracy:0.984635]
# [Epocn:57],[batch_count:4.0],[loss:0.088789],[accuracy:0.985554]
# [Epocn:57],[batch_count:5.0],[loss:0.102245],[accuracy:0.979116]
# [Epocn:57],[batch_count:6.0],[loss:0.099920],[accuracy:0.980308]
# [Epocn:57],[batch_count:7.0],[loss:0.092058],[accuracy:0.985000]
# [Epocn:57],[batch_count:8.0],[loss:0.097515],[accuracy:0.982932]
# [Epocn:57],[batch_count:9.0],[loss:0.101473],[accuracy:0.982419]
# [Epocn:57],[batch_count:10.0],[loss:0.096275],[accuracy:0.982810]
# [Epoch 57/201], [loss:0.098677], accuracy:0.981534]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:58],[batch_count:1.0],[loss:0.099545],[accuracy:0.981139]
# [Epocn:58],[batch_count:2.0],[loss:0.103429],[accuracy:0.977512]
# [Epocn:58],[batch_count:3.0],[loss:0.101464],[accuracy:0.985477]
# [Epocn:58],[batch_count:4.0],[loss:0.094502],[accuracy:0.985718]
# [Epocn:58],[batch_count:5.0],[loss:0.094142],[accuracy:0.985133]
# [Epocn:58],[batch_count:6.0],[loss:0.104487],[accuracy:0.977303]
# [Epocn:58],[batch_count:7.0],[loss:0.091476],[accuracy:0.984481]
# [Epocn:58],[batch_count:8.0],[loss:0.093005],[accuracy:0.981782]
# [Epocn:58],[batch_count:9.0],[loss:0.106436],[accuracy:0.976007]
# [Epocn:58],[batch_count:10.0],[loss:0.087655],[accuracy:0.984970]
# [Epoch 58/201], [loss:0.097614], accuracy:0.981952]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:59],[batch_count:1.0],[loss:0.091003],[accuracy:0.985700]
# [Epocn:59],[batch_count:2.0],[loss:0.093444],[accuracy:0.984059]
# [Epocn:59],[batch_count:3.0],[loss:0.093244],[accuracy:0.985410]
# [Epocn:59],[batch_count:4.0],[loss:0.100928],[accuracy:0.977458]
# [Epocn:59],[batch_count:5.0],[loss:0.110626],[accuracy:0.975406]
# [Epocn:59],[batch_count:6.0],[loss:0.096458],[accuracy:0.982613]
# [Epocn:59],[batch_count:7.0],[loss:0.092180],[accuracy:0.983597]
# [Epocn:59],[batch_count:8.0],[loss:0.087983],[accuracy:0.985263]
# [Epocn:59],[batch_count:9.0],[loss:0.091191],[accuracy:0.981693]
# [Epocn:59],[batch_count:10.0],[loss:0.094883],[accuracy:0.982445]
# [Epoch 59/201], [loss:0.095194], accuracy:0.982364]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:60],[batch_count:1.0],[loss:0.090223],[accuracy:0.983011]
# [Epocn:60],[batch_count:2.0],[loss:0.093138],[accuracy:0.981678]
# [Epocn:60],[batch_count:3.0],[loss:0.089329],[accuracy:0.985091]
# [Epocn:60],[batch_count:4.0],[loss:0.087349],[accuracy:0.983362]
# [Epocn:60],[batch_count:5.0],[loss:0.094788],[accuracy:0.982123]
# [Epocn:60],[batch_count:6.0],[loss:0.088382],[accuracy:0.984899]
# [Epocn:60],[batch_count:7.0],[loss:0.102460],[accuracy:0.981216]
# [Epocn:60],[batch_count:8.0],[loss:0.105131],[accuracy:0.974877]
# [Epocn:60],[batch_count:9.0],[loss:0.097731],[accuracy:0.978690]
# [Epocn:60],[batch_count:10.0],[loss:0.087445],[accuracy:0.987013]
# [Epoch 60/201], [loss:0.093598], accuracy:0.982196]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 60
# ------------------------------------------------------------------------------------------
# count:153600,TP:3541,TN:148406,FP:325,FN1328
# processing image NO 0, time comsuption 0.007407s
# count:153600,TP:3506,TN:148238,FP:267,FN1589
# processing image NO 1, time comsuption 0.007579s
# count:153600,TP:5928,TN:144430,FP:270,FN2972
# processing image NO 2, time comsuption 0.007512s
# count:153600,TP:3665,TN:147236,FP:698,FN2001
# processing image NO 3, time comsuption 0.007949s
# count:153600,TP:2866,TN:149150,FP:359,FN1225
# processing image NO 4, time comsuption 0.007557s
# count:153600,TP:3000,TN:149004,FP:363,FN1233
# processing image NO 5, time comsuption 0.007482s
# count:153600,TP:3999,TN:147746,FP:311,FN1544
# processing image NO 6, time comsuption 0.007514s
# count:153600,TP:3499,TN:148405,FP:159,FN1537
# processing image NO 7, time comsuption 0.007385s
# count:153600,TP:3337,TN:148636,FP:526,FN1101
# processing image NO 8, time comsuption 0.007441s
# count:153600,TP:2764,TN:148606,FP:1075,FN1155
# processing image NO 9, time comsuption 0.007374s
# count:153600,TP:4488,TN:145825,FP:636,FN2651
# processing image NO 10, time comsuption 0.007912s
# count:153600,TP:2905,TN:148846,FP:701,FN1148
# processing image NO 11, time comsuption 0.007439s
# count:153600,TP:2714,TN:148574,FP:1067,FN1245
# processing image NO 12, time comsuption 0.007416s
# count:153600,TP:2661,TN:148415,FP:1322,FN1202
# processing image NO 13, time comsuption 0.007454s
# count:153600,TP:3630,TN:147782,FP:599,FN1589
# processing image NO 14, time comsuption 0.007354s
# count:153600,TP:3220,TN:147749,FP:1110,FN1521
# processing image NO 15, time comsuption 0.007639s
# count:153600,TP:3209,TN:147831,FP:352,FN2208
# processing image NO 16, time comsuption 0.008168s
# count:153600,TP:2837,TN:149011,FP:603,FN1149
# processing image NO 17, time comsuption 0.007425s
# count:153600,TP:3101,TN:148438,FP:546,FN1515
# processing image NO 18, time comsuption 0.010797s
# count:153600,TP:3357,TN:148276,FP:537,FN1430
# processing image NO 19, time comsuption 0.007446s
# count:153600,TP:3082,TN:148845,FP:288,FN1385
# processing image NO 20, time comsuption 0.007400s
# count:153600,TP:4997,TN:146579,FP:545,FN1479
# processing image NO 21, time comsuption 0.007390s
# count:153600,TP:2853,TN:148402,FP:1041,FN1304
# processing image NO 22, time comsuption 0.007480s
# count:153600,TP:3978,TN:147609,FP:343,FN1670
# processing image NO 23, time comsuption 0.007436s
# count:153600,TP:2424,TN:149218,FP:649,FN1309
# processing image NO 24, time comsuption 0.007477s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 60/201], [loss:0.084207], accuracy:0.986149]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:61],[batch_count:1.0],[loss:0.089171],[accuracy:0.985226]
# [Epocn:61],[batch_count:2.0],[loss:0.094967],[accuracy:0.978516]
# [Epocn:61],[batch_count:3.0],[loss:0.085808],[accuracy:0.984792]
# [Epocn:61],[batch_count:4.0],[loss:0.092576],[accuracy:0.983760]
# [Epocn:61],[batch_count:5.0],[loss:0.101003],[accuracy:0.978133]
# [Epocn:61],[batch_count:6.0],[loss:0.091124],[accuracy:0.982850]
# [Epocn:61],[batch_count:7.0],[loss:0.095335],[accuracy:0.982421]
# [Epocn:61],[batch_count:8.0],[loss:0.096364],[accuracy:0.979213]
# [Epocn:61],[batch_count:9.0],[loss:0.087203],[accuracy:0.984543]
# [Epocn:61],[batch_count:10.0],[loss:0.093735],[accuracy:0.982301]
# [Epoch 61/201], [loss:0.092729], accuracy:0.982175]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:62],[batch_count:1.0],[loss:0.094639],[accuracy:0.979633]
# [Epocn:62],[batch_count:2.0],[loss:0.088879],[accuracy:0.983429]
# [Epocn:62],[batch_count:3.0],[loss:0.094989],[accuracy:0.983102]
# [Epocn:62],[batch_count:4.0],[loss:0.088118],[accuracy:0.983011]
# [Epocn:62],[batch_count:5.0],[loss:0.091725],[accuracy:0.980075]
# [Epocn:62],[batch_count:6.0],[loss:0.091355],[accuracy:0.984112]
# [Epocn:62],[batch_count:7.0],[loss:0.088770],[accuracy:0.982692]
# [Epocn:62],[batch_count:8.0],[loss:0.089470],[accuracy:0.982051]
# [Epocn:62],[batch_count:9.0],[loss:0.088913],[accuracy:0.984422]
# [Epocn:62],[batch_count:10.0],[loss:0.091656],[accuracy:0.980818]
# [Epoch 62/201], [loss:0.090851], accuracy:0.982334]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:63],[batch_count:1.0],[loss:0.089248],[accuracy:0.984686]
# [Epocn:63],[batch_count:2.0],[loss:0.094245],[accuracy:0.978752]
# [Epocn:63],[batch_count:3.0],[loss:0.089600],[accuracy:0.984110]
# [Epocn:63],[batch_count:4.0],[loss:0.101387],[accuracy:0.975703]
# [Epocn:63],[batch_count:5.0],[loss:0.088394],[accuracy:0.984444]
# [Epocn:63],[batch_count:6.0],[loss:0.100893],[accuracy:0.975192]
# [Epocn:63],[batch_count:7.0],[loss:0.086586],[accuracy:0.985971]
# [Epocn:63],[batch_count:8.0],[loss:0.094711],[accuracy:0.983792]
# [Epocn:63],[batch_count:9.0],[loss:0.089303],[accuracy:0.982780]
# [Epocn:63],[batch_count:10.0],[loss:0.090447],[accuracy:0.980612]
# [Epoch 63/201], [loss:0.092481], accuracy:0.981604]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:64],[batch_count:1.0],[loss:0.087395],[accuracy:0.981257]
# [Epocn:64],[batch_count:2.0],[loss:0.083827],[accuracy:0.984443]
# [Epocn:64],[batch_count:3.0],[loss:0.099440],[accuracy:0.976651]
# [Epocn:64],[batch_count:4.0],[loss:0.091576],[accuracy:0.982527]
# [Epocn:64],[batch_count:5.0],[loss:0.088720],[accuracy:0.984415]
# [Epocn:64],[batch_count:6.0],[loss:0.089211],[accuracy:0.980938]
# [Epocn:64],[batch_count:7.0],[loss:0.099628],[accuracy:0.980245]
# [Epocn:64],[batch_count:8.0],[loss:0.086269],[accuracy:0.982762]
# [Epocn:64],[batch_count:9.0],[loss:0.081503],[accuracy:0.986474]
# [Epocn:64],[batch_count:10.0],[loss:0.086444],[accuracy:0.984169]
# [Epoch 64/201], [loss:0.089401], accuracy:0.982388]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:65],[batch_count:1.0],[loss:0.098077],[accuracy:0.975614]
# [Epocn:65],[batch_count:2.0],[loss:0.103969],[accuracy:0.972994]
# [Epocn:65],[batch_count:3.0],[loss:0.082083],[accuracy:0.985385]
# [Epocn:65],[batch_count:4.0],[loss:0.085108],[accuracy:0.985476]
# [Epocn:65],[batch_count:5.0],[loss:0.092012],[accuracy:0.982809]
# [Epocn:65],[batch_count:6.0],[loss:0.096013],[accuracy:0.977422]
# [Epocn:65],[batch_count:7.0],[loss:0.092371],[accuracy:0.981361]
# [Epocn:65],[batch_count:8.0],[loss:0.083061],[accuracy:0.983862]
# [Epocn:65],[batch_count:9.0],[loss:0.087113],[accuracy:0.983673]
# [Epocn:65],[batch_count:10.0],[loss:0.081429],[accuracy:0.985799]
# [Epoch 65/201], [loss:0.090124], accuracy:0.981440]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:66],[batch_count:1.0],[loss:0.083437],[accuracy:0.984385]
# [Epocn:66],[batch_count:2.0],[loss:0.094586],[accuracy:0.978728]
# [Epocn:66],[batch_count:3.0],[loss:0.091478],[accuracy:0.979974]
# [Epocn:66],[batch_count:4.0],[loss:0.084897],[accuracy:0.983619]
# [Epocn:66],[batch_count:5.0],[loss:0.085911],[accuracy:0.981468]
# [Epocn:66],[batch_count:6.0],[loss:0.087270],[accuracy:0.983187]
# [Epocn:66],[batch_count:7.0],[loss:0.080404],[accuracy:0.985538]
# [Epocn:66],[batch_count:8.0],[loss:0.109752],[accuracy:0.979348]
# [Epocn:66],[batch_count:9.0],[loss:0.089102],[accuracy:0.979028]
# [Epocn:66],[batch_count:10.0],[loss:0.085921],[accuracy:0.984704]
# [Epoch 66/201], [loss:0.089276], accuracy:0.981998]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:67],[batch_count:1.0],[loss:0.095179],[accuracy:0.977913]
# [Epocn:67],[batch_count:2.0],[loss:0.085906],[accuracy:0.983802]
# [Epocn:67],[batch_count:3.0],[loss:0.097579],[accuracy:0.974424]
# [Epocn:67],[batch_count:4.0],[loss:0.080444],[accuracy:0.984686]
# [Epocn:67],[batch_count:5.0],[loss:0.093680],[accuracy:0.979883]
# [Epocn:67],[batch_count:6.0],[loss:0.082898],[accuracy:0.984242]
# [Epocn:67],[batch_count:7.0],[loss:0.079445],[accuracy:0.985919]
# [Epocn:67],[batch_count:8.0],[loss:0.087755],[accuracy:0.983708]
# [Epocn:67],[batch_count:9.0],[loss:0.085974],[accuracy:0.983194]
# [Epocn:67],[batch_count:10.0],[loss:0.086416],[accuracy:0.981613]
# [Epoch 67/201], [loss:0.087527], accuracy:0.981938]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:68],[batch_count:1.0],[loss:0.093706],[accuracy:0.978130]
