# %%
# !nvidia-smi # 查看GPU信息
# Out:
# Fri Jun 12 17:19:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 进入需要训练项目的文件夹
# %cd /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate3
# Out:
# /content/drive/My Drive/ML2020_spring_crack_detection/DeepCrackU-net-dilate3

# %%
# !pip install xlutils
# Out:
# Collecting xlutils
#   Downloading https://files.pythonhosted.org/packages/c7/55/e22ac73dbb316cabb5db28bef6c87044a95914f713a6e81b593f8a0d2f79/xlutils-2.0.0-py2.py3-none-any.whl (55kB)
#      |████████████████████████████████| 61kB 1.8MB/s
# Requirement already satisfied: xlrd>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.1.0)
# Requirement already satisfied: xlwt>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from xlutils) (1.3.0)
# Installing collected packages: xlutils
# Successfully installed xlutils-2.0.0

# %%
from models_deepcrack_unet import SegmentNet, weights_init_normal
from dataset_deepcrack_unet import CFDDataset

import torch.nn as nn
import torch

from torchvision import datasets
from torchvision.utils import save_image
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader

import os
import sys
import argparse
import time
import PIL.Image as Image

import numpy as np

import xlwt
import xlrd
from xlutils.copy import copy

# %%
# 在ipynb文件中，parse的创建用函数来创建
# 直接用parser=parser = argparse.ArgumentParser() 来创建之后调用会报错

def get_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument("--cuda", type=bool, default=True, help="number of gpu")
    parser.add_argument("--gpu_num", type=int, default=1, help="number of gpu")
    parser.add_argument("--worker_num", type=int, default=0, help="number of input workers") # 只有一个GPU,default=0表示单进程加载
    parser.add_argument("--batch_size", type=int, default=6, help="batch size of input")
    parser.add_argument("--lr", type=float, default=0.01, help="adam: learning rate")
    parser.add_argument("--b1", type=float, default=0.90, help="adam: decay of first order momentum of gradient")
    parser.add_argument("--b2", type=float, default=0.997, help="adam: decay of second order momentum of gradient")
    parser.add_argument("--weight_decay", type=float, default=0.0005, help="adam: weight decay coefficient")

    parser.add_argument("--begin_epoch", type=int, default=1, help="begin_epoch")
    parser.add_argument("--end_epoch", type=int, default=201, help="end_epoch")

    parser.add_argument("--need_test", type=bool, default=True, help="need to test")
    parser.add_argument("--test_interval", type=int, default=10, help="interval of test")
    parser.add_argument("--need_save", type=bool, default=True, help="need to save")
    parser.add_argument("--save_interval", type=int, default=10, help="interval of save weights")

    parser.add_argument("--img_width", type=int, default=480, help="size of image width")
    parser.add_argument("--img_height", type=int, default=320, help="size of image height")
    
    return parser.parse_args(args=[])

opt = get_arguments()

print(opt)
# Out:
# Namespace(b1=0.9, b2=0.997, batch_size=6, begin_epoch=1, cuda=True, end_epoch=201, gpu_num=1, img_height=320, img_width=480, lr=0.01, need_save=True, need_test=True, save_interval=10, test_interval=10, weight_decay=0.0005, worker_num=0)

# %%
dataSetRoot = "../Data_cleaned"

# %%
# 建立网络
segment_net = SegmentNet(init_weights=True)

# 选择二分类交叉熵损失函数
criterion_segment  = torch.nn.BCELoss()

# %%
# 选择Adam优化器
optimizer_seg = torch.optim.Adam(segment_net.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=opt.weight_decay)

# 指数方式调整学习率，每一个epoch之后学习率变为原来的0.98倍
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer_seg, gamma=0.98)

# %%
# 选择训练环境和参数
if opt.cuda:
    segment_net = segment_net.cuda()
    criterion_segment.cuda()

if opt.gpu_num > 1:
    segment_net = torch.nn.DataParallel(segment_net, device_ids=list(range(opt.gpu_num)))

if opt.begin_epoch != 1:
    # 加载前期训练的模型
    segment_net.load_state_dict(torch.load("./saved_models/segment_net_%d.pth" % (opt.begin_epoch-1)))
else:
    # 初始化权重
    segment_net.apply(weights_init_normal)

# %%
# 对原始数据和真实值进行一定前期处理，方便后续训练
transforms_ = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width), Image.BICUBIC),
    transforms.ToTensor()
])

transforms_mask = transforms.Compose([
    transforms.Resize((opt.img_height, opt.img_width)), 
    transforms.ToTensor()
])

# %%
# 加载训练集和测试集
trainCFDloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask, subFold="CFD", isTrain=True),
    batch_size=opt.batch_size,
    shuffle=True,
    num_workers=opt.worker_num,
)

testloader = DataLoader(
    CFDDataset(dataSetRoot, transforms_=transforms_, transforms_mask= transforms_mask,  subFold="CFD/cfd_TEST", isTrain=True),
    batch_size=1,
    shuffle=False,
    num_workers=opt.worker_num
)

# %%
# 定义对输出结果进行阈值化处理的函数，将小于阈值的计算为0，大于阈值的计算为1，在图像中像素为1的点为白色，为0的点为黑色
def data_threshold(data, threshold):
    threshold = torch.Tensor([threshold]).cuda()
    data_target = torch.Tensor([i//threshold for i in data]).cuda()
    return data_target

# %%
# 获取训练之后的 accuracy, precision , recall ,F1评价指标
# mask是真实值，data是预测值
def evaluate_metric(mask, data):
    m = metrics.confusion_matrix(mask, data)
    count_TP = m[1, 1]
    count_TN = m[0, 0]
    count_FN = m[1, 0] 
    count_FP = m[0 ,1]
    
    count = count_TP + count_FN + count_FP +count_TN
    print("count:{0},TP:{1},TN:{2},FP:{3},FN:{4}".format(count, count_TP, count_TN, count_FP, count_FN))  
    
    # 准确率
    accuracy = (count_TP+count_TN)/count 
    # 精准率
    precision = count_TP / (count_TP + count_FP) 
    # 查全率
    recall = count_TP / (count_TP + count_FN)
    # F1分
    F1 = 2*count_TP/(2*count_TP + count_FP + count_FN)
    
    return accuracy, precision, recall, F1

# %%
if opt.begin_epoch == 1:
  # 将训练过程的需要保存的数据保存到xls文件中
  # 创建一个workbook，设置编码
  workbook = xlwt.Workbook(encoding = 'utf-8')

  #---------------------写入训练过程的epoch, loss, accuracy------------------
  # 创建一个worksheet
  worksheet = workbook.add_sheet('sheet1')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')

  #---------------------写入测试过程的epoch, loss, accuracy------------------
  worksheet = workbook.add_sheet('sheet2')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'loss')
  worksheet.write(0, 2, 'accuracy')
                  
  #---------------------写入测试过程的epoch, accuracy, precision, recall, F1------------------                
  worksheet = workbook.add_sheet('sheet3')
  worksheet.write(0, 0, 'epoch')
  worksheet.write(0, 1, 'accuracy')
  worksheet.write(0, 2, 'precision')
  worksheet.write(0, 3, 'recall')
  worksheet.write(0, 4, 'F1')

  # 保存
  workbook.save('evaluate_data.xls')

def write_excel_xls_append(path, value, sheet_num):
  index = len(value)  # 获取需要写入数据的行数
  workbook = xlrd.open_workbook(path)            # 打开工作簿
  sheets = workbook.sheet_names()                # 获取工作簿中的所有表格
  worksheet = workbook.sheet_by_name(sheets[sheet_num])  # 获取工作簿中所有表格中的的第一个表格
  rows_old = worksheet.nrows                 # 获取表格中已存在的数据的行数
  new_workbook = copy(workbook)                # 将xlrd对象拷贝转化为xlwt对象
  new_worksheet = new_workbook.get_sheet(sheet_num)      # 获取转化后工作簿中的第sheet_num个表格
  
  for i in range(0, index):
      new_worksheet.write(rows_old, i, value[i])  # 追加写入数据
  new_workbook.save(path)  # 保存工作簿
  print("xls格式表格[追加]写入数据成功！")

# %%
for epoch in range(opt.begin_epoch, opt.end_epoch):

  iterCFD = trainCFDloader.__iter__()

  lenNum = len(trainCFDloader)

  segment_net.train()

  # -----------------------------------------------------------------------------
  # 开始训练
  # 记录每一个epoch的总损失和总精度
  train_loss_sum, train_acc_sum, batch_count = 0.0, 0.0, 0.0

  for i in range(0, lenNum):
      
    batchData = iterCFD.__next__()

    if opt.cuda:
        img = batchData["img"].cuda()
        mask = batchData["mask"].cuda()
    else:
        img = batchData["img"]
        mask = batchData["mask"]

    optimizer_seg.zero_grad()

    rst = segment_net(img)
    seg = rst["seg"]

    # 计算训练过程的损失loss
    loss_seg = 0.45*criterion_segment(seg, mask)+0.25*criterion_segment(rst["scale4"], mask)+0.15*criterion_segment(rst["scale3"], mask)\
            +0.1*criterion_segment(rst["scale2"], mask)+0.05*criterion_segment(rst["scale1"], mask)
    loss_seg.backward()
    optimizer_seg.step()

    train_loss_sum += loss_seg.item() 
    
    # 计算训练过程的accuracy
    net_seg = data_threshold(seg.clone().flatten(), 0.5)    # 预测值
    mask_seg = mask.clone().flatten()              # 真实值
    
    # 对每个像素点的值进行比较，相同的点计入right_seg 
    right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
    total_num = float(mask.clone().flatten().size()[0])
    
    batch_acc = right_seg/total_num
    train_acc_sum += batch_acc
    
    batch_count += 1
    
    # 输出每个epoch之中每个batch的信息
    print("[Epocn:{0}],[batch_count:{1}],[loss:{2:.6f}],[accuracy:{3:.6f}]".format(epoch, batch_count, loss_seg.item(), batch_acc))
    

  
  # 输出训练过程每个epoch平均的loss和accuracy
  print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, train_loss_sum/batch_count, train_acc_sum/batch_count))
    
  # 将上述epoch, loss, accuracy数据写入xls文件
  print("------------------------------------------------------------------------------------------")
  print("开始写入训练过程的epoch, loss, accuracy")
  train_xls_value = [epoch, train_loss_sum/batch_count, train_acc_sum/batch_count]
  write_excel_xls_append("evaluate_data.xls", train_xls_value, 0)
  print("------------------------------------------------------------------------------------------")
  

  # -----------------------------------------------------------------------------
  # 以一定周期保存训练之后的模型
  if opt.need_save and epoch % opt.save_interval == 0 and epoch >= opt.save_interval:

    save_path_str = "./saved_models"
    if os.path.exists(save_path_str) == False:
        os.makedirs(save_path_str, exist_ok=True)

    torch.save(segment_net.state_dict(), "%s/segment_net_%d.pth" % (save_path_str, epoch))
    print("------------------------------------------------------------------------------------------")
    print("save weights ! epoch = %d" %epoch)
    print("------------------------------------------------------------------------------------------")
    pass
    

  # -----------------------------------------------------------------------------
  # 对模型进行测试，并保存结果
  if opt.need_test and epoch % opt.test_interval == 0 and epoch >= opt.test_interval:

    test_loss_sum, test_acc_sum, batch_count = 0.0, 0.0, 0.0
    result_evaluate_epoch = np.array([0.0, 0.0, 0.0, 0.0])

    for i, testBatch in enumerate(testloader):
      imgTest = testBatch["img"].cuda()
      t1 = time.time()
      rstTest = segment_net(imgTest)
      t2 = time.time()

      # 计算测试过程的损失loss
      mask = testBatch["mask"].cuda()
      loss_test = criterion_segment(rstTest["seg"], mask)

      test_loss_sum += loss_test.item()

      # 计算测试过程的accuracy
      net_seg = data_threshold(rstTest["seg"].clone().flatten(), 0.5)  # 预测值
      mask_seg = mask.clone().flatten()                  # 真实值
      
      # 对每个像素点的值进行比较，相同的点计入right_seg 
      right_seg = torch.eq(net_seg, mask_seg).sum().float().item()
      total_num = float(mask.clone().flatten().size()[0])
      
      batch_acc = right_seg/total_num
      test_acc_sum += batch_acc
      
      batch_count += 1

      # 对一个batch测试结果进行综合评估，并进行累加，方便后续保存
      result_evaluate_batch = np.array(list(evaluate_metric(mask_seg, net_seg)))
      result_evaluate_epoch += result_evaluate_batch
      
      # 对保存的图片进行阈值化处理
      seg_shape = rstTest["seg"].data.shape
      segTest_flatten = data_threshold(rstTest["seg"].flatten(), 0.5)
      segTest = segTest_flatten.reshape(seg_shape[0], seg_shape[1], seg_shape[2], seg_shape[3])

      # 建立文件的保存路径
      save_path_str = "./testResultSeg/epoch_%d"%(epoch)
      if os.path.exists(save_path_str) == False:
          os.makedirs(save_path_str, exist_ok=True)

      # 输出文件的保存信息
      print("processing image NO %d, time comsuption %fs"%(i, t2 - t1))
      save_image(imgTest.data, "%s/img_%d.jpg"% (save_path_str, i))
      save_image(segTest.data, "%s/img_%d_seg.jpg"% (save_path_str, i))
      save_image(rstTest["seg"].data, "%s/img_%d_raw_seg.jpg"% (save_path_str, i))

    # 将上述测试过程的评估参数acc,precision,recall和F1分数进行保存
    print("------------------------------------------------------------------------------------------")
    print("开始写入评估参数")
    result_evaluate_epoch = result_evaluate_epoch/np.array([batch_count])
    test_xls_metric = [epoch] + list(result_evaluate_epoch)
    write_excel_xls_append("evaluate_data.xls", test_xls_metric, 2)
    print("------------------------------------------------------------------------------------------")
    
    # 输出测试过程每个epoch平均的loss和accuracy
    print("------------------------------------------------------------------------------------------")
    print("[Epoch {0}/{1}], [loss:{2:.6f}], accuracy:{3:.6f}]".format(epoch, opt.end_epoch, test_loss_sum/batch_count, test_acc_sum/batch_count))
    print("------------------------------------------------------------------------------------------")
    
    # 将上述epoch, loss, accuracy数据写入xls文件
    print("------------------------------------------------------------------------------------------")
    print("开始写入测试过程的epoch, loss, accuracy")
    test_xls_value = [epoch, test_loss_sum/batch_count, test_acc_sum/batch_count]
    write_excel_xls_append("evaluate_data.xls", test_xls_value, 1)
    print("------------------------------------------------------------------------------------------")

  # 利用schedular对学习率进行调节
  scheduler.step()
# Out:
# [Epocn:1],[batch_count:1.0],[loss:0.805180],[accuracy:0.506500]
# [Epocn:1],[batch_count:2.0],[loss:0.685056],[accuracy:0.781086]
# [Epocn:1],[batch_count:3.0],[loss:0.741570],[accuracy:0.687679]
# [Epocn:1],[batch_count:4.0],[loss:0.709629],[accuracy:0.887109]
# [Epocn:1],[batch_count:5.0],[loss:0.670892],[accuracy:0.853688]
# [Epocn:1],[batch_count:6.0],[loss:0.664724],[accuracy:0.882677]
# [Epocn:1],[batch_count:7.0],[loss:0.620515],[accuracy:0.909146]
# [Epocn:1],[batch_count:8.0],[loss:0.659423],[accuracy:0.874562]
# [Epocn:1],[batch_count:9.0],[loss:0.683645],[accuracy:0.866089]
# [Epocn:1],[batch_count:10.0],[loss:0.645757],[accuracy:0.895186]
# [Epoch 1/201], [loss:0.688639], accuracy:0.814372]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:2],[batch_count:1.0],[loss:0.644859],[accuracy:0.907589]
# [Epocn:2],[batch_count:2.0],[loss:0.590772],[accuracy:0.942805]
# [Epocn:2],[batch_count:3.0],[loss:0.606154],[accuracy:0.921631]
# [Epocn:2],[batch_count:4.0],[loss:0.594999],[accuracy:0.927701]
# [Epocn:2],[batch_count:5.0],[loss:0.587383],[accuracy:0.939442]
# [Epocn:2],[batch_count:6.0],[loss:0.596051],[accuracy:0.937537]
# [Epocn:2],[batch_count:7.0],[loss:0.581364],[accuracy:0.958886]
# [Epocn:2],[batch_count:8.0],[loss:0.569959],[accuracy:0.945290]
# [Epocn:2],[batch_count:9.0],[loss:0.613212],[accuracy:0.917525]
# [Epocn:2],[batch_count:10.0],[loss:0.586079],[accuracy:0.941352]
# [Epoch 2/201], [loss:0.597083], accuracy:0.933976]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:3],[batch_count:1.0],[loss:0.564767],[accuracy:0.950423]
# [Epocn:3],[batch_count:2.0],[loss:0.572443],[accuracy:0.962486]
# [Epocn:3],[batch_count:3.0],[loss:0.561204],[accuracy:0.953796]
# [Epocn:3],[batch_count:4.0],[loss:0.547712],[accuracy:0.964784]
# [Epocn:3],[batch_count:5.0],[loss:0.543635],[accuracy:0.961605]
# [Epocn:3],[batch_count:6.0],[loss:0.554957],[accuracy:0.958598]
# [Epocn:3],[batch_count:7.0],[loss:0.550929],[accuracy:0.944273]
# [Epocn:3],[batch_count:8.0],[loss:0.531727],[accuracy:0.974508]
# [Epocn:3],[batch_count:9.0],[loss:0.543040],[accuracy:0.962893]
# [Epocn:3],[batch_count:10.0],[loss:0.521153],[accuracy:0.975046]
# [Epoch 3/201], [loss:0.549157], accuracy:0.960841]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:4],[batch_count:1.0],[loss:0.512450],[accuracy:0.976254]
# [Epocn:4],[batch_count:2.0],[loss:0.510253],[accuracy:0.972105]
# [Epocn:4],[batch_count:3.0],[loss:0.529006],[accuracy:0.956290]
# [Epocn:4],[batch_count:4.0],[loss:0.536571],[accuracy:0.947106]
# [Epocn:4],[batch_count:5.0],[loss:0.528602],[accuracy:0.947126]
# [Epocn:4],[batch_count:6.0],[loss:0.512120],[accuracy:0.955004]
# [Epocn:4],[batch_count:7.0],[loss:0.535223],[accuracy:0.936233]
# [Epocn:4],[batch_count:8.0],[loss:0.501678],[accuracy:0.964448]
# [Epocn:4],[batch_count:9.0],[loss:0.502011],[accuracy:0.972760]
# [Epocn:4],[batch_count:10.0],[loss:0.499771],[accuracy:0.973267]
# [Epoch 4/201], [loss:0.516769], accuracy:0.960059]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:5],[batch_count:1.0],[loss:0.483869],[accuracy:0.972670]
# [Epocn:5],[batch_count:2.0],[loss:0.494664],[accuracy:0.968696]
# [Epocn:5],[batch_count:3.0],[loss:0.480979],[accuracy:0.974888]
# [Epocn:5],[batch_count:4.0],[loss:0.474778],[accuracy:0.973125]
# [Epocn:5],[batch_count:5.0],[loss:0.475099],[accuracy:0.975777]
# [Epocn:5],[batch_count:6.0],[loss:0.473913],[accuracy:0.979350]
# [Epocn:5],[batch_count:7.0],[loss:0.484935],[accuracy:0.953416]
# [Epocn:5],[batch_count:8.0],[loss:0.472550],[accuracy:0.970316]
# [Epocn:5],[batch_count:9.0],[loss:0.449645],[accuracy:0.974842]
# [Epocn:5],[batch_count:10.0],[loss:0.476113],[accuracy:0.960017]
# [Epoch 5/201], [loss:0.476654], accuracy:0.970310]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:6],[batch_count:1.0],[loss:0.469704],[accuracy:0.964273]
# [Epocn:6],[batch_count:2.0],[loss:0.440747],[accuracy:0.973213]
# [Epocn:6],[batch_count:3.0],[loss:0.449667],[accuracy:0.967121]
# [Epocn:6],[batch_count:4.0],[loss:0.450190],[accuracy:0.977959]
# [Epocn:6],[batch_count:5.0],[loss:0.456036],[accuracy:0.974412]
# [Epocn:6],[batch_count:6.0],[loss:0.457138],[accuracy:0.972139]
# [Epocn:6],[batch_count:7.0],[loss:0.454258],[accuracy:0.978994]
# [Epocn:6],[batch_count:8.0],[loss:0.435609],[accuracy:0.978546]
# [Epocn:6],[batch_count:9.0],[loss:0.443683],[accuracy:0.965575]
# [Epocn:6],[batch_count:10.0],[loss:0.428389],[accuracy:0.971564]
# [Epoch 6/201], [loss:0.448542], accuracy:0.972380]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:7],[batch_count:1.0],[loss:0.417807],[accuracy:0.974656]
# [Epocn:7],[batch_count:2.0],[loss:0.431938],[accuracy:0.964722]
# [Epocn:7],[batch_count:3.0],[loss:0.419115],[accuracy:0.974341]
# [Epocn:7],[batch_count:4.0],[loss:0.419108],[accuracy:0.969286]
# [Epocn:7],[batch_count:5.0],[loss:0.414801],[accuracy:0.976306]
# [Epocn:7],[batch_count:6.0],[loss:0.437438],[accuracy:0.975539]
# [Epocn:7],[batch_count:7.0],[loss:0.414488],[accuracy:0.981100]
# [Epocn:7],[batch_count:8.0],[loss:0.421081],[accuracy:0.972984]
# [Epocn:7],[batch_count:9.0],[loss:0.408184],[accuracy:0.982804]
# [Epocn:7],[batch_count:10.0],[loss:0.404219],[accuracy:0.980436]
# [Epoch 7/201], [loss:0.418818], accuracy:0.975218]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:8],[batch_count:1.0],[loss:0.399445],[accuracy:0.977593]
# [Epocn:8],[batch_count:2.0],[loss:0.396183],[accuracy:0.969389]
# [Epocn:8],[batch_count:3.0],[loss:0.395914],[accuracy:0.974178]
# [Epocn:8],[batch_count:4.0],[loss:0.392964],[accuracy:0.976338]
# [Epocn:8],[batch_count:5.0],[loss:0.400815],[accuracy:0.971097]
# [Epocn:8],[batch_count:6.0],[loss:0.393564],[accuracy:0.975910]
# [Epocn:8],[batch_count:7.0],[loss:0.401008],[accuracy:0.979668]
# [Epocn:8],[batch_count:8.0],[loss:0.390090],[accuracy:0.975560]
# [Epocn:8],[batch_count:9.0],[loss:0.391322],[accuracy:0.975525]
# [Epocn:8],[batch_count:10.0],[loss:0.385587],[accuracy:0.982992]
# [Epoch 8/201], [loss:0.394689], accuracy:0.975825]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:9],[batch_count:1.0],[loss:0.396984],[accuracy:0.970707]
# [Epocn:9],[batch_count:2.0],[loss:0.389367],[accuracy:0.975680]
# [Epocn:9],[batch_count:3.0],[loss:0.442119],[accuracy:0.950892]
# [Epocn:9],[batch_count:4.0],[loss:0.391868],[accuracy:0.969690]
# [Epocn:9],[batch_count:5.0],[loss:0.370635],[accuracy:0.980730]
# [Epocn:9],[batch_count:6.0],[loss:0.383039],[accuracy:0.974370]
# [Epocn:9],[batch_count:7.0],[loss:0.366149],[accuracy:0.981822]
# [Epocn:9],[batch_count:8.0],[loss:0.370728],[accuracy:0.976617]
# [Epocn:9],[batch_count:9.0],[loss:0.367027],[accuracy:0.974364]
# [Epocn:9],[batch_count:10.0],[loss:0.353333],[accuracy:0.972281]
# [Epoch 9/201], [loss:0.383125], accuracy:0.972715]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:10],[batch_count:1.0],[loss:0.373626],[accuracy:0.968204]
# [Epocn:10],[batch_count:2.0],[loss:0.346254],[accuracy:0.976727]
# [Epocn:10],[batch_count:3.0],[loss:0.356721],[accuracy:0.973001]
# [Epocn:10],[batch_count:4.0],[loss:0.380545],[accuracy:0.972274]
# [Epocn:10],[batch_count:5.0],[loss:0.356048],[accuracy:0.980511]
# [Epocn:10],[batch_count:6.0],[loss:0.356131],[accuracy:0.980180]
# [Epocn:10],[batch_count:7.0],[loss:0.354145],[accuracy:0.981343]
# [Epocn:10],[batch_count:8.0],[loss:0.350979],[accuracy:0.980182]
# [Epocn:10],[batch_count:9.0],[loss:0.336930],[accuracy:0.978296]
# [Epocn:10],[batch_count:10.0],[loss:0.357588],[accuracy:0.966225]
# [Epoch 10/201], [loss:0.356897], accuracy:0.975695]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 10
# ------------------------------------------------------------------------------------------
# count:153600,TP:2895,TN:149088,FP:1167,FN450
# processing image NO 0, time comsuption 0.014738s
# count:153600,TP:2835,TN:148662,FP:1274,FN829
# processing image NO 1, time comsuption 0.010711s
# count:153600,TP:4405,TN:146388,FP:1124,FN1683
# processing image NO 2, time comsuption 0.011154s
# count:153600,TP:2335,TN:147689,FP:1983,FN1593
# processing image NO 3, time comsuption 0.011377s
# count:153600,TP:2699,TN:149727,FP:1091,FN83
# processing image NO 4, time comsuption 0.011395s
# count:153600,TP:2760,TN:149585,FP:1118,FN137
# processing image NO 5, time comsuption 0.010750s
# count:153600,TP:3271,TN:148600,FP:1215,FN514
# processing image NO 6, time comsuption 0.014182s
# count:153600,TP:3372,TN:149158,FP:809,FN261
# processing image NO 7, time comsuption 0.014044s
# count:153600,TP:2564,TN:149116,FP:1550,FN370
# processing image NO 8, time comsuption 0.013765s
# count:153600,TP:2327,TN:147631,FP:3372,FN270
# processing image NO 9, time comsuption 0.013964s
# count:153600,TP:2694,TN:147231,FP:1637,FN2038
# processing image NO 10, time comsuption 0.015693s
# count:153600,TP:2356,TN:148435,FP:2434,FN375
# processing image NO 11, time comsuption 0.011964s
# count:153600,TP:2131,TN:148167,FP:2779,FN523
# processing image NO 12, time comsuption 0.014219s
# count:153600,TP:1617,TN:146468,FP:4540,FN975
# processing image NO 13, time comsuption 0.011176s
# count:153600,TP:2355,TN:147348,FP:2841,FN1056
# processing image NO 14, time comsuption 0.011557s
# count:153600,TP:2461,TN:148195,FP:2151,FN793
# processing image NO 15, time comsuption 0.014295s
# count:153600,TP:2977,TN:148284,FP:1451,FN888
# processing image NO 16, time comsuption 0.019096s
# count:153600,TP:2218,TN:149028,FP:1955,FN399
# processing image NO 17, time comsuption 0.013367s
# count:153600,TP:2488,TN:148268,FP:2185,FN659
# processing image NO 18, time comsuption 0.012420s
# count:153600,TP:2363,TN:148615,FP:1775,FN847
# processing image NO 19, time comsuption 0.011702s
# count:153600,TP:2405,TN:149436,FP:1116,FN643
# processing image NO 20, time comsuption 0.014959s
# count:153600,TP:3175,TN:147398,FP:1849,FN1178
# processing image NO 21, time comsuption 0.014362s
# count:153600,TP:2290,TN:147896,FP:2868,FN546
# processing image NO 22, time comsuption 0.014198s
# count:153600,TP:3063,TN:148339,FP:1345,FN853
# processing image NO 23, time comsuption 0.013893s
# count:153600,TP:2049,TN:148639,FP:2428,FN484
# processing image NO 24, time comsuption 0.011705s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 10/201], [loss:0.336379], accuracy:0.982678]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:11],[batch_count:1.0],[loss:0.348881],[accuracy:0.977866]
# [Epocn:11],[batch_count:2.0],[loss:0.342291],[accuracy:0.976834]
# [Epocn:11],[batch_count:3.0],[loss:0.335555],[accuracy:0.977105]
# [Epocn:11],[batch_count:4.0],[loss:0.351606],[accuracy:0.965141]
# [Epocn:11],[batch_count:5.0],[loss:0.347412],[accuracy:0.974427]
# [Epocn:11],[batch_count:6.0],[loss:0.322368],[accuracy:0.978746]
# [Epocn:11],[batch_count:7.0],[loss:0.333591],[accuracy:0.979596]
# [Epocn:11],[batch_count:8.0],[loss:0.322403],[accuracy:0.977810]
# [Epocn:11],[batch_count:9.0],[loss:0.331556],[accuracy:0.980788]
# [Epocn:11],[batch_count:10.0],[loss:0.329866],[accuracy:0.978233]
# [Epoch 11/201], [loss:0.336553], accuracy:0.976655]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:12],[batch_count:1.0],[loss:0.327003],[accuracy:0.974444]
# [Epocn:12],[batch_count:2.0],[loss:0.320026],[accuracy:0.983575]
# [Epocn:12],[batch_count:3.0],[loss:0.320633],[accuracy:0.978843]
# [Epocn:12],[batch_count:4.0],[loss:0.307087],[accuracy:0.979398]
# [Epocn:12],[batch_count:5.0],[loss:0.317752],[accuracy:0.975911]
# [Epocn:12],[batch_count:6.0],[loss:0.317054],[accuracy:0.980043]
# [Epocn:12],[batch_count:7.0],[loss:0.319362],[accuracy:0.980941]
# [Epocn:12],[batch_count:8.0],[loss:0.327962],[accuracy:0.971034]
# [Epocn:12],[batch_count:9.0],[loss:0.312133],[accuracy:0.983107]
# [Epocn:12],[batch_count:10.0],[loss:0.309365],[accuracy:0.981777]
# [Epoch 12/201], [loss:0.317838], accuracy:0.978907]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:13],[batch_count:1.0],[loss:0.303320],[accuracy:0.981366]
# [Epocn:13],[batch_count:2.0],[loss:0.305709],[accuracy:0.971297]
# [Epocn:13],[batch_count:3.0],[loss:0.303384],[accuracy:0.982210]
# [Epocn:13],[batch_count:4.0],[loss:0.301962],[accuracy:0.974155]
# [Epocn:13],[batch_count:5.0],[loss:0.295920],[accuracy:0.980778]
# [Epocn:13],[batch_count:6.0],[loss:0.326670],[accuracy:0.964021]
# [Epocn:13],[batch_count:7.0],[loss:0.316354],[accuracy:0.966026]
# [Epocn:13],[batch_count:8.0],[loss:0.310924],[accuracy:0.971535]
# [Epocn:13],[batch_count:9.0],[loss:0.314863],[accuracy:0.976077]
# [Epocn:13],[batch_count:10.0],[loss:0.318892],[accuracy:0.981951]
# [Epoch 13/201], [loss:0.309800], accuracy:0.974942]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:14],[batch_count:1.0],[loss:0.305805],[accuracy:0.979387]
# [Epocn:14],[batch_count:2.0],[loss:0.301862],[accuracy:0.974660]
# [Epocn:14],[batch_count:3.0],[loss:0.297751],[accuracy:0.981132]
# [Epocn:14],[batch_count:4.0],[loss:0.294664],[accuracy:0.980283]
# [Epocn:14],[batch_count:5.0],[loss:0.301891],[accuracy:0.970720]
# [Epocn:14],[batch_count:6.0],[loss:0.307928],[accuracy:0.970511]
# [Epocn:14],[batch_count:7.0],[loss:0.284614],[accuracy:0.984647]
# [Epocn:14],[batch_count:8.0],[loss:0.285322],[accuracy:0.981846]
# [Epocn:14],[batch_count:9.0],[loss:0.286452],[accuracy:0.985473]
# [Epocn:14],[batch_count:10.0],[loss:0.278964],[accuracy:0.980156]
# [Epoch 14/201], [loss:0.294525], accuracy:0.978882]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:15],[batch_count:1.0],[loss:0.276349],[accuracy:0.984071]
# [Epocn:15],[batch_count:2.0],[loss:0.271951],[accuracy:0.979140]
# [Epocn:15],[batch_count:3.0],[loss:0.272727],[accuracy:0.982559]
# [Epocn:15],[batch_count:4.0],[loss:0.282834],[accuracy:0.978757]
# [Epocn:15],[batch_count:5.0],[loss:0.285809],[accuracy:0.971833]
# [Epocn:15],[batch_count:6.0],[loss:0.282276],[accuracy:0.976350]
# [Epocn:15],[batch_count:7.0],[loss:0.268155],[accuracy:0.984015]
# [Epocn:15],[batch_count:8.0],[loss:0.271303],[accuracy:0.979834]
# [Epocn:15],[batch_count:9.0],[loss:0.288986],[accuracy:0.975582]
# [Epocn:15],[batch_count:10.0],[loss:0.273056],[accuracy:0.985020]
# [Epoch 15/201], [loss:0.277344], accuracy:0.979716]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:16],[batch_count:1.0],[loss:0.261720],[accuracy:0.984478]
# [Epocn:16],[batch_count:2.0],[loss:0.265093],[accuracy:0.983201]
# [Epocn:16],[batch_count:3.0],[loss:0.260481],[accuracy:0.986245]
# [Epocn:16],[batch_count:4.0],[loss:0.282591],[accuracy:0.979040]
# [Epocn:16],[batch_count:5.0],[loss:0.268165],[accuracy:0.979940]
# [Epocn:16],[batch_count:6.0],[loss:0.267848],[accuracy:0.981160]
# [Epocn:16],[batch_count:7.0],[loss:0.272987],[accuracy:0.966074]
# [Epocn:16],[batch_count:8.0],[loss:0.263778],[accuracy:0.975349]
# [Epocn:16],[batch_count:9.0],[loss:0.272713],[accuracy:0.976769]
# [Epocn:16],[batch_count:10.0],[loss:0.278675],[accuracy:0.973736]
# [Epoch 16/201], [loss:0.269405], accuracy:0.978599]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:17],[batch_count:1.0],[loss:0.282614],[accuracy:0.977426]
# [Epocn:17],[batch_count:2.0],[loss:0.255117],[accuracy:0.984707]
# [Epocn:17],[batch_count:3.0],[loss:0.252152],[accuracy:0.984512]
# [Epocn:17],[batch_count:4.0],[loss:0.264760],[accuracy:0.981827]
# [Epocn:17],[batch_count:5.0],[loss:0.260441],[accuracy:0.981939]
# [Epocn:17],[batch_count:6.0],[loss:0.253251],[accuracy:0.981598]
# [Epocn:17],[batch_count:7.0],[loss:0.262181],[accuracy:0.972537]
# [Epocn:17],[batch_count:8.0],[loss:0.249956],[accuracy:0.976836]
# [Epocn:17],[batch_count:9.0],[loss:0.253637],[accuracy:0.981872]
# [Epocn:17],[batch_count:10.0],[loss:0.246819],[accuracy:0.975799]
# [Epoch 17/201], [loss:0.258093], accuracy:0.979905]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:18],[batch_count:1.0],[loss:0.299428],[accuracy:0.970769]
# [Epocn:18],[batch_count:2.0],[loss:0.280332],[accuracy:0.976403]
# [Epocn:18],[batch_count:3.0],[loss:0.252480],[accuracy:0.984275]
# [Epocn:18],[batch_count:4.0],[loss:0.258483],[accuracy:0.979799]
# [Epocn:18],[batch_count:5.0],[loss:0.254039],[accuracy:0.974124]
# [Epocn:18],[batch_count:6.0],[loss:0.243011],[accuracy:0.978780]
# [Epocn:18],[batch_count:7.0],[loss:0.262784],[accuracy:0.969806]
# [Epocn:18],[batch_count:8.0],[loss:0.234008],[accuracy:0.980667]
# [Epocn:18],[batch_count:9.0],[loss:0.244448],[accuracy:0.979558]
# [Epocn:18],[batch_count:10.0],[loss:0.230285],[accuracy:0.983991]
# [Epoch 18/201], [loss:0.255930], accuracy:0.977817]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:19],[batch_count:1.0],[loss:0.245399],[accuracy:0.980567]
# [Epocn:19],[batch_count:2.0],[loss:0.240432],[accuracy:0.982317]
# [Epocn:19],[batch_count:3.0],[loss:0.235194],[accuracy:0.977921]
# [Epocn:19],[batch_count:4.0],[loss:0.240823],[accuracy:0.971786]
# [Epocn:19],[batch_count:5.0],[loss:0.238373],[accuracy:0.980115]
# [Epocn:19],[batch_count:6.0],[loss:0.229433],[accuracy:0.985424]
# [Epocn:19],[batch_count:7.0],[loss:0.235360],[accuracy:0.979858]
# [Epocn:19],[batch_count:8.0],[loss:0.236843],[accuracy:0.981622]
# [Epocn:19],[batch_count:9.0],[loss:0.253865],[accuracy:0.976334]
# [Epocn:19],[batch_count:10.0],[loss:0.242080],[accuracy:0.980516]
# [Epoch 19/201], [loss:0.239780], accuracy:0.979646]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:20],[batch_count:1.0],[loss:0.235643],[accuracy:0.984724]
# [Epocn:20],[batch_count:2.0],[loss:0.226608],[accuracy:0.986339]
# [Epocn:20],[batch_count:3.0],[loss:0.244350],[accuracy:0.972681]
# [Epocn:20],[batch_count:4.0],[loss:0.232126],[accuracy:0.981395]
# [Epocn:20],[batch_count:5.0],[loss:0.233593],[accuracy:0.982674]
# [Epocn:20],[batch_count:6.0],[loss:0.260631],[accuracy:0.968671]
# [Epocn:20],[batch_count:7.0],[loss:0.232972],[accuracy:0.979044]
# [Epocn:20],[batch_count:8.0],[loss:0.219955],[accuracy:0.978558]
# [Epocn:20],[batch_count:9.0],[loss:0.222090],[accuracy:0.985041]
# [Epocn:20],[batch_count:10.0],[loss:0.224452],[accuracy:0.976699]
# [Epoch 20/201], [loss:0.233242], accuracy:0.979583]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 20
# ------------------------------------------------------------------------------------------
# count:153600,TP:2356,TN:149839,FP:416,FN989
# processing image NO 0, time comsuption 0.015063s
# count:153600,TP:2330,TN:149505,FP:431,FN1334
# processing image NO 1, time comsuption 0.010065s
# count:153600,TP:3793,TN:146998,FP:514,FN2295
# processing image NO 2, time comsuption 0.011472s
# count:153600,TP:1817,TN:149012,FP:660,FN2111
# processing image NO 3, time comsuption 0.010847s
# count:153600,TP:2300,TN:150299,FP:519,FN482
# processing image NO 4, time comsuption 0.013887s
# count:153600,TP:2272,TN:150220,FP:483,FN625
# processing image NO 5, time comsuption 0.012271s
# count:153600,TP:2842,TN:149365,FP:450,FN943
# processing image NO 6, time comsuption 0.011353s
# count:153600,TP:2793,TN:149682,FP:285,FN840
# processing image NO 7, time comsuption 0.011382s
# count:153600,TP:2201,TN:150037,FP:629,FN733
# processing image NO 8, time comsuption 0.010885s
# count:153600,TP:2007,TN:148846,FP:2157,FN590
# processing image NO 9, time comsuption 0.012485s
# count:153600,TP:2159,TN:148010,FP:858,FN2573
# processing image NO 10, time comsuption 0.013821s
# count:153600,TP:1991,TN:150077,FP:792,FN740
# processing image NO 11, time comsuption 0.011202s
# count:153600,TP:1871,TN:149772,FP:1174,FN783
# processing image NO 12, time comsuption 0.011095s
# count:153600,TP:1568,TN:148806,FP:2202,FN1024
# processing image NO 13, time comsuption 0.013621s
# count:153600,TP:1912,TN:149387,FP:802,FN1499
# processing image NO 14, time comsuption 0.010539s
# count:153600,TP:2024,TN:149248,FP:1098,FN1230
# processing image NO 15, time comsuption 0.011400s
# count:153600,TP:2347,TN:149186,FP:549,FN1518
# processing image NO 16, time comsuption 0.010934s
# count:153600,TP:1927,TN:150279,FP:704,FN690
# processing image NO 17, time comsuption 0.010854s
# count:153600,TP:1908,TN:149500,FP:953,FN1239
# processing image NO 18, time comsuption 0.011352s
# count:153600,TP:2066,TN:149708,FP:682,FN1144
# processing image NO 19, time comsuption 0.010895s
# count:153600,TP:2009,TN:150128,FP:424,FN1039
# processing image NO 20, time comsuption 0.011040s
# count:153600,TP:2614,TN:148345,FP:902,FN1739
# processing image NO 21, time comsuption 0.011134s
# count:153600,TP:1902,TN:149683,FP:1081,FN934
# processing image NO 22, time comsuption 0.013858s
# count:153600,TP:2541,TN:149130,FP:554,FN1375
# processing image NO 23, time comsuption 0.010825s
# count:153600,TP:1720,TN:150126,FP:941,FN813
# processing image NO 24, time comsuption 0.014236s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 20/201], [loss:0.212515], accuracy:0.987091]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:21],[batch_count:1.0],[loss:0.224442],[accuracy:0.978137]
# [Epocn:21],[batch_count:2.0],[loss:0.230593],[accuracy:0.980400]
# [Epocn:21],[batch_count:3.0],[loss:0.217466],[accuracy:0.981049]
# [Epocn:21],[batch_count:4.0],[loss:0.217717],[accuracy:0.982578]
# [Epocn:21],[batch_count:5.0],[loss:0.216831],[accuracy:0.979666]
# [Epocn:21],[batch_count:6.0],[loss:0.214051],[accuracy:0.984350]
# [Epocn:21],[batch_count:7.0],[loss:0.216541],[accuracy:0.984949]
# [Epocn:21],[batch_count:8.0],[loss:0.213026],[accuracy:0.982096]
# [Epocn:21],[batch_count:9.0],[loss:0.223944],[accuracy:0.979409]
# [Epocn:21],[batch_count:10.0],[loss:0.229815],[accuracy:0.976868]
# [Epoch 21/201], [loss:0.220442], accuracy:0.980950]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:22],[batch_count:1.0],[loss:0.211449],[accuracy:0.981119]
# [Epocn:22],[batch_count:2.0],[loss:0.207111],[accuracy:0.984439]
# [Epocn:22],[batch_count:3.0],[loss:0.208168],[accuracy:0.985200]
# [Epocn:22],[batch_count:4.0],[loss:0.214050],[accuracy:0.978759]
# [Epocn:22],[batch_count:5.0],[loss:0.208629],[accuracy:0.985913]
# [Epocn:22],[batch_count:6.0],[loss:0.211354],[accuracy:0.982824]
# [Epocn:22],[batch_count:7.0],[loss:0.224586],[accuracy:0.966516]
# [Epocn:22],[batch_count:8.0],[loss:0.219429],[accuracy:0.973084]
# [Epocn:22],[batch_count:9.0],[loss:0.207257],[accuracy:0.982758]
# [Epocn:22],[batch_count:10.0],[loss:0.286153],[accuracy:0.955007]
# [Epoch 22/201], [loss:0.219819], accuracy:0.977562]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:23],[batch_count:1.0],[loss:0.223639],[accuracy:0.978868]
# [Epocn:23],[batch_count:2.0],[loss:0.225083],[accuracy:0.969672]
# [Epocn:23],[batch_count:3.0],[loss:0.210893],[accuracy:0.980757]
# [Epocn:23],[batch_count:4.0],[loss:0.216218],[accuracy:0.977626]
# [Epocn:23],[batch_count:5.0],[loss:0.206298],[accuracy:0.984781]
# [Epocn:23],[batch_count:6.0],[loss:0.240383],[accuracy:0.974227]
# [Epocn:23],[batch_count:7.0],[loss:0.219926],[accuracy:0.976468]
# [Epocn:23],[batch_count:8.0],[loss:0.228095],[accuracy:0.970557]
# [Epocn:23],[batch_count:9.0],[loss:0.203131],[accuracy:0.979958]
# [Epocn:23],[batch_count:10.0],[loss:0.203917],[accuracy:0.980616]
# [Epoch 23/201], [loss:0.217758], accuracy:0.977353]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:24],[batch_count:1.0],[loss:0.207999],[accuracy:0.980704]
# [Epocn:24],[batch_count:2.0],[loss:0.210218],[accuracy:0.981931]
# [Epocn:24],[batch_count:3.0],[loss:0.204270],[accuracy:0.984371]
# [Epocn:24],[batch_count:4.0],[loss:0.218952],[accuracy:0.975907]
# [Epocn:24],[batch_count:5.0],[loss:0.207163],[accuracy:0.974703]
# [Epocn:24],[batch_count:6.0],[loss:0.210664],[accuracy:0.979586]
# [Epocn:24],[batch_count:7.0],[loss:0.204653],[accuracy:0.972161]
# [Epocn:24],[batch_count:8.0],[loss:0.241974],[accuracy:0.969175]
# [Epocn:24],[batch_count:9.0],[loss:0.211237],[accuracy:0.980569]
# [Epocn:24],[batch_count:10.0],[loss:0.194104],[accuracy:0.985241]
# [Epoch 24/201], [loss:0.211123], accuracy:0.978435]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:25],[batch_count:1.0],[loss:0.211166],[accuracy:0.973238]
# [Epocn:25],[batch_count:2.0],[loss:0.211540],[accuracy:0.983275]
# [Epocn:25],[batch_count:3.0],[loss:0.203670],[accuracy:0.979910]
# [Epocn:25],[batch_count:4.0],[loss:0.195676],[accuracy:0.978296]
# [Epocn:25],[batch_count:5.0],[loss:0.207969],[accuracy:0.982644]
# [Epocn:25],[batch_count:6.0],[loss:0.208112],[accuracy:0.982134]
# [Epocn:25],[batch_count:7.0],[loss:0.196141],[accuracy:0.976359]
# [Epocn:25],[batch_count:8.0],[loss:0.188954],[accuracy:0.981849]
# [Epocn:25],[batch_count:9.0],[loss:0.194074],[accuracy:0.980679]
# [Epocn:25],[batch_count:10.0],[loss:0.203989],[accuracy:0.976802]
# [Epoch 25/201], [loss:0.202129], accuracy:0.979519]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:26],[batch_count:1.0],[loss:0.188783],[accuracy:0.985052]
# [Epocn:26],[batch_count:2.0],[loss:0.197870],[accuracy:0.982030]
# [Epocn:26],[batch_count:3.0],[loss:0.193639],[accuracy:0.983418]
# [Epocn:26],[batch_count:4.0],[loss:0.195792],[accuracy:0.977435]
# [Epocn:26],[batch_count:5.0],[loss:0.197862],[accuracy:0.976031]
# [Epocn:26],[batch_count:6.0],[loss:0.188383],[accuracy:0.978772]
# [Epocn:26],[batch_count:7.0],[loss:0.178474],[accuracy:0.982576]
# [Epocn:26],[batch_count:8.0],[loss:0.191989],[accuracy:0.979899]
# [Epocn:26],[batch_count:9.0],[loss:0.204607],[accuracy:0.976589]
# [Epocn:26],[batch_count:10.0],[loss:0.182434],[accuracy:0.984828]
# [Epoch 26/201], [loss:0.191983], accuracy:0.980663]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:27],[batch_count:1.0],[loss:0.200796],[accuracy:0.976698]
# [Epocn:27],[batch_count:2.0],[loss:0.185761],[accuracy:0.983997]
# [Epocn:27],[batch_count:3.0],[loss:0.198773],[accuracy:0.981326]
# [Epocn:27],[batch_count:4.0],[loss:0.178367],[accuracy:0.986171]
# [Epocn:27],[batch_count:5.0],[loss:0.184422],[accuracy:0.980490]
# [Epocn:27],[batch_count:6.0],[loss:0.187841],[accuracy:0.984236]
# [Epocn:27],[batch_count:7.0],[loss:0.177789],[accuracy:0.985023]
# [Epocn:27],[batch_count:8.0],[loss:0.185115],[accuracy:0.982642]
# [Epocn:27],[batch_count:9.0],[loss:0.178816],[accuracy:0.980728]
# [Epocn:27],[batch_count:10.0],[loss:0.196010],[accuracy:0.969815]
# [Epoch 27/201], [loss:0.187369], accuracy:0.981113]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:28],[batch_count:1.0],[loss:0.189090],[accuracy:0.976216]
# [Epocn:28],[batch_count:2.0],[loss:0.180505],[accuracy:0.984582]
# [Epocn:28],[batch_count:3.0],[loss:0.176287],[accuracy:0.985064]
# [Epocn:28],[batch_count:4.0],[loss:0.170341],[accuracy:0.987427]
# [Epocn:28],[batch_count:5.0],[loss:0.180768],[accuracy:0.977686]
# [Epocn:28],[batch_count:6.0],[loss:0.180596],[accuracy:0.980152]
# [Epocn:28],[batch_count:7.0],[loss:0.194709],[accuracy:0.974184]
# [Epocn:28],[batch_count:8.0],[loss:0.172361],[accuracy:0.980809]
# [Epocn:28],[batch_count:9.0],[loss:0.172832],[accuracy:0.984281]
# [Epocn:28],[batch_count:10.0],[loss:0.172238],[accuracy:0.985509]
# [Epoch 28/201], [loss:0.178973], accuracy:0.981591]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:29],[batch_count:1.0],[loss:0.180941],[accuracy:0.978891]
# [Epocn:29],[batch_count:2.0],[loss:0.174440],[accuracy:0.981385]
# [Epocn:29],[batch_count:3.0],[loss:0.178600],[accuracy:0.982980]
# [Epocn:29],[batch_count:4.0],[loss:0.178316],[accuracy:0.981026]
# [Epocn:29],[batch_count:5.0],[loss:0.166519],[accuracy:0.985112]
# [Epocn:29],[batch_count:6.0],[loss:0.172338],[accuracy:0.983899]
# [Epocn:29],[batch_count:7.0],[loss:0.179078],[accuracy:0.974703]
# [Epocn:29],[batch_count:8.0],[loss:0.171615],[accuracy:0.982916]
# [Epocn:29],[batch_count:9.0],[loss:0.175242],[accuracy:0.984601]
# [Epocn:29],[batch_count:10.0],[loss:0.169538],[accuracy:0.984491]
# [Epoch 29/201], [loss:0.174663], accuracy:0.982000]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:30],[batch_count:1.0],[loss:0.167912],[accuracy:0.985354]
# [Epocn:30],[batch_count:2.0],[loss:0.178288],[accuracy:0.976389]
# [Epocn:30],[batch_count:3.0],[loss:0.163838],[accuracy:0.986200]
# [Epocn:30],[batch_count:4.0],[loss:0.165817],[accuracy:0.984274]
# [Epocn:30],[batch_count:5.0],[loss:0.197996],[accuracy:0.976104]
# [Epocn:30],[batch_count:6.0],[loss:0.165418],[accuracy:0.984364]
# [Epocn:30],[batch_count:7.0],[loss:0.169012],[accuracy:0.978997]
# [Epocn:30],[batch_count:8.0],[loss:0.173864],[accuracy:0.976620]
# [Epocn:30],[batch_count:9.0],[loss:0.165119],[accuracy:0.984769]
# [Epocn:30],[batch_count:10.0],[loss:0.173945],[accuracy:0.980371]
# [Epoch 30/201], [loss:0.172121], accuracy:0.981344]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 30
# ------------------------------------------------------------------------------------------
# count:153600,TP:2417,TN:149795,FP:460,FN928
# processing image NO 0, time comsuption 0.011777s
# count:153600,TP:2278,TN:149628,FP:308,FN1386
# processing image NO 1, time comsuption 0.011262s
# count:153600,TP:3853,TN:146985,FP:527,FN2235
# processing image NO 2, time comsuption 0.011558s
# count:153600,TP:1763,TN:148942,FP:730,FN2165
# processing image NO 3, time comsuption 0.011461s
# count:153600,TP:2203,TN:150294,FP:524,FN579
# processing image NO 4, time comsuption 0.014166s
# count:153600,TP:2263,TN:150287,FP:416,FN634
# processing image NO 5, time comsuption 0.010212s
# count:153600,TP:2765,TN:149422,FP:393,FN1020
# processing image NO 6, time comsuption 0.014009s
# count:153600,TP:2613,TN:149639,FP:328,FN1020
# processing image NO 7, time comsuption 0.010544s
# count:153600,TP:2246,TN:149998,FP:668,FN688
# processing image NO 8, time comsuption 0.010895s
# count:153600,TP:1927,TN:148888,FP:2115,FN670
# processing image NO 9, time comsuption 0.011432s
# count:153600,TP:2252,TN:148123,FP:745,FN2480
# processing image NO 10, time comsuption 0.011302s
# count:153600,TP:1920,TN:150003,FP:866,FN811
# processing image NO 11, time comsuption 0.010612s
# count:153600,TP:1872,TN:149727,FP:1219,FN782
# processing image NO 12, time comsuption 0.018297s
# count:153600,TP:1563,TN:148477,FP:2531,FN1029
# processing image NO 13, time comsuption 0.013886s
# count:153600,TP:1995,TN:149422,FP:767,FN1416
# processing image NO 14, time comsuption 0.012260s
# count:153600,TP:2132,TN:149530,FP:816,FN1122
# processing image NO 15, time comsuption 0.011100s
# count:153600,TP:2454,TN:149281,FP:454,FN1411
# processing image NO 16, time comsuption 0.011589s
# count:153600,TP:1843,TN:150291,FP:692,FN774
# processing image NO 17, time comsuption 0.011482s
# count:153600,TP:1961,TN:149448,FP:1005,FN1186
# processing image NO 18, time comsuption 0.010478s
# count:153600,TP:2139,TN:149661,FP:729,FN1071
# processing image NO 19, time comsuption 0.011556s
# count:153600,TP:1964,TN:150103,FP:449,FN1084
# processing image NO 20, time comsuption 0.013542s
# count:153600,TP:2844,TN:148404,FP:843,FN1509
# processing image NO 21, time comsuption 0.014159s
# count:153600,TP:1891,TN:149449,FP:1315,FN945
# processing image NO 22, time comsuption 0.010994s
# count:153600,TP:2534,TN:149090,FP:594,FN1382
# processing image NO 23, time comsuption 0.016497s
# count:153600,TP:1813,TN:150155,FP:912,FN720
# processing image NO 24, time comsuption 0.011557s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 30/201], [loss:0.156506], accuracy:0.987115]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:31],[batch_count:1.0],[loss:0.174852],[accuracy:0.976478]
# [Epocn:31],[batch_count:2.0],[loss:0.163840],[accuracy:0.979124]
# [Epocn:31],[batch_count:3.0],[loss:0.158214],[accuracy:0.985890]
# [Epocn:31],[batch_count:4.0],[loss:0.168590],[accuracy:0.982112]
# [Epocn:31],[batch_count:5.0],[loss:0.174523],[accuracy:0.980417]
# [Epocn:31],[batch_count:6.0],[loss:0.162834],[accuracy:0.982646]
# [Epocn:31],[batch_count:7.0],[loss:0.157060],[accuracy:0.987781]
# [Epocn:31],[batch_count:8.0],[loss:0.167271],[accuracy:0.984399]
# [Epocn:31],[batch_count:9.0],[loss:0.164876],[accuracy:0.983129]
# [Epocn:31],[batch_count:10.0],[loss:0.172741],[accuracy:0.975353]
# [Epoch 31/201], [loss:0.166480], accuracy:0.981733]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:32],[batch_count:1.0],[loss:0.166556],[accuracy:0.982533]
# [Epocn:32],[batch_count:2.0],[loss:0.170926],[accuracy:0.983350]
# [Epocn:32],[batch_count:3.0],[loss:0.163518],[accuracy:0.983209]
# [Epocn:32],[batch_count:4.0],[loss:0.156663],[accuracy:0.983247]
# [Epocn:32],[batch_count:5.0],[loss:0.157068],[accuracy:0.983065]
# [Epocn:32],[batch_count:6.0],[loss:0.156167],[accuracy:0.982431]
# [Epocn:32],[batch_count:7.0],[loss:0.155617],[accuracy:0.986354]
# [Epocn:32],[batch_count:8.0],[loss:0.173602],[accuracy:0.979304]
# [Epocn:32],[batch_count:9.0],[loss:0.160344],[accuracy:0.981903]
# [Epocn:32],[batch_count:10.0],[loss:0.170407],[accuracy:0.973632]
# [Epoch 32/201], [loss:0.163087], accuracy:0.981903]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:33],[batch_count:1.0],[loss:0.152982],[accuracy:0.981970]
# [Epocn:33],[batch_count:2.0],[loss:0.155321],[accuracy:0.980291]
# [Epocn:33],[batch_count:3.0],[loss:0.150838],[accuracy:0.983606]
# [Epocn:33],[batch_count:4.0],[loss:0.152515],[accuracy:0.985610]
# [Epocn:33],[batch_count:5.0],[loss:0.178734],[accuracy:0.974029]
# [Epocn:33],[batch_count:6.0],[loss:0.155244],[accuracy:0.983817]
# [Epocn:33],[batch_count:7.0],[loss:0.165904],[accuracy:0.982025]
# [Epocn:33],[batch_count:8.0],[loss:0.159479],[accuracy:0.983733]
# [Epocn:33],[batch_count:9.0],[loss:0.155793],[accuracy:0.986812]
# [Epocn:33],[batch_count:10.0],[loss:0.152418],[accuracy:0.983632]
# [Epoch 33/201], [loss:0.157923], accuracy:0.982552]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:34],[batch_count:1.0],[loss:0.157768],[accuracy:0.983722]
# [Epocn:34],[batch_count:2.0],[loss:0.150925],[accuracy:0.985319]
# [Epocn:34],[batch_count:3.0],[loss:0.169027],[accuracy:0.980360]
# [Epocn:34],[batch_count:4.0],[loss:0.166947],[accuracy:0.976204]
# [Epocn:34],[batch_count:5.0],[loss:0.155665],[accuracy:0.986337]
# [Epocn:34],[batch_count:6.0],[loss:0.145890],[accuracy:0.983997]
# [Epocn:34],[batch_count:7.0],[loss:0.151582],[accuracy:0.983661]
# [Epocn:34],[batch_count:8.0],[loss:0.153067],[accuracy:0.981546]
# [Epocn:34],[batch_count:9.0],[loss:0.157763],[accuracy:0.979249]
# [Epocn:34],[batch_count:10.0],[loss:0.144766],[accuracy:0.986514]
# [Epoch 34/201], [loss:0.155340], accuracy:0.982691]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:35],[batch_count:1.0],[loss:0.167661],[accuracy:0.980576]
# [Epocn:35],[batch_count:2.0],[loss:0.148548],[accuracy:0.985766]
# [Epocn:35],[batch_count:3.0],[loss:0.157082],[accuracy:0.979948]
# [Epocn:35],[batch_count:4.0],[loss:0.150537],[accuracy:0.980936]
# [Epocn:35],[batch_count:5.0],[loss:0.137725],[accuracy:0.988706]
# [Epocn:35],[batch_count:6.0],[loss:0.149183],[accuracy:0.985668]
# [Epocn:35],[batch_count:7.0],[loss:0.162104],[accuracy:0.975916]
# [Epocn:35],[batch_count:8.0],[loss:0.151076],[accuracy:0.979392]
# [Epocn:35],[batch_count:9.0],[loss:0.151983],[accuracy:0.981872]
# [Epocn:35],[batch_count:10.0],[loss:0.150846],[accuracy:0.984363]
# [Epoch 35/201], [loss:0.152674], accuracy:0.982314]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:36],[batch_count:1.0],[loss:0.150187],[accuracy:0.982316]
# [Epocn:36],[batch_count:2.0],[loss:0.154132],[accuracy:0.980178]
# [Epocn:36],[batch_count:3.0],[loss:0.148034],[accuracy:0.983254]
# [Epocn:36],[batch_count:4.0],[loss:0.154136],[accuracy:0.977957]
# [Epocn:36],[batch_count:5.0],[loss:0.144506],[accuracy:0.983030]
# [Epocn:36],[batch_count:6.0],[loss:0.140051],[accuracy:0.987517]
# [Epocn:36],[batch_count:7.0],[loss:0.144602],[accuracy:0.982821]
# [Epocn:36],[batch_count:8.0],[loss:0.145197],[accuracy:0.983435]
# [Epocn:36],[batch_count:9.0],[loss:0.142617],[accuracy:0.981994]
# [Epocn:36],[batch_count:10.0],[loss:0.147344],[accuracy:0.986458]
# [Epoch 36/201], [loss:0.147081], accuracy:0.982896]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:37],[batch_count:1.0],[loss:0.141804],[accuracy:0.983237]
# [Epocn:37],[batch_count:2.0],[loss:0.161912],[accuracy:0.980417]
# [Epocn:37],[batch_count:3.0],[loss:0.146275],[accuracy:0.976980]
# [Epocn:37],[batch_count:4.0],[loss:0.143693],[accuracy:0.980979]
# [Epocn:37],[batch_count:5.0],[loss:0.141927],[accuracy:0.984175]
# [Epocn:37],[batch_count:6.0],[loss:0.147272],[accuracy:0.980635]
# [Epocn:37],[batch_count:7.0],[loss:0.143655],[accuracy:0.984505]
# [Epocn:37],[batch_count:8.0],[loss:0.144557],[accuracy:0.982491]
# [Epocn:37],[batch_count:9.0],[loss:0.149991],[accuracy:0.985382]
# [Epocn:37],[batch_count:10.0],[loss:0.134307],[accuracy:0.989257]
# [Epoch 37/201], [loss:0.145539], accuracy:0.982806]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:38],[batch_count:1.0],[loss:0.145823],[accuracy:0.983380]
# [Epocn:38],[batch_count:2.0],[loss:0.152335],[accuracy:0.982250]
# [Epocn:38],[batch_count:3.0],[loss:0.144890],[accuracy:0.985093]
# [Epocn:38],[batch_count:4.0],[loss:0.137126],[accuracy:0.985201]
# [Epocn:38],[batch_count:5.0],[loss:0.146179],[accuracy:0.983091]
# [Epocn:38],[batch_count:6.0],[loss:0.142664],[accuracy:0.985494]
# [Epocn:38],[batch_count:7.0],[loss:0.140872],[accuracy:0.981933]
# [Epocn:38],[batch_count:8.0],[loss:0.141635],[accuracy:0.981260]
# [Epocn:38],[batch_count:9.0],[loss:0.146417],[accuracy:0.978796]
# [Epocn:38],[batch_count:10.0],[loss:0.155473],[accuracy:0.974734]
# [Epoch 38/201], [loss:0.145342], accuracy:0.982123]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:39],[batch_count:1.0],[loss:0.133271],[accuracy:0.985885]
# [Epocn:39],[batch_count:2.0],[loss:0.145796],[accuracy:0.979568]
# [Epocn:39],[batch_count:3.0],[loss:0.146849],[accuracy:0.981356]
# [Epocn:39],[batch_count:4.0],[loss:0.142834],[accuracy:0.982888]
# [Epocn:39],[batch_count:5.0],[loss:0.130127],[accuracy:0.986483]
# [Epocn:39],[batch_count:6.0],[loss:0.126695],[accuracy:0.988596]
# [Epocn:39],[batch_count:7.0],[loss:0.139742],[accuracy:0.982674]
# [Epocn:39],[batch_count:8.0],[loss:0.148844],[accuracy:0.980488]
# [Epocn:39],[batch_count:9.0],[loss:0.136635],[accuracy:0.987510]
# [Epocn:39],[batch_count:10.0],[loss:0.154513],[accuracy:0.968962]
# [Epoch 39/201], [loss:0.140531], accuracy:0.982441]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:40],[batch_count:1.0],[loss:0.132114],[accuracy:0.985142]
# [Epocn:40],[batch_count:2.0],[loss:0.132474],[accuracy:0.984465]
# [Epocn:40],[batch_count:3.0],[loss:0.142484],[accuracy:0.980400]
# [Epocn:40],[batch_count:4.0],[loss:0.130813],[accuracy:0.987029]
# [Epocn:40],[batch_count:5.0],[loss:0.144385],[accuracy:0.979809]
# [Epocn:40],[batch_count:6.0],[loss:0.129256],[accuracy:0.986548]
# [Epocn:40],[batch_count:7.0],[loss:0.146187],[accuracy:0.975289]
# [Epocn:40],[batch_count:8.0],[loss:0.130680],[accuracy:0.985082]
# [Epocn:40],[batch_count:9.0],[loss:0.137791],[accuracy:0.981603]
# [Epocn:40],[batch_count:10.0],[loss:0.136470],[accuracy:0.983191]
# [Epoch 40/201], [loss:0.136265], accuracy:0.982856]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 40
# ------------------------------------------------------------------------------------------
# count:153600,TP:2478,TN:149911,FP:344,FN867
# processing image NO 0, time comsuption 0.012137s
# count:153600,TP:2450,TN:149634,FP:302,FN1214
# processing image NO 1, time comsuption 0.014753s
# count:153600,TP:3768,TN:147167,FP:345,FN2320
# processing image NO 2, time comsuption 0.011660s
# count:153600,TP:2331,TN:149006,FP:666,FN1597
# processing image NO 3, time comsuption 0.013529s
# count:153600,TP:2053,TN:150394,FP:424,FN729
# processing image NO 4, time comsuption 0.013164s
# count:153600,TP:2152,TN:150271,FP:432,FN745
# processing image NO 5, time comsuption 0.010998s
# count:153600,TP:2646,TN:149339,FP:476,FN1139
# processing image NO 6, time comsuption 0.013884s
# count:153600,TP:2521,TN:149692,FP:275,FN1112
# processing image NO 7, time comsuption 0.012622s
# count:153600,TP:2108,TN:150092,FP:574,FN826
# processing image NO 8, time comsuption 0.011510s
# count:153600,TP:1915,TN:149568,FP:1435,FN682
# processing image NO 9, time comsuption 0.013335s
# count:153600,TP:2919,TN:147967,FP:901,FN1813
# processing image NO 10, time comsuption 0.010899s
# count:153600,TP:1893,TN:150163,FP:706,FN838
# processing image NO 11, time comsuption 0.011085s
# count:153600,TP:1793,TN:149609,FP:1337,FN861
# processing image NO 12, time comsuption 0.010823s
# count:153600,TP:1777,TN:148992,FP:2016,FN815
# processing image NO 13, time comsuption 0.010487s
# count:153600,TP:2246,TN:149326,FP:863,FN1165
# processing image NO 14, time comsuption 0.010955s
# count:153600,TP:2196,TN:149513,FP:833,FN1058
# processing image NO 15, time comsuption 0.010896s
# count:153600,TP:2312,TN:149296,FP:439,FN1553
# processing image NO 16, time comsuption 0.013844s
# count:153600,TP:1873,TN:150346,FP:637,FN744
# processing image NO 17, time comsuption 0.016218s
# count:153600,TP:2089,TN:149568,FP:885,FN1058
# processing image NO 18, time comsuption 0.011277s
# count:153600,TP:2165,TN:149508,FP:882,FN1045
# processing image NO 19, time comsuption 0.010671s
# count:153600,TP:2109,TN:150192,FP:360,FN939
# processing image NO 20, time comsuption 0.010134s
# count:153600,TP:3036,TN:148525,FP:722,FN1317
# processing image NO 21, time comsuption 0.014131s
# count:153600,TP:1874,TN:149564,FP:1200,FN962
# processing image NO 22, time comsuption 0.010848s
# count:153600,TP:2539,TN:149215,FP:469,FN1377
# processing image NO 23, time comsuption 0.011098s
# count:153600,TP:1717,TN:150109,FP:958,FN816
# processing image NO 24, time comsuption 0.011305s
# ------------------------------------------------------------------------------------------
# 开始写入评估参数
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# [Epoch 40/201], [loss:0.123518], accuracy:0.987996]
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# 开始写入测试过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:41],[batch_count:1.0],[loss:0.133706],[accuracy:0.981931]
# [Epocn:41],[batch_count:2.0],[loss:0.135055],[accuracy:0.984544]
# [Epocn:41],[batch_count:3.0],[loss:0.129344],[accuracy:0.986895]
# [Epocn:41],[batch_count:4.0],[loss:0.131350],[accuracy:0.985893]
# [Epocn:41],[batch_count:5.0],[loss:0.128393],[accuracy:0.986844]
# [Epocn:41],[batch_count:6.0],[loss:0.136051],[accuracy:0.979389]
# [Epocn:41],[batch_count:7.0],[loss:0.138986],[accuracy:0.979635]
# [Epocn:41],[batch_count:8.0],[loss:0.131243],[accuracy:0.984724]
# [Epocn:41],[batch_count:9.0],[loss:0.128188],[accuracy:0.982546]
# [Epocn:41],[batch_count:10.0],[loss:0.129936],[accuracy:0.983962]
# [Epoch 41/201], [loss:0.132225], accuracy:0.983636]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:42],[batch_count:1.0],[loss:0.131526],[accuracy:0.982216]
# [Epocn:42],[batch_count:2.0],[loss:0.134864],[accuracy:0.978561]
# [Epocn:42],[batch_count:3.0],[loss:0.126470],[accuracy:0.986191]
# [Epocn:42],[batch_count:4.0],[loss:0.143133],[accuracy:0.979725]
# [Epocn:42],[batch_count:5.0],[loss:0.126647],[accuracy:0.986629]
# [Epocn:42],[batch_count:6.0],[loss:0.144361],[accuracy:0.977343]
# [Epocn:42],[batch_count:7.0],[loss:0.127750],[accuracy:0.980379]
# [Epocn:42],[batch_count:8.0],[loss:0.137007],[accuracy:0.982973]
# [Epocn:42],[batch_count:9.0],[loss:0.125078],[accuracy:0.986455]
# [Epocn:42],[batch_count:10.0],[loss:0.135031],[accuracy:0.985832]
# [Epoch 42/201], [loss:0.133187], accuracy:0.982630]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:43],[batch_count:1.0],[loss:0.135836],[accuracy:0.977294]
# [Epocn:43],[batch_count:2.0],[loss:0.131796],[accuracy:0.984038]
# [Epocn:43],[batch_count:3.0],[loss:0.133404],[accuracy:0.983564]
# [Epocn:43],[batch_count:4.0],[loss:0.129824],[accuracy:0.985144]
# [Epocn:43],[batch_count:5.0],[loss:0.122951],[accuracy:0.987272]
# [Epocn:43],[batch_count:6.0],[loss:0.125236],[accuracy:0.984080]
# [Epocn:43],[batch_count:7.0],[loss:0.147992],[accuracy:0.976749]
# [Epocn:43],[batch_count:8.0],[loss:0.131806],[accuracy:0.983963]
# [Epocn:43],[batch_count:9.0],[loss:0.137033],[accuracy:0.983101]
# [Epocn:43],[batch_count:10.0],[loss:0.131108],[accuracy:0.979820]
# [Epoch 43/201], [loss:0.132699], accuracy:0.982503]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:44],[batch_count:1.0],[loss:0.129238],[accuracy:0.984595]
# [Epocn:44],[batch_count:2.0],[loss:0.121053],[accuracy:0.986615]
# [Epocn:44],[batch_count:3.0],[loss:0.123374],[accuracy:0.981570]
# [Epocn:44],[batch_count:4.0],[loss:0.128881],[accuracy:0.980387]
# [Epocn:44],[batch_count:5.0],[loss:0.126030],[accuracy:0.983398]
# [Epocn:44],[batch_count:6.0],[loss:0.184148],[accuracy:0.971642]
# [Epocn:44],[batch_count:7.0],[loss:0.133126],[accuracy:0.982262]
# [Epocn:44],[batch_count:8.0],[loss:0.136524],[accuracy:0.976995]
# [Epocn:44],[batch_count:9.0],[loss:0.130757],[accuracy:0.983104]
# [Epocn:44],[batch_count:10.0],[loss:0.118898],[accuracy:0.988042]
# [Epoch 44/201], [loss:0.133203], accuracy:0.981861]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:45],[batch_count:1.0],[loss:0.134420],[accuracy:0.980867]
# [Epocn:45],[batch_count:2.0],[loss:0.138557],[accuracy:0.980213]
# [Epocn:45],[batch_count:3.0],[loss:0.125109],[accuracy:0.983176]
# [Epocn:45],[batch_count:4.0],[loss:0.124211],[accuracy:0.984269]
# [Epocn:45],[batch_count:5.0],[loss:0.132114],[accuracy:0.981140]
# [Epocn:45],[batch_count:6.0],[loss:0.135557],[accuracy:0.982028]
# [Epocn:45],[batch_count:7.0],[loss:0.125760],[accuracy:0.983453]
# [Epocn:45],[batch_count:8.0],[loss:0.133160],[accuracy:0.979758]
# [Epocn:45],[batch_count:9.0],[loss:0.125499],[accuracy:0.984809]
# [Epocn:45],[batch_count:10.0],[loss:0.127492],[accuracy:0.979581]
# [Epoch 45/201], [loss:0.130188], accuracy:0.981929]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:46],[batch_count:1.0],[loss:0.128020],[accuracy:0.980719]
# [Epocn:46],[batch_count:2.0],[loss:0.120332],[accuracy:0.985372]
# [Epocn:46],[batch_count:3.0],[loss:0.132272],[accuracy:0.977573]
# [Epocn:46],[batch_count:4.0],[loss:0.126886],[accuracy:0.980672]
# [Epocn:46],[batch_count:5.0],[loss:0.128518],[accuracy:0.982065]
# [Epocn:46],[batch_count:6.0],[loss:0.123079],[accuracy:0.988435]
# [Epocn:46],[batch_count:7.0],[loss:0.124771],[accuracy:0.981478]
# [Epocn:46],[batch_count:8.0],[loss:0.113122],[accuracy:0.989600]
# [Epocn:46],[batch_count:9.0],[loss:0.129589],[accuracy:0.981084]
# [Epocn:46],[batch_count:10.0],[loss:0.132827],[accuracy:0.978212]
# [Epoch 46/201], [loss:0.125942], accuracy:0.982521]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:47],[batch_count:1.0],[loss:0.118471],[accuracy:0.983522]
# [Epocn:47],[batch_count:2.0],[loss:0.120613],[accuracy:0.983646]
# [Epocn:47],[batch_count:3.0],[loss:0.126904],[accuracy:0.980699]
# [Epocn:47],[batch_count:4.0],[loss:0.120468],[accuracy:0.984251]
# [Epocn:47],[batch_count:5.0],[loss:0.123580],[accuracy:0.987096]
# [Epocn:47],[batch_count:6.0],[loss:0.120038],[accuracy:0.985380]
# [Epocn:47],[batch_count:7.0],[loss:0.123777],[accuracy:0.985195]
# [Epocn:47],[batch_count:8.0],[loss:0.117808],[accuracy:0.981298]
# [Epocn:47],[batch_count:9.0],[loss:0.124592],[accuracy:0.983585]
# [Epocn:47],[batch_count:10.0],[loss:0.135963],[accuracy:0.973749]
# [Epoch 47/201], [loss:0.123222], accuracy:0.982842]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:48],[batch_count:1.0],[loss:0.119897],[accuracy:0.984840]
# [Epocn:48],[batch_count:2.0],[loss:0.109501],[accuracy:0.988203]
# [Epocn:48],[batch_count:3.0],[loss:0.137146],[accuracy:0.981158]
# [Epocn:48],[batch_count:4.0],[loss:0.123491],[accuracy:0.982975]
# [Epocn:48],[batch_count:5.0],[loss:0.117453],[accuracy:0.985420]
# [Epocn:48],[batch_count:6.0],[loss:0.128838],[accuracy:0.978551]
# [Epocn:48],[batch_count:7.0],[loss:0.127128],[accuracy:0.979191]
# [Epocn:48],[batch_count:8.0],[loss:0.108626],[accuracy:0.989366]
# [Epocn:48],[batch_count:9.0],[loss:0.118956],[accuracy:0.979722]
# [Epocn:48],[batch_count:10.0],[loss:0.111541],[accuracy:0.986990]
# [Epoch 48/201], [loss:0.120258], accuracy:0.983642]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:49],[batch_count:1.0],[loss:0.121721],[accuracy:0.984814]
# [Epocn:49],[batch_count:2.0],[loss:0.114319],[accuracy:0.987789]
# [Epocn:49],[batch_count:3.0],[loss:0.114561],[accuracy:0.982754]
# [Epocn:49],[batch_count:4.0],[loss:0.115989],[accuracy:0.986659]
# [Epocn:49],[batch_count:5.0],[loss:0.121107],[accuracy:0.977817]
# [Epocn:49],[batch_count:6.0],[loss:0.124553],[accuracy:0.982422]
# [Epocn:49],[batch_count:7.0],[loss:0.111139],[accuracy:0.986418]
# [Epocn:49],[batch_count:8.0],[loss:0.110162],[accuracy:0.984952]
# [Epocn:49],[batch_count:9.0],[loss:0.125002],[accuracy:0.982943]
# [Epocn:49],[batch_count:10.0],[loss:0.118162],[accuracy:0.983810]
# [Epoch 49/201], [loss:0.117671], accuracy:0.984038]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# [Epocn:50],[batch_count:1.0],[loss:0.118651],[accuracy:0.981024]
# [Epocn:50],[batch_count:2.0],[loss:0.119170],[accuracy:0.980738]
# [Epocn:50],[batch_count:3.0],[loss:0.115302],[accuracy:0.982974]
# [Epocn:50],[batch_count:4.0],[loss:0.117019],[accuracy:0.983457]
# [Epocn:50],[batch_count:5.0],[loss:0.112144],[accuracy:0.982576]
# [Epocn:50],[batch_count:6.0],[loss:0.114313],[accuracy:0.986694]
# [Epocn:50],[batch_count:7.0],[loss:0.114834],[accuracy:0.986060]
# [Epocn:50],[batch_count:8.0],[loss:0.114819],[accuracy:0.985907]
# [Epocn:50],[batch_count:9.0],[loss:0.130897],[accuracy:0.980216]
# [Epocn:50],[batch_count:10.0],[loss:0.106871],[accuracy:0.988645]
# [Epoch 50/201], [loss:0.116402], accuracy:0.983829]
# ------------------------------------------------------------------------------------------
# 开始写入训练过程的epoch, loss, accuracy
# xls格式表格[追加]写入数据成功！
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# save weights ! epoch = 50
# ------------------------------------------------------------------------------------------
# count:153600,TP:2339,TN:149797,FP:458,FN1006
# processing image NO 0, time comsuption 0.010799s
# count:153600,TP:2321,TN:149486,FP:450,FN1343
# processing image NO 1, time comsuption 0.013880s
# count:153600,TP:3681,TN:147089,FP:423,FN2407
# processing image NO 2, time comsuption 0.011225s
# count:153600,TP:2018,TN:148957,FP:715,FN1910
# processing image NO 3, time comsuption 0.011956s
# count:153600,TP:1931,TN:150310,FP:508,FN851
# processing image NO 4, time comsuption 0.013813s
# count:153600,TP:2003,TN:150273,FP:430,FN894
# processing image NO 5, time comsuption 0.013029s
# count:153600,TP:2475,TN:149212,FP:603,FN1310
# processing image NO 6, time comsuption 0.010857s
# count:153600,TP:2413,TN:149707,FP:260,FN1220
# processing image NO 7, time comsuption 0.013968s
# count:153600,TP:2115,TN:150071,FP:595,FN819
# processing image NO 8, time comsuption 0.011387s
# count:153600,TP:1773,TN:149604,FP:1399,FN824
# processing image NO 9, time comsuption 0.010783s
# count:153600,TP:2686,TN:148088,FP:780,FN2046
# processing image NO 10, time comsuption 0.011393s
# count:153600,TP:1776,TN:149980,FP:889,FN955
# processing image NO 11, time comsuption 0.011492s
# count:153600,TP:1719,TN:150095,FP:851,FN935
# processing image NO 12, time comsuption 0.011493s
# count:153600,TP:1562,TN:149991,FP:1017,FN1030
# processing image NO 13, time comsuption 0.014211s
# count:153600,TP:1948,TN:149417,FP:772,FN1463
# processing image NO 14, time comsuption 0.011451s
# count:153600,TP:2147,TN:149643,FP:703,FN1107
# processing image NO 15, time comsuption 0.011606s
# count:153600,TP:2187,TN:149256,FP:479,FN1678
# processing image NO 16, time comsuption 0.013529s
# count:153600,TP:1737,TN:150200,FP:783,FN880
# processing image NO 17, time comsuption 0.011280s
# count:153600,TP:1837,TN:149603,FP:850,FN1310
# processing image NO 18, time comsuption 0.010986s
# count:153600,TP:2123,TN:149688,FP:702,FN1087
